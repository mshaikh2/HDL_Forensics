# %%
import numpy as np
from keras import layers, models, optimizers
from keras.models import Model
from keras.layers import Input, Reshape, Flatten, Conv2D, BatchNormalization, concatenate, Dropout, Lambda, Dense
from keras import backend as K
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
from capsulelayers import CapsuleLayer, PrimaryCap, Length, Mask
import os
import datetime
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
import argparse
from keras.preprocessing.image import ImageDataGenerator
from keras import callbacks
import cv2

def CapsNet(input_shape, n_class, routings):
    """
    A Capsule Network on MNIST.
    :param input_shape: data shape, 3d, [width, height, channels]
    :param n_class: number of classes
    :param routings: number of routing iterations
    :return: Two Keras Models, the first one used for training, and the second one for evaluation.
            `eval_model` can also be used for training.
    """
    x = layers.Input(shape=input_shape)

    # Layer 1: Just a conventional Conv2D layer
    conv1 = layers.Conv2D(filters=256, kernel_size=9, strides=1, padding='valid', activation='relu', name='conv1')(x)
    
#     output = layers.Conv2D(filters=8*32, kernel_size=9, strides=2, padding='valid',
#                            name='primarycap_conv2d')(conv1)
    
    # Layer 2: Conv2D layer with `squash` activation, then reshape to [None, num_capsule, dim_capsule]
    primarycaps = PrimaryCap(conv1, dim_capsule=8, n_channels=32, kernel_size=9, strides=2, padding='valid')

    # Layer 3: Capsule layer. Routing algorithm works here.
    digitcaps = CapsuleLayer(num_capsule=n_class, dim_capsule=16, routings=routings,
                             name='digitcaps')(primarycaps)

    # Layer 4: This is an auxiliary layer to replace each capsule with its length. Just to match the true label's shape.
    # If using tensorflow, this will not be necessary. :)
    out_caps = Length(name='capsnet')(digitcaps)

    # Decoder network.
    y = layers.Input(shape=(n_class,))
    masked_by_y = Mask()([digitcaps, y])  # The true label is used to mask the output of capsule layer. For training
    masked = Mask()(digitcaps)  # Mask using the capsule with maximal length. For prediction

    # Shared Decoder model in training and prediction
    decoder = models.Sequential(name='decoder')
    decoder.add(layers.Dense(512, activation='relu', input_dim=16*n_class))
    decoder.add(layers.Dense(1024, activation='relu'))
    decoder.add(layers.Dense(np.prod(input_shape), activation='sigmoid'))
    decoder.add(layers.Reshape(target_shape=input_shape, name='out_recon'))

    # Models for training and evaluation (prediction)
    train_model = models.Model([x, y], [out_caps, decoder(masked_by_y)])
    eval_model = models.Model(x, [out_caps, decoder(masked)])

    # manipulate model
    noise = layers.Input(shape=(n_class, 16))
    noised_digitcaps = layers.Add()([digitcaps, noise])
    masked_noised_y = Mask()([noised_digitcaps, y])
    manipulate_model = models.Model([x, y, noise], decoder(masked_noised_y))
    return train_model, eval_model, manipulate_model
# Out:
# Using TensorFlow backend.

# %%
csv_data = pd.read_csv('AND_Features.csv')
display(csv_data.head()), display(csv_data.shape)
image_path = 'cleaned_AND_data_64x64/'
images = os.listdir(image_path)
print(len(images))
images = pd.DataFrame(np.array(images), columns=['image'])
print(images.shape)
# Out:
#    Unnamed: 0 ImageId  f1  f2  f3  f4  f5  f6  f7  f8  f9
# 0           0   0359a   2   1   1   0   2   2   0   2   2
# 1           1   0577a   2   1   1   0   2   2   0   1   2
# 2           2   1120a   2   1   1   3   2   2   0   2   2
# 3           3   1120b   1   1   1   0   2   2   0   2   2
# 4           4   1120c   2   1   1   0   2   2   0   0   2
# (1026, 11)
# 13850
# (13850, 1)

# %%
dataset_columns = csv_data.columns
display(csv_data.head(20))
csv_data.shape
# Out:
#     Unnamed: 0 ImageId  f1  f2  f3  f4  f5  f6  f7  f8  f9
# 0            0   0359a   2   1   1   0   2   2   0   2   2
# 1            1   0577a   2   1   1   0   2   2   0   1   2
# 2            2   1120a   2   1   1   3   2   2   0   2   2
# 3            3   1120b   1   1   1   0   2   2   0   2   2
# 4            4   1120c   2   1   1   0   2   2   0   0   2
# 5            5   1121a   2   1   1   3   2   2   0   1   2
# 6            6   1121b   2   1   1   0   2   2   0   3   2
# 7            7   1121c   1   1   1   0   2   2   0   1   2
# 8            8   1229b   1   1   1   3   2   2   0   2   2
# 9            9   1302a   2   1   1   3   2   2   0   0   2
# 10          10   1302b   3   1   1   0   2   2   0   2   2
# 11          11   1302c   2   1   1   3   2   2   0   3   2
# 12          12   1305a   1   1   1   0   2   2   0   0   2
# 13          13   1305b   2   1   1   0   2   2   1   2   2
# 14          14   1305c   1   1   1   3   2   2   0   1   2
# 15          15   1386a   1   1   1   0   2   2   0   3   2
# 16          16   1386b   3   1   1   0   2   2   0   1   2
# 17          17   1386c   3   1   1   3   2   2   0   2   2
# 18          18   1391c   2   1   1   0   2   2   1   1   2
# 19          19   1489a   1   1   1   3   2   2   0   0   2
# (1026, 11)

# %%
train_csv_data =  csv_data[:700]
val_csv_data =  csv_data[700:]
train_csv_data.shape, val_csv_data.shape
# Out:
# ((700, 11), (326, 11))

# %%
feature_lengths = {}
for col in dataset_columns[2:10]:
    feature_lengths[col] = len(csv_data[col].unique())
feature_lengths
# Out:
# {'f1': 4, 'f2': 5, 'f3': 3, 'f4': 5, 'f5': 4, 'f6': 4, 'f7': 4, 'f8': 5}

# %%
f = []
for col in dataset_columns[2:]:
    f.append(csv_data[col].unique().shape[0])
f
# Out:
# [4, 5, 3, 5, 4, 4, 4, 5, 2]

# %%
input_shape = (64,64,1)
inp = Input(shape=input_shape)
bm = Conv2D(kernel_size=(3,3), filters=32, activation='relu', strides=(1,1), padding='same')(inp)
bm = Conv2D(kernel_size=(3,3), filters=64, activation='relu', strides=(2,2), padding='same')(bm)
bm = Dropout(0.5)(bm)
bm = Conv2D(kernel_size=(3,3), filters=128, activation='relu', strides=(1,1), padding='same')(bm)
bm_out = Conv2D(kernel_size=(3,3), filters=256, activation='relu', strides=(2,2), padding='same', name='basemodel_output')(bm)
baseModel = Model(inputs=[inp],outputs=[bm_out])
baseModel.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        320
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# basemodel_output (Conv2D)    (None, 16, 16, 256)       295168
# =================================================================
# Total params: 387,840
# Trainable params: 387,840
# Non-trainable params: 0
# _________________________________________________________________

# %%
def getdigit(x, f):
#     print(x[:,f].shape)
    return x[:,f]

# %%
n_class = 8
routings = 3
x = baseModel.get_layer('basemodel_output').output
# x = layers.Input(shape=input_shape)

# Layer 1: Just a conventional Conv2D layer
# conv1 = layers.Conv2D(filters=256, kernel_size=9, strides=1, padding='valid', activation='relu', name='conv1')(x)

#     output = layers.Conv2D(filters=8*32, kernel_size=9, strides=2, padding='valid',
#                            name='primarycap_conv2d')(conv1)

# Layer 2: Conv2D layer with `squash` activation, then reshape to [None, num_capsule, dim_capsule]
primarycaps = PrimaryCap(x, dim_capsule=8, n_channels=32, kernel_size=9, strides=2, padding='valid')

# Layer 3: Capsule layer. Routing algorithm works here.
digitcaps = CapsuleLayer(num_capsule=n_class, dim_capsule=16, routings=routings,
                         name='digitcaps')(primarycaps)

# Layer 4: This is an auxiliary layer to replace each capsule with its length. Just to match the true label's shape.
# If using tensorflow, this will not be necessary. :)
# out_caps = Length(name='capsnet')(digitcaps)
# f=0
l1 = Lambda(getdigit,arguments={'f':0})(digitcaps)
l2 = Lambda(function=getdigit, arguments={'f':1})(digitcaps)
l3 = Lambda(function=getdigit, arguments={'f':2})(digitcaps)
l4 = Lambda(function=getdigit, arguments={'f':3})(digitcaps)
l5 = Lambda(function=getdigit, arguments={'f':4})(digitcaps)
l6 = Lambda(function=getdigit, arguments={'f':5})(digitcaps)
l7 = Lambda(function=getdigit, arguments={'f':6})(digitcaps)
l8 = Lambda(function=getdigit, arguments={'f':7})(digitcaps)

dense_layer_1 = Dense(64 , activation='relu', name = 'dense_layer_1')(l1)
dense_layer_2 = Dense(64 , activation='relu', name = 'dense_layer_2')(l2)
dense_layer_3 = Dense(64 , activation='relu', name = 'dense_layer_3')(l3)
dense_layer_4 = Dense(64 , activation='relu', name = 'dense_layer_4')(l4)
dense_layer_5 = Dense(64 , activation='relu', name = 'dense_layer_5')(l5)
dense_layer_6 = Dense(64 , activation='relu', name = 'dense_layer_6')(l6)
dense_layer_7 = Dense(64 , activation='relu', name = 'dense_layer_7')(l7)
dense_layer_8 = Dense(64 , activation='relu', name = 'dense_layer_8')(l8)


out_feature_1 = Dense(f[0] , activation='softmax', name = 'out_feature_1')(dense_layer_1)
out_feature_2 = Dense(f[1] , activation='softmax', name = 'out_feature_2')(dense_layer_2)
out_feature_3 = Dense(f[2] , activation='softmax', name = 'out_feature_3')(dense_layer_3)
out_feature_4 = Dense(f[3] , activation='softmax', name = 'out_feature_4')(dense_layer_4)
out_feature_5 = Dense(f[4] , activation='softmax', name = 'out_feature_5')(dense_layer_5)
out_feature_6 = Dense(f[5] , activation='softmax', name = 'out_feature_6')(dense_layer_6)
out_feature_7 = Dense(f[6] , activation='softmax', name = 'out_feature_7')(dense_layer_7)
out_feature_8 = Dense(f[7] , activation='softmax', name = 'out_feature_8')(dense_layer_8)

decoder = Flatten()(digitcaps)
decoder = Dense(512, activation='relu')(decoder)
decoder = Dense(1024, activation='relu')(decoder)
decoder = Dense(np.prod(input_shape), activation='sigmoid')(decoder)
decoder_out = Reshape(target_shape = input_shape, name = 'recon')(decoder)
# Out:
# WARNING:tensorflow:From /home/mshaikh2/AdvancedProjects/Handwriting/capsulelayers.py:145: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead

# %%
model = Model(inputs=baseModel.inputs,outputs=[decoder_out
                                            ,out_feature_1
                                               ,out_feature_2
                                               ,out_feature_3
                                               ,out_feature_4
                                               ,out_feature_5
                                               ,out_feature_6
                                               ,out_feature_7
                                               ,out_feature_8])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   18496       conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 64)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 128)  73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# basemodel_output (Conv2D)       (None, 16, 16, 256)  295168      conv2d_3[0][0]
# __________________________________________________________________________________________________
# primarycap_conv2d (Conv2D)      (None, 4, 4, 256)    5308672     basemodel_output[0][0]
# __________________________________________________________________________________________________
# primarycap_reshape (Reshape)    (None, 512, 8)       0           primarycap_conv2d[0][0]
# __________________________________________________________________________________________________
# primarycap_squash (Lambda)      (None, 512, 8)       0           primarycap_reshape[0][0]
# __________________________________________________________________________________________________
# digitcaps (CapsuleLayer)        (None, 8, 16)        524288      primarycap_squash[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 128)          0           digitcaps[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          66048       flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1024)         525312      dense_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 16)           0           digitcaps[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 16)           0           digitcaps[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 16)           0           digitcaps[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 16)           0           digitcaps[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 16)           0           digitcaps[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 16)           0           digitcaps[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 16)           0           digitcaps[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 16)           0           digitcaps[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4096)         4198400     dense_2[0][0]
# __________________________________________________________________________________________________
# dense_layer_1 (Dense)           (None, 64)           1088        lambda_1[0][0]
# __________________________________________________________________________________________________
# dense_layer_2 (Dense)           (None, 64)           1088        lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_layer_3 (Dense)           (None, 64)           1088        lambda_3[0][0]
# __________________________________________________________________________________________________
# dense_layer_4 (Dense)           (None, 64)           1088        lambda_4[0][0]
# __________________________________________________________________________________________________
# dense_layer_5 (Dense)           (None, 64)           1088        lambda_5[0][0]
# __________________________________________________________________________________________________
# dense_layer_6 (Dense)           (None, 64)           1088        lambda_6[0][0]
# __________________________________________________________________________________________________
# dense_layer_7 (Dense)           (None, 64)           1088        lambda_7[0][0]
# __________________________________________________________________________________________________
# dense_layer_8 (Dense)           (None, 64)           1088        lambda_8[0][0]
# __________________________________________________________________________________________________
# recon (Reshape)                 (None, 64, 64, 1)    0           dense_3[0][0]
# __________________________________________________________________________________________________
# out_feature_1 (Dense)           (None, 4)            260         dense_layer_1[0][0]
# __________________________________________________________________________________________________
# out_feature_2 (Dense)           (None, 5)            325         dense_layer_2[0][0]
# __________________________________________________________________________________________________
# out_feature_3 (Dense)           (None, 3)            195         dense_layer_3[0][0]
# __________________________________________________________________________________________________
# out_feature_4 (Dense)           (None, 5)            325         dense_layer_4[0][0]
# __________________________________________________________________________________________________
# out_feature_5 (Dense)           (None, 4)            260         dense_layer_5[0][0]
# __________________________________________________________________________________________________
# out_feature_6 (Dense)           (None, 4)            260         dense_layer_6[0][0]
# __________________________________________________________________________________________________
# out_feature_7 (Dense)           (None, 4)            260         dense_layer_7[0][0]
# __________________________________________________________________________________________________
# out_feature_8 (Dense)           (None, 5)            325         dense_layer_8[0][0]
# ==================================================================================================
# Total params: 11,021,474
# Trainable params: 11,021,474
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import model_to_dot
from IPython.display import SVG

SVG(model_to_dot(model, show_layer_names=True, show_shapes=True).create(prog='dot', format='svg'))

# %%
losses = {}
lossWeights = {}
for i in range(1,9):
    losses["out_feature_"+str(i)] = "categorical_crossentropy"
    lossWeights["out_feature_"+str(i)] = 1.0
losses['recon'] = 'mse'
lossWeights['recon'] = 1.0

# %%
INIT_LR = 0.001
# opt = optimizers.SGD(lr=INIT_LR, decay=1e-6, momentum=0.95, nesterov=True)
# opt = optimizers.Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
opt = optimizers.Adadelta(lr=INIT_LR, decay=1e-04)
model.compile(optimizer=opt
                  ,loss=losses
                  ,loss_weights=lossWeights
                  ,metrics=['accuracy'])

# %%
def datagen(batch_size,list_of_writers):
    counter = 0
    
    
    while counter <= batch_size:
        counter = 0
        # for writer in unique_writers:
        #     print(identitycounter*100/stop_at, end='\r')
        writer_indexes = np.random.randint(0,len(list_of_writers),batch_size)
        x,f_1_out,f_2_out,f_3_out,f_4_out,f_5_out,f_6_out,f_7_out,f_8_out = [],[],[],[],[],[],[],[],[]
        for writer_index in writer_indexes:
#             class_vectors = []
            writer = list_of_writers[writer_index]
#             print(writer)
            writer_samples = list(images[images['image'].str.match(writer)]['image'])
#             print('writer:',writer,', writer_samples:',writer_samples)
            if len(writer_samples) == 0:
                continue
            writer_sample_index = np.random.randint(0,len(writer_samples))

            #     unique_writers_count[writer] = len(writer_samples)
#             print('writer_sample_index:',writer_sample_index)
            csv_writer = writer_samples[writer_sample_index][:5]

    
            loaded_image = cv2.imread(os.path.join(image_path,writer_samples[writer_sample_index]),0)
            loaded_image = np.expand_dims(loaded_image,-1)
#             print('csv_writer:', csv_writer, ', writer:', writer)
#             display(csv_data[csv_data['ImageId'].str.match(csv_writer)])
            csv_discreete_features = csv_data[csv_data['ImageId'].str.match(csv_writer)].iloc[0].values[2:]
#             print(csv_writer, writer_samples[writer_sample_index])
#             print(csv_writer,csv_discreete_features)
#             for i in range(1,9):
#                 print(csv_discreete_features[i-1],end=',')
            f_1_out.append(csv_discreete_features[0])
            f_2_out.append(csv_discreete_features[1])
            f_3_out.append(csv_discreete_features[2])
            f_4_out.append(csv_discreete_features[3])
            f_5_out.append(csv_discreete_features[4])
            f_6_out.append(csv_discreete_features[5])
            f_7_out.append(csv_discreete_features[6])
            f_8_out.append(csv_discreete_features[7])
#                 class_vectors.append(to_categorical(csv_discreete_features[i-1],num_classes=feature_lengths['f'+str(i)]))
#             print("\n",len(class_vectors))
#             print('\n-----------')
            
#             print("++++++++++++++++++++++[",counter,"]+++++++++++++++++++++++")
        #     imgcounter = 0
        #     for sample in writer_samples:
        #         imagepath = os.path.join(image_path,sample)
        #         raw_img = cv2.imread(imagepath)
        #         imgcounter+=1
        #     imgcounter=0
        #     identitycounter += 1
            x.append(255.0-loaded_image)
            
            
            counter+=1
#             print('counter:', counter, end='\r')
        yield np.array(x)/255.0, [np.array(x)/255.0 \
                                  ,to_categorical(f_1_out,num_classes=feature_lengths['f1']) \
                            , to_categorical(f_2_out,num_classes=feature_lengths['f2']) \
                            , to_categorical(f_3_out,num_classes=feature_lengths['f3']) \
                            , to_categorical(f_4_out,num_classes=feature_lengths['f4']) \
                            , to_categorical(f_5_out,num_classes=feature_lengths['f5']) \
                            , to_categorical(f_6_out,num_classes=feature_lengths['f6']) \
                            , to_categorical(f_7_out,num_classes=feature_lengths['f7']) \
                            , to_categorical(f_8_out,num_classes=feature_lengths['f8'])]

# %%
# # unique_writers_count
# f_count = {}
train_list_of_writers = train_csv_data['ImageId'].unique()
val_list_of_writers = val_csv_data['ImageId'].unique()
batch_size = 64

tg = datagen(batch_size,train_list_of_writers)
vg = datagen(batch_size,val_list_of_writers)

# %%
inputs,o = next(tg)
inputs.shape, o[0].shape, o[1].shape,o[2].shape,o[3].shape,o[4].shape,o[5].shape,o[6].shape,o[7].shape, o[8].shape
# Out:
# ((64, 64, 64, 1),
#  (64, 64, 64, 1),
#  (64, 4),
#  (64, 5),
#  (64, 3),
#  (64, 5),
#  (64, 4),
#  (64, 4),
#  (64, 4),
#  (64, 5))

# %%
EPOCHS = 10000

datetime = str(datetime.datetime.now())
LOG_DIR = 'training/unseen_speakers/logs/'
run_name = datetime.replace(' ','_').replace('.','_')
print('run_name:',run_name)
tb = callbacks.TensorBoard(log_dir=os.path.join(LOG_DIR, run_name),batch_size=16)
mc = callbacks.ModelCheckpoint(filepath='human_features_capsulenets_weights_v1.h5', monitor='val_loss',period=1,save_best_only=True,save_weights_only=True,mode='auto',verbose=3)
es = callbacks.EarlyStopping(patience=1000, monitor='val_loss', min_delta=0.0005, mode='auto')
hist = model.fit_generator(generator=tg
                    ,validation_data=vg
                    ,epochs=EPOCHS
                    , steps_per_epoch=1
                    , validation_steps=1
                    , verbose = 3
                    , callbacks=[tb,mc,es])
# Out:
# run_name: 2019-03-10_19:15:26_770450
# Epoch 1/5000
#
# Epoch 00001: val_loss improved from inf to 11.70978, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 2/5000
#
# Epoch 00002: val_loss did not improve from 11.70978
# Epoch 3/5000
#
# Epoch 00003: val_loss did not improve from 11.70978
# Epoch 4/5000
#
# Epoch 00004: val_loss did not improve from 11.70978
# Epoch 5/5000
#
# Epoch 00005: val_loss did not improve from 11.70978
# Epoch 6/5000
#
# Epoch 00006: val_loss did not improve from 11.70978
# Epoch 7/5000
#
# Epoch 00007: val_loss did not improve from 11.70978
# Epoch 8/5000
#
# Epoch 00008: val_loss did not improve from 11.70978
# Epoch 9/5000
#
# Epoch 00009: val_loss did not improve from 11.70978
# Epoch 10/5000
#
# Epoch 00010: val_loss improved from 11.70978 to 11.70977, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 11/5000
#
# Epoch 00011: val_loss improved from 11.70977 to 11.70951, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 12/5000
#
# Epoch 00012: val_loss did not improve from 11.70951
# Epoch 13/5000
#
# Epoch 00013: val_loss did not improve from 11.70951
# Epoch 14/5000
#
# Epoch 00014: val_loss did not improve from 11.70951
# Epoch 15/5000
#
# Epoch 00015: val_loss did not improve from 11.70951
# Epoch 16/5000
#
# Epoch 00016: val_loss did not improve from 11.70951
# Epoch 17/5000
#
# Epoch 00017: val_loss improved from 11.70951 to 11.70919, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 18/5000
#
# Epoch 00018: val_loss did not improve from 11.70919
# Epoch 19/5000
#
# Epoch 00019: val_loss did not improve from 11.70919
# Epoch 20/5000
#
# Epoch 00020: val_loss did not improve from 11.70919
# Epoch 21/5000
#
# Epoch 00021: val_loss did not improve from 11.70919
# Epoch 22/5000
#
# Epoch 00022: val_loss did not improve from 11.70919
# Epoch 23/5000
#
# Epoch 00023: val_loss did not improve from 11.70919
# Epoch 24/5000
#
# Epoch 00024: val_loss did not improve from 11.70919
# Epoch 25/5000
#
# Epoch 00025: val_loss did not improve from 11.70919
# Epoch 26/5000
#
# Epoch 00026: val_loss did not improve from 11.70919
# Epoch 27/5000
#
# Epoch 00027: val_loss did not improve from 11.70919
# Epoch 28/5000
#
# Epoch 00028: val_loss did not improve from 11.70919
# Epoch 29/5000
#
# Epoch 00029: val_loss did not improve from 11.70919
# Epoch 30/5000
#
# Epoch 00030: val_loss did not improve from 11.70919
# Epoch 31/5000
#
# Epoch 00031: val_loss did not improve from 11.70919
# Epoch 32/5000
#
# Epoch 00032: val_loss did not improve from 11.70919
# Epoch 33/5000
#
# Epoch 00033: val_loss did not improve from 11.70919
# Epoch 34/5000
#
# Epoch 00034: val_loss did not improve from 11.70919
# Epoch 35/5000
#
# Epoch 00035: val_loss did not improve from 11.70919
# Epoch 36/5000
#
# Epoch 00036: val_loss did not improve from 11.70919
# Epoch 37/5000
#
# Epoch 00037: val_loss did not improve from 11.70919
# Epoch 38/5000
#
# Epoch 00038: val_loss did not improve from 11.70919
# Epoch 39/5000
#
# Epoch 00039: val_loss did not improve from 11.70919
# Epoch 40/5000
#
# Epoch 00040: val_loss did not improve from 11.70919
# Epoch 41/5000
#
# Epoch 00041: val_loss did not improve from 11.70919
# Epoch 42/5000
#
# Epoch 00042: val_loss did not improve from 11.70919
# Epoch 43/5000
#
# Epoch 00043: val_loss did not improve from 11.70919
# Epoch 44/5000
#
# Epoch 00044: val_loss did not improve from 11.70919
# Epoch 45/5000
#
# Epoch 00045: val_loss did not improve from 11.70919
# Epoch 46/5000
#
# Epoch 00046: val_loss did not improve from 11.70919
# Epoch 47/5000
#
# Epoch 00047: val_loss did not improve from 11.70919
# Epoch 48/5000
#
# Epoch 00048: val_loss did not improve from 11.70919
# Epoch 49/5000
#
# Epoch 00049: val_loss improved from 11.70919 to 11.70877, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 50/5000
#
# Epoch 00050: val_loss did not improve from 11.70877
# Epoch 51/5000
#
# Epoch 00051: val_loss improved from 11.70877 to 11.70871, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 52/5000
#
# Epoch 00052: val_loss did not improve from 11.70871
# Epoch 53/5000
#
# Epoch 00053: val_loss did not improve from 11.70871
# Epoch 54/5000
#
# Epoch 00054: val_loss did not improve from 11.70871
# Epoch 55/5000
#
# Epoch 00055: val_loss did not improve from 11.70871
# Epoch 56/5000
#
# Epoch 00056: val_loss did not improve from 11.70871
# Epoch 57/5000
#
# Epoch 00057: val_loss did not improve from 11.70871
# Epoch 58/5000
#
# Epoch 00058: val_loss did not improve from 11.70871
# Epoch 59/5000
#
# Epoch 00059: val_loss did not improve from 11.70871
# Epoch 60/5000
#
# Epoch 00060: val_loss did not improve from 11.70871
# Epoch 61/5000
#
# Epoch 00061: val_loss did not improve from 11.70871
# Epoch 62/5000
#
# Epoch 00062: val_loss improved from 11.70871 to 11.70852, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 63/5000
#
# Epoch 00063: val_loss did not improve from 11.70852
# Epoch 64/5000
#
# Epoch 00064: val_loss did not improve from 11.70852
# Epoch 65/5000
#
# Epoch 00065: val_loss did not improve from 11.70852
# Epoch 66/5000
#
# Epoch 00066: val_loss did not improve from 11.70852
# Epoch 67/5000
#
# Epoch 00067: val_loss did not improve from 11.70852
# Epoch 68/5000
#
# Epoch 00068: val_loss did not improve from 11.70852
# Epoch 69/5000
#
# Epoch 00069: val_loss did not improve from 11.70852
# Epoch 70/5000
#
# Epoch 00070: val_loss did not improve from 11.70852
# Epoch 71/5000
#
# Epoch 00071: val_loss did not improve from 11.70852
# Epoch 72/5000
#
# Epoch 00072: val_loss improved from 11.70852 to 11.70844, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 73/5000
#
# Epoch 00073: val_loss did not improve from 11.70844
# Epoch 74/5000
#
# Epoch 00074: val_loss did not improve from 11.70844
# Epoch 75/5000
#
# Epoch 00075: val_loss did not improve from 11.70844
# Epoch 76/5000
#
# Epoch 00076: val_loss did not improve from 11.70844
# Epoch 77/5000
#
# Epoch 00077: val_loss did not improve from 11.70844
# Epoch 78/5000
#
# Epoch 00078: val_loss did not improve from 11.70844
# Epoch 79/5000
#
# Epoch 00079: val_loss did not improve from 11.70844
# Epoch 80/5000
#
# Epoch 00080: val_loss did not improve from 11.70844
# Epoch 81/5000
#
# Epoch 00081: val_loss did not improve from 11.70844
# Epoch 82/5000
#
# Epoch 00082: val_loss did not improve from 11.70844
# Epoch 83/5000
#
# Epoch 00083: val_loss did not improve from 11.70844
# Epoch 84/5000
#
# Epoch 00084: val_loss did not improve from 11.70844
# Epoch 85/5000
#
# Epoch 00085: val_loss did not improve from 11.70844
# Epoch 86/5000
#
# Epoch 00086: val_loss did not improve from 11.70844
# Epoch 87/5000
#
# Epoch 00087: val_loss did not improve from 11.70844
# Epoch 88/5000
#
# Epoch 00088: val_loss did not improve from 11.70844
# Epoch 89/5000
#
# Epoch 00089: val_loss improved from 11.70844 to 11.70836, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 90/5000
#
# Epoch 00090: val_loss did not improve from 11.70836
# Epoch 91/5000
#
# Epoch 00091: val_loss improved from 11.70836 to 11.70826, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 92/5000
#
# Epoch 00092: val_loss did not improve from 11.70826
# Epoch 93/5000
#
# Epoch 00093: val_loss did not improve from 11.70826
# Epoch 94/5000
#
# Epoch 00094: val_loss did not improve from 11.70826
# Epoch 95/5000
#
# Epoch 00095: val_loss did not improve from 11.70826
# Epoch 96/5000
#
# Epoch 00096: val_loss improved from 11.70826 to 11.70800, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 97/5000
#
# Epoch 00097: val_loss improved from 11.70800 to 11.70774, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 98/5000
#
# Epoch 00098: val_loss did not improve from 11.70774
# Epoch 99/5000
#
# Epoch 00099: val_loss improved from 11.70774 to 11.70771, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 100/5000
#
# Epoch 00100: val_loss did not improve from 11.70771
# Epoch 101/5000
#
# Epoch 00101: val_loss did not improve from 11.70771
# Epoch 102/5000
#
# Epoch 00102: val_loss did not improve from 11.70771
# Epoch 103/5000
#
# Epoch 00103: val_loss did not improve from 11.70771
# Epoch 104/5000
#
# Epoch 00104: val_loss did not improve from 11.70771
# Epoch 105/5000
#
# Epoch 00105: val_loss did not improve from 11.70771
# Epoch 106/5000
#
# Epoch 00106: val_loss improved from 11.70771 to 11.70767, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 107/5000
#
# Epoch 00107: val_loss did not improve from 11.70767
# Epoch 108/5000
#
# Epoch 00108: val_loss did not improve from 11.70767
# Epoch 109/5000
#
# Epoch 00109: val_loss did not improve from 11.70767
# Epoch 110/5000
# Epoch 00110: val_loss did not improve from 11.70767
# Epoch 111/5000
#
# Epoch 00111: val_loss did not improve from 11.70767
# Epoch 112/5000
#
# Epoch 00112: val_loss did not improve from 11.70767
# Epoch 113/5000
#
# Epoch 00113: val_loss did not improve from 11.70767
# Epoch 114/5000
#
# Epoch 00114: val_loss did not improve from 11.70767
# Epoch 115/5000
#
# Epoch 00115: val_loss did not improve from 11.70767
# Epoch 116/5000
#
# Epoch 00116: val_loss did not improve from 11.70767
# Epoch 117/5000
#
# Epoch 00117: val_loss did not improve from 11.70767
# Epoch 118/5000
#
# Epoch 00118: val_loss did not improve from 11.70767
# Epoch 119/5000
#
# Epoch 00119: val_loss did not improve from 11.70767
# Epoch 120/5000
#
# Epoch 00120: val_loss did not improve from 11.70767
# Epoch 121/5000
#
# Epoch 00121: val_loss did not improve from 11.70767
# Epoch 122/5000
#
# Epoch 00122: val_loss did not improve from 11.70767
# Epoch 123/5000
#
# Epoch 00123: val_loss did not improve from 11.70767
# Epoch 124/5000
#
# Epoch 00124: val_loss did not improve from 11.70767
# Epoch 125/5000
#
# Epoch 00125: val_loss did not improve from 11.70767
# Epoch 126/5000
#
# Epoch 00126: val_loss did not improve from 11.70767
# Epoch 127/5000
#
# Epoch 00127: val_loss did not improve from 11.70767
# Epoch 128/5000
#
# Epoch 00128: val_loss improved from 11.70767 to 11.70733, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 129/5000
#
# Epoch 00129: val_loss did not improve from 11.70733
# Epoch 130/5000
#
# Epoch 00130: val_loss did not improve from 11.70733
# Epoch 131/5000
#
# Epoch 00131: val_loss did not improve from 11.70733
# Epoch 132/5000
#
# Epoch 00132: val_loss did not improve from 11.70733
# Epoch 133/5000
#
# Epoch 00133: val_loss did not improve from 11.70733
# Epoch 134/5000
#
# Epoch 00134: val_loss did not improve from 11.70733
# Epoch 135/5000
#
# Epoch 00135: val_loss did not improve from 11.70733
# Epoch 136/5000
#
# Epoch 00136: val_loss did not improve from 11.70733
# Epoch 137/5000
#
# Epoch 00137: val_loss did not improve from 11.70733
# Epoch 138/5000
#
# Epoch 00138: val_loss did not improve from 11.70733
# Epoch 139/5000
#
# Epoch 00139: val_loss did not improve from 11.70733
# Epoch 140/5000
#
# Epoch 00140: val_loss did not improve from 11.70733
# Epoch 141/5000
#
# Epoch 00141: val_loss did not improve from 11.70733
# Epoch 142/5000
#
# Epoch 00142: val_loss did not improve from 11.70733
# Epoch 143/5000
#
# Epoch 00143: val_loss did not improve from 11.70733
# Epoch 144/5000
#
# Epoch 00144: val_loss did not improve from 11.70733
# Epoch 145/5000
#
# Epoch 00145: val_loss did not improve from 11.70733
# Epoch 146/5000
#
# Epoch 00146: val_loss did not improve from 11.70733
# Epoch 147/5000
#
# Epoch 00147: val_loss did not improve from 11.70733
# Epoch 148/5000
#
# Epoch 00148: val_loss did not improve from 11.70733
# Epoch 149/5000
#
# Epoch 00149: val_loss did not improve from 11.70733
# Epoch 150/5000
#
# Epoch 00150: val_loss did not improve from 11.70733
# Epoch 151/5000
#
# Epoch 00151: val_loss did not improve from 11.70733
# Epoch 152/5000
#
# Epoch 00152: val_loss did not improve from 11.70733
# Epoch 153/5000
#
# Epoch 00153: val_loss did not improve from 11.70733
# Epoch 154/5000
#
# Epoch 00154: val_loss did not improve from 11.70733
# Epoch 155/5000
#
# Epoch 00155: val_loss did not improve from 11.70733
# Epoch 156/5000
#
# Epoch 00156: val_loss did not improve from 11.70733
# Epoch 157/5000
#
# Epoch 00157: val_loss improved from 11.70733 to 11.70725, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 158/5000
#
# Epoch 00158: val_loss did not improve from 11.70725
# Epoch 159/5000
#
# Epoch 00159: val_loss improved from 11.70725 to 11.70705, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 160/5000
#
# Epoch 00160: val_loss did not improve from 11.70705
# Epoch 161/5000
#
# Epoch 00161: val_loss did not improve from 11.70705
# Epoch 162/5000
#
# Epoch 00162: val_loss did not improve from 11.70705
# Epoch 163/5000
#
# Epoch 00163: val_loss did not improve from 11.70705
# Epoch 164/5000
#
# Epoch 00164: val_loss did not improve from 11.70705
# Epoch 165/5000
#
# Epoch 00165: val_loss improved from 11.70705 to 11.70611, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 166/5000
#
# Epoch 00166: val_loss did not improve from 11.70611
# Epoch 167/5000
#
# Epoch 00167: val_loss did not improve from 11.70611
# Epoch 168/5000
#
# Epoch 00168: val_loss did not improve from 11.70611
# Epoch 169/5000
#
# Epoch 00169: val_loss did not improve from 11.70611
# Epoch 170/5000
#
# Epoch 00170: val_loss did not improve from 11.70611
# Epoch 171/5000
#
# Epoch 00171: val_loss did not improve from 11.70611
# Epoch 172/5000
#
# Epoch 00172: val_loss did not improve from 11.70611
# Epoch 173/5000
#
# Epoch 00173: val_loss did not improve from 11.70611
# Epoch 174/5000
#
# Epoch 00174: val_loss did not improve from 11.70611
# Epoch 175/5000
#
# Epoch 00175: val_loss did not improve from 11.70611
# Epoch 176/5000
#
# Epoch 00176: val_loss did not improve from 11.70611
# Epoch 177/5000
#
# Epoch 00177: val_loss did not improve from 11.70611
# Epoch 178/5000
#
# Epoch 00178: val_loss did not improve from 11.70611
# Epoch 179/5000
#
# Epoch 00179: val_loss did not improve from 11.70611
# Epoch 180/5000
#
# Epoch 00180: val_loss did not improve from 11.70611
# Epoch 181/5000
#
# Epoch 00181: val_loss did not improve from 11.70611
# Epoch 182/5000
#
# Epoch 00182: val_loss did not improve from 11.70611
# Epoch 183/5000
#
# Epoch 00183: val_loss did not improve from 11.70611
# Epoch 184/5000
#
# Epoch 00184: val_loss did not improve from 11.70611
# Epoch 185/5000
#
# Epoch 00185: val_loss did not improve from 11.70611
# Epoch 186/5000
#
# Epoch 00186: val_loss did not improve from 11.70611
# Epoch 187/5000
#
# Epoch 00187: val_loss did not improve from 11.70611
# Epoch 188/5000
#
# Epoch 00188: val_loss did not improve from 11.70611
# Epoch 189/5000
#
# Epoch 00189: val_loss did not improve from 11.70611
# Epoch 190/5000
#
# Epoch 00190: val_loss improved from 11.70611 to 11.70588, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 191/5000
#
# Epoch 00191: val_loss did not improve from 11.70588
# Epoch 192/5000
#
# Epoch 00192: val_loss did not improve from 11.70588
# Epoch 193/5000
#
# Epoch 00193: val_loss did not improve from 11.70588
# Epoch 194/5000
#
# Epoch 00194: val_loss did not improve from 11.70588
# Epoch 195/5000
#
# Epoch 00195: val_loss did not improve from 11.70588
# Epoch 196/5000
#
# Epoch 00196: val_loss did not improve from 11.70588
# Epoch 197/5000
#
# Epoch 00197: val_loss did not improve from 11.70588
# Epoch 198/5000
#
# Epoch 00198: val_loss did not improve from 11.70588
# Epoch 199/5000
#
# Epoch 00199: val_loss did not improve from 11.70588
# Epoch 200/5000
#
# Epoch 00200: val_loss did not improve from 11.70588
# Epoch 201/5000
#
# Epoch 00201: val_loss did not improve from 11.70588
# Epoch 202/5000
#
# Epoch 00202: val_loss did not improve from 11.70588
# Epoch 203/5000
#
# Epoch 00203: val_loss did not improve from 11.70588
# Epoch 204/5000
#
# Epoch 00204: val_loss did not improve from 11.70588
# Epoch 205/5000
#
# Epoch 00205: val_loss did not improve from 11.70588
# Epoch 206/5000
#
# Epoch 00206: val_loss did not improve from 11.70588
# Epoch 207/5000
#
# Epoch 00207: val_loss did not improve from 11.70588
# Epoch 208/5000
#
# Epoch 00208: val_loss did not improve from 11.70588
# Epoch 209/5000
#
# Epoch 00209: val_loss did not improve from 11.70588
# Epoch 210/5000
#
# Epoch 00210: val_loss did not improve from 11.70588
# Epoch 211/5000
#
# Epoch 00211: val_loss did not improve from 11.70588
# Epoch 212/5000
#
# Epoch 00212: val_loss did not improve from 11.70588
# Epoch 213/5000
#
# Epoch 00213: val_loss did not improve from 11.70588
# Epoch 214/5000
#
# Epoch 00214: val_loss did not improve from 11.70588
# Epoch 215/5000
#
# Epoch 00215: val_loss did not improve from 11.70588
# Epoch 216/5000
#
# Epoch 00216: val_loss did not improve from 11.70588
# Epoch 217/5000
#
# Epoch 00217: val_loss did not improve from 11.70588
# Epoch 218/5000
#
# Epoch 00218: val_loss did not improve from 11.70588
# Epoch 219/5000
#
# Epoch 00219: val_loss did not improve from 11.70588
# Epoch 220/5000
#
# Epoch 00220: val_loss did not improve from 11.70588
# Epoch 221/5000
#
# Epoch 00221: val_loss did not improve from 11.70588
# Epoch 222/5000
#
# Epoch 00222: val_loss did not improve from 11.70588
# Epoch 223/5000
#
# Epoch 00223: val_loss did not improve from 11.70588
# Epoch 224/5000
#
# Epoch 00224: val_loss did not improve from 11.70588
# Epoch 225/5000
#
# Epoch 00225: val_loss did not improve from 11.70588
# Epoch 226/5000
# Epoch 00226: val_loss did not improve from 11.70588
# Epoch 227/5000
#
# Epoch 00227: val_loss did not improve from 11.70588
# Epoch 228/5000
#
# Epoch 00228: val_loss did not improve from 11.70588
# Epoch 229/5000
#
# Epoch 00229: val_loss did not improve from 11.70588
# Epoch 230/5000
#
# Epoch 00230: val_loss did not improve from 11.70588
# Epoch 231/5000
#
# Epoch 00231: val_loss improved from 11.70588 to 11.70571, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 232/5000
#
# Epoch 00232: val_loss did not improve from 11.70571
# Epoch 233/5000
#
# Epoch 00233: val_loss did not improve from 11.70571
# Epoch 234/5000
#
# Epoch 00234: val_loss did not improve from 11.70571
# Epoch 235/5000
#
# Epoch 00235: val_loss did not improve from 11.70571
# Epoch 236/5000
#
# Epoch 00236: val_loss did not improve from 11.70571
# Epoch 237/5000
#
# Epoch 00237: val_loss did not improve from 11.70571
# Epoch 238/5000
#
# Epoch 00238: val_loss did not improve from 11.70571
# Epoch 239/5000
#
# Epoch 00239: val_loss did not improve from 11.70571
# Epoch 240/5000
#
# Epoch 00240: val_loss did not improve from 11.70571
# Epoch 241/5000
#
# Epoch 00241: val_loss did not improve from 11.70571
# Epoch 242/5000
#
# Epoch 00242: val_loss did not improve from 11.70571
# Epoch 243/5000
#
# Epoch 00243: val_loss did not improve from 11.70571
# Epoch 244/5000
#
# Epoch 00244: val_loss improved from 11.70571 to 11.70549, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 245/5000
#
# Epoch 00245: val_loss did not improve from 11.70549
# Epoch 246/5000
#
# Epoch 00246: val_loss did not improve from 11.70549
# Epoch 247/5000
#
# Epoch 00247: val_loss did not improve from 11.70549
# Epoch 248/5000
#
# Epoch 00248: val_loss did not improve from 11.70549
# Epoch 249/5000
#
# Epoch 00249: val_loss did not improve from 11.70549
# Epoch 250/5000
#
# Epoch 00250: val_loss did not improve from 11.70549
# Epoch 251/5000
#
# Epoch 00251: val_loss did not improve from 11.70549
# Epoch 252/5000
#
# Epoch 00252: val_loss did not improve from 11.70549
# Epoch 253/5000
#
# Epoch 00253: val_loss did not improve from 11.70549
# Epoch 254/5000
#
# Epoch 00254: val_loss improved from 11.70549 to 11.70435, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 255/5000
#
# Epoch 00255: val_loss did not improve from 11.70435
# Epoch 256/5000
#
# Epoch 00256: val_loss did not improve from 11.70435
# Epoch 257/5000
#
# Epoch 00257: val_loss did not improve from 11.70435
# Epoch 258/5000
#
# Epoch 00258: val_loss did not improve from 11.70435
# Epoch 259/5000
#
# Epoch 00259: val_loss did not improve from 11.70435
# Epoch 260/5000
#
# Epoch 00260: val_loss did not improve from 11.70435
# Epoch 261/5000
#
# Epoch 00261: val_loss did not improve from 11.70435
# Epoch 262/5000
#
# Epoch 00262: val_loss did not improve from 11.70435
# Epoch 263/5000
#
# Epoch 00263: val_loss did not improve from 11.70435
# Epoch 264/5000
#
# Epoch 00264: val_loss did not improve from 11.70435
# Epoch 265/5000
#
# Epoch 00265: val_loss did not improve from 11.70435
# Epoch 266/5000
#
# Epoch 00266: val_loss did not improve from 11.70435
# Epoch 267/5000
#
# Epoch 00267: val_loss did not improve from 11.70435
# Epoch 268/5000
#
# Epoch 00268: val_loss did not improve from 11.70435
# Epoch 269/5000
#
# Epoch 00269: val_loss did not improve from 11.70435
# Epoch 270/5000
#
# Epoch 00270: val_loss did not improve from 11.70435
# Epoch 271/5000
#
# Epoch 00271: val_loss did not improve from 11.70435
# Epoch 272/5000
#
# Epoch 00272: val_loss did not improve from 11.70435
# Epoch 273/5000
#
# Epoch 00273: val_loss did not improve from 11.70435
# Epoch 274/5000
#
# Epoch 00274: val_loss did not improve from 11.70435
# Epoch 275/5000
#
# Epoch 00275: val_loss did not improve from 11.70435
# Epoch 276/5000
#
# Epoch 00276: val_loss did not improve from 11.70435
# Epoch 277/5000
#
# Epoch 00277: val_loss did not improve from 11.70435
# Epoch 278/5000
#
# Epoch 00278: val_loss did not improve from 11.70435
# Epoch 279/5000
#
# Epoch 00279: val_loss did not improve from 11.70435
# Epoch 280/5000
#
# Epoch 00280: val_loss did not improve from 11.70435
# Epoch 281/5000
#
# Epoch 00281: val_loss did not improve from 11.70435
# Epoch 282/5000
#
# Epoch 00282: val_loss did not improve from 11.70435
# Epoch 283/5000
#
# Epoch 00283: val_loss did not improve from 11.70435
# Epoch 284/5000
#
# Epoch 00284: val_loss did not improve from 11.70435
# Epoch 285/5000
#
# Epoch 00285: val_loss did not improve from 11.70435
# Epoch 286/5000
#
# Epoch 00286: val_loss did not improve from 11.70435
# Epoch 287/5000
#
# Epoch 00287: val_loss did not improve from 11.70435
# Epoch 288/5000
#
# Epoch 00288: val_loss did not improve from 11.70435
# Epoch 289/5000
#
# Epoch 00289: val_loss did not improve from 11.70435
# Epoch 290/5000
#
# Epoch 00290: val_loss did not improve from 11.70435
# Epoch 291/5000
#
# Epoch 00291: val_loss did not improve from 11.70435
# Epoch 292/5000
#
# Epoch 00292: val_loss did not improve from 11.70435
# Epoch 293/5000
#
# Epoch 00293: val_loss improved from 11.70435 to 11.70421, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 294/5000
#
# Epoch 00294: val_loss did not improve from 11.70421
# Epoch 295/5000
#
# Epoch 00295: val_loss did not improve from 11.70421
# Epoch 296/5000
#
# Epoch 00296: val_loss did not improve from 11.70421
# Epoch 297/5000
#
# Epoch 00297: val_loss did not improve from 11.70421
# Epoch 298/5000
#
# Epoch 00298: val_loss did not improve from 11.70421
# Epoch 299/5000
#
# Epoch 00299: val_loss did not improve from 11.70421
# Epoch 300/5000
#
# Epoch 00300: val_loss did not improve from 11.70421
# Epoch 301/5000
#
# Epoch 00301: val_loss did not improve from 11.70421
# Epoch 302/5000
#
# Epoch 00302: val_loss did not improve from 11.70421
# Epoch 303/5000
#
# Epoch 00303: val_loss did not improve from 11.70421
# Epoch 304/5000
#
# Epoch 00304: val_loss did not improve from 11.70421
# Epoch 305/5000
#
# Epoch 00305: val_loss did not improve from 11.70421
# Epoch 306/5000
#
# Epoch 00306: val_loss did not improve from 11.70421
# Epoch 307/5000
#
# Epoch 00307: val_loss did not improve from 11.70421
# Epoch 308/5000
#
# Epoch 00308: val_loss did not improve from 11.70421
# Epoch 309/5000
#
# Epoch 00309: val_loss did not improve from 11.70421
# Epoch 310/5000
#
# Epoch 00310: val_loss did not improve from 11.70421
# Epoch 311/5000
#
# Epoch 00311: val_loss did not improve from 11.70421
# Epoch 312/5000
#
# Epoch 00312: val_loss did not improve from 11.70421
# Epoch 313/5000
#
# Epoch 00313: val_loss did not improve from 11.70421
# Epoch 314/5000
#
# Epoch 00314: val_loss improved from 11.70421 to 11.70359, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 315/5000
#
# Epoch 00315: val_loss did not improve from 11.70359
# Epoch 316/5000
#
# Epoch 00316: val_loss did not improve from 11.70359
# Epoch 317/5000
#
# Epoch 00317: val_loss did not improve from 11.70359
# Epoch 318/5000
#
# Epoch 00318: val_loss did not improve from 11.70359
# Epoch 319/5000
#
# Epoch 00319: val_loss did not improve from 11.70359
# Epoch 320/5000
#
# Epoch 00320: val_loss did not improve from 11.70359
# Epoch 321/5000
#
# Epoch 00321: val_loss did not improve from 11.70359
# Epoch 322/5000
#
# Epoch 00322: val_loss did not improve from 11.70359
# Epoch 323/5000
#
# Epoch 00323: val_loss did not improve from 11.70359
# Epoch 324/5000
#
# Epoch 00324: val_loss did not improve from 11.70359
# Epoch 325/5000
#
# Epoch 00325: val_loss did not improve from 11.70359
# Epoch 326/5000
#
# Epoch 00326: val_loss did not improve from 11.70359
# Epoch 327/5000
#
# Epoch 00327: val_loss did not improve from 11.70359
# Epoch 328/5000
#
# Epoch 00328: val_loss did not improve from 11.70359
# Epoch 329/5000
#
# Epoch 00329: val_loss did not improve from 11.70359
# Epoch 330/5000
#
# Epoch 00330: val_loss did not improve from 11.70359
# Epoch 331/5000
#
# Epoch 00331: val_loss did not improve from 11.70359
# Epoch 332/5000
#
# Epoch 00332: val_loss did not improve from 11.70359
# Epoch 333/5000
#
# Epoch 00333: val_loss did not improve from 11.70359
# Epoch 334/5000
#
# Epoch 00334: val_loss did not improve from 11.70359
# Epoch 335/5000
#
# Epoch 00335: val_loss did not improve from 11.70359
# Epoch 336/5000
#
# Epoch 00336: val_loss did not improve from 11.70359
# Epoch 337/5000
#
# Epoch 00337: val_loss did not improve from 11.70359
# Epoch 338/5000
#
# Epoch 00338: val_loss did not improve from 11.70359
# Epoch 339/5000
#
# Epoch 00339: val_loss did not improve from 11.70359
# Epoch 340/5000
#
# Epoch 00340: val_loss did not improve from 11.70359
# Epoch 341/5000
#
# Epoch 00341: val_loss did not improve from 11.70359
# Epoch 342/5000
# Epoch 00342: val_loss did not improve from 11.70359
# Epoch 343/5000
#
# Epoch 00343: val_loss improved from 11.70359 to 11.70358, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 344/5000
#
# Epoch 00344: val_loss did not improve from 11.70358
# Epoch 345/5000
#
# Epoch 00345: val_loss did not improve from 11.70358
# Epoch 346/5000
#
# Epoch 00346: val_loss did not improve from 11.70358
# Epoch 347/5000
#
# Epoch 00347: val_loss did not improve from 11.70358
# Epoch 348/5000
#
# Epoch 00348: val_loss did not improve from 11.70358
# Epoch 349/5000
#
# Epoch 00349: val_loss did not improve from 11.70358
# Epoch 350/5000
#
# Epoch 00350: val_loss did not improve from 11.70358
# Epoch 351/5000
#
# Epoch 00351: val_loss did not improve from 11.70358
# Epoch 352/5000
#
# Epoch 00352: val_loss improved from 11.70358 to 11.70309, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 353/5000
#
# Epoch 00353: val_loss did not improve from 11.70309
# Epoch 354/5000
#
# Epoch 00354: val_loss did not improve from 11.70309
# Epoch 355/5000
#
# Epoch 00355: val_loss did not improve from 11.70309
# Epoch 356/5000
#
# Epoch 00356: val_loss did not improve from 11.70309
# Epoch 357/5000
#
# Epoch 00357: val_loss did not improve from 11.70309
# Epoch 358/5000
#
# Epoch 00358: val_loss did not improve from 11.70309
# Epoch 359/5000
#
# Epoch 00359: val_loss did not improve from 11.70309
# Epoch 360/5000
#
# Epoch 00360: val_loss did not improve from 11.70309
# Epoch 361/5000
#
# Epoch 00361: val_loss did not improve from 11.70309
# Epoch 362/5000
#
# Epoch 00362: val_loss did not improve from 11.70309
# Epoch 363/5000
#
# Epoch 00363: val_loss did not improve from 11.70309
# Epoch 364/5000
#
# Epoch 00364: val_loss did not improve from 11.70309
# Epoch 365/5000
#
# Epoch 00365: val_loss did not improve from 11.70309
# Epoch 366/5000
#
# Epoch 00366: val_loss did not improve from 11.70309
# Epoch 367/5000
#
# Epoch 00367: val_loss did not improve from 11.70309
# Epoch 368/5000
#
# Epoch 00368: val_loss did not improve from 11.70309
# Epoch 369/5000
#
# Epoch 00369: val_loss did not improve from 11.70309
# Epoch 370/5000
#
# Epoch 00370: val_loss did not improve from 11.70309
# Epoch 371/5000
#
# Epoch 00371: val_loss did not improve from 11.70309
# Epoch 372/5000
#
# Epoch 00372: val_loss improved from 11.70309 to 11.70295, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 373/5000
#
# Epoch 00373: val_loss did not improve from 11.70295
# Epoch 374/5000
#
# Epoch 00374: val_loss did not improve from 11.70295
# Epoch 375/5000
#
# Epoch 00375: val_loss did not improve from 11.70295
# Epoch 376/5000
#
# Epoch 00376: val_loss did not improve from 11.70295
# Epoch 377/5000
#
# Epoch 00377: val_loss did not improve from 11.70295
# Epoch 378/5000
#
# Epoch 00378: val_loss did not improve from 11.70295
# Epoch 379/5000
#
# Epoch 00379: val_loss did not improve from 11.70295
# Epoch 380/5000
#
# Epoch 00380: val_loss did not improve from 11.70295
# Epoch 381/5000
#
# Epoch 00381: val_loss did not improve from 11.70295
# Epoch 382/5000
#
# Epoch 00382: val_loss did not improve from 11.70295
# Epoch 383/5000
#
# Epoch 00383: val_loss did not improve from 11.70295
# Epoch 384/5000
#
# Epoch 00384: val_loss improved from 11.70295 to 11.70233, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 385/5000
#
# Epoch 00385: val_loss did not improve from 11.70233
# Epoch 386/5000
#
# Epoch 00386: val_loss did not improve from 11.70233
# Epoch 387/5000
#
# Epoch 00387: val_loss did not improve from 11.70233
# Epoch 388/5000
#
# Epoch 00388: val_loss did not improve from 11.70233
# Epoch 389/5000
#
# Epoch 00389: val_loss did not improve from 11.70233
# Epoch 390/5000
#
# Epoch 00390: val_loss did not improve from 11.70233
# Epoch 391/5000
#
# Epoch 00391: val_loss did not improve from 11.70233
# Epoch 392/5000
#
# Epoch 00392: val_loss did not improve from 11.70233
# Epoch 393/5000
#
# Epoch 00393: val_loss did not improve from 11.70233
# Epoch 394/5000
#
# Epoch 00394: val_loss did not improve from 11.70233
# Epoch 395/5000
#
# Epoch 00395: val_loss did not improve from 11.70233
# Epoch 396/5000
#
# Epoch 00396: val_loss did not improve from 11.70233
# Epoch 397/5000
#
# Epoch 00397: val_loss did not improve from 11.70233
# Epoch 398/5000
#
# Epoch 00398: val_loss did not improve from 11.70233
# Epoch 399/5000
#
# Epoch 00399: val_loss did not improve from 11.70233
# Epoch 400/5000
#
# Epoch 00400: val_loss did not improve from 11.70233
# Epoch 401/5000
#
# Epoch 00401: val_loss did not improve from 11.70233
# Epoch 402/5000
#
# Epoch 00402: val_loss improved from 11.70233 to 11.70180, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 403/5000
#
# Epoch 00403: val_loss did not improve from 11.70180
# Epoch 404/5000
#
# Epoch 00404: val_loss did not improve from 11.70180
# Epoch 405/5000
#
# Epoch 00405: val_loss did not improve from 11.70180
# Epoch 406/5000
#
# Epoch 00406: val_loss did not improve from 11.70180
# Epoch 407/5000
#
# Epoch 00407: val_loss did not improve from 11.70180
# Epoch 408/5000
#
# Epoch 00408: val_loss did not improve from 11.70180
# Epoch 409/5000
#
# Epoch 00409: val_loss did not improve from 11.70180
# Epoch 410/5000
#
# Epoch 00410: val_loss did not improve from 11.70180
# Epoch 411/5000
#
# Epoch 00411: val_loss did not improve from 11.70180
# Epoch 412/5000
#
# Epoch 00412: val_loss did not improve from 11.70180
# Epoch 413/5000
#
# Epoch 00413: val_loss did not improve from 11.70180
# Epoch 414/5000
#
# Epoch 00414: val_loss did not improve from 11.70180
# Epoch 415/5000
#
# Epoch 00415: val_loss did not improve from 11.70180
# Epoch 416/5000
#
# Epoch 00416: val_loss did not improve from 11.70180
# Epoch 417/5000
#
# Epoch 00417: val_loss did not improve from 11.70180
# Epoch 418/5000
#
# Epoch 00418: val_loss did not improve from 11.70180
# Epoch 419/5000
#
# Epoch 00419: val_loss did not improve from 11.70180
# Epoch 420/5000
#
# Epoch 00420: val_loss did not improve from 11.70180
# Epoch 421/5000
#
# Epoch 00421: val_loss did not improve from 11.70180
# Epoch 422/5000
#
# Epoch 00422: val_loss did not improve from 11.70180
# Epoch 423/5000
#
# Epoch 00423: val_loss improved from 11.70180 to 11.70166, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 424/5000
#
# Epoch 00424: val_loss did not improve from 11.70166
# Epoch 425/5000
#
# Epoch 00425: val_loss did not improve from 11.70166
# Epoch 426/5000
#
# Epoch 00426: val_loss did not improve from 11.70166
# Epoch 427/5000
#
# Epoch 00427: val_loss did not improve from 11.70166
# Epoch 428/5000
#
# Epoch 00428: val_loss did not improve from 11.70166
# Epoch 429/5000
#
# Epoch 00429: val_loss did not improve from 11.70166
# Epoch 430/5000
#
# Epoch 00430: val_loss did not improve from 11.70166
# Epoch 431/5000
#
# Epoch 00431: val_loss did not improve from 11.70166
# Epoch 432/5000
#
# Epoch 00432: val_loss did not improve from 11.70166
# Epoch 433/5000
#
# Epoch 00433: val_loss did not improve from 11.70166
# Epoch 434/5000
#
# Epoch 00434: val_loss did not improve from 11.70166
# Epoch 435/5000
#
# Epoch 00435: val_loss did not improve from 11.70166
# Epoch 436/5000
#
# Epoch 00436: val_loss did not improve from 11.70166
# Epoch 437/5000
#
# Epoch 00437: val_loss did not improve from 11.70166
# Epoch 438/5000
#
# Epoch 00438: val_loss did not improve from 11.70166
# Epoch 439/5000
#
# Epoch 00439: val_loss did not improve from 11.70166
# Epoch 440/5000
#
# Epoch 00440: val_loss did not improve from 11.70166
# Epoch 441/5000
#
# Epoch 00441: val_loss did not improve from 11.70166
# Epoch 442/5000
#
# Epoch 00442: val_loss did not improve from 11.70166
# Epoch 443/5000
#
# Epoch 00443: val_loss did not improve from 11.70166
# Epoch 444/5000
#
# Epoch 00444: val_loss did not improve from 11.70166
# Epoch 445/5000
#
# Epoch 00445: val_loss did not improve from 11.70166
# Epoch 446/5000
#
# Epoch 00446: val_loss did not improve from 11.70166
# Epoch 447/5000
#
# Epoch 00447: val_loss did not improve from 11.70166
# Epoch 448/5000
#
# Epoch 00448: val_loss did not improve from 11.70166
# Epoch 449/5000
#
# Epoch 00449: val_loss did not improve from 11.70166
# Epoch 450/5000
#
# Epoch 00450: val_loss did not improve from 11.70166
# Epoch 451/5000
#
# Epoch 00451: val_loss did not improve from 11.70166
# Epoch 452/5000
#
# Epoch 00452: val_loss did not improve from 11.70166
# Epoch 453/5000
#
# Epoch 00453: val_loss did not improve from 11.70166
# Epoch 454/5000
#
# Epoch 00454: val_loss did not improve from 11.70166
# Epoch 455/5000
#
# Epoch 00455: val_loss did not improve from 11.70166
# Epoch 456/5000
#
# Epoch 00456: val_loss did not improve from 11.70166
# Epoch 457/5000
# Epoch 00457: val_loss improved from 11.70166 to 11.70104, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 458/5000
#
# Epoch 00458: val_loss did not improve from 11.70104
# Epoch 459/5000
#
# Epoch 00459: val_loss did not improve from 11.70104
# Epoch 460/5000
#
# Epoch 00460: val_loss did not improve from 11.70104
# Epoch 461/5000
#
# Epoch 00461: val_loss did not improve from 11.70104
# Epoch 462/5000
#
# Epoch 00462: val_loss did not improve from 11.70104
# Epoch 463/5000
#
# Epoch 00463: val_loss did not improve from 11.70104
# Epoch 464/5000
#
# Epoch 00464: val_loss improved from 11.70104 to 11.70098, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 465/5000
#
# Epoch 00465: val_loss did not improve from 11.70098
# Epoch 466/5000
#
# Epoch 00466: val_loss did not improve from 11.70098
# Epoch 467/5000
#
# Epoch 00467: val_loss did not improve from 11.70098
# Epoch 468/5000
#
# Epoch 00468: val_loss did not improve from 11.70098
# Epoch 469/5000
#
# Epoch 00469: val_loss did not improve from 11.70098
# Epoch 470/5000
#
# Epoch 00470: val_loss improved from 11.70098 to 11.70086, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 471/5000
#
# Epoch 00471: val_loss did not improve from 11.70086
# Epoch 472/5000
#
# Epoch 00472: val_loss did not improve from 11.70086
# Epoch 473/5000
#
# Epoch 00473: val_loss did not improve from 11.70086
# Epoch 474/5000
#
# Epoch 00474: val_loss did not improve from 11.70086
# Epoch 475/5000
#
# Epoch 00475: val_loss did not improve from 11.70086
# Epoch 476/5000
#
# Epoch 00476: val_loss did not improve from 11.70086
# Epoch 477/5000
#
# Epoch 00477: val_loss did not improve from 11.70086
# Epoch 478/5000
#
# Epoch 00478: val_loss did not improve from 11.70086
# Epoch 479/5000
#
# Epoch 00479: val_loss did not improve from 11.70086
# Epoch 480/5000
#
# Epoch 00480: val_loss did not improve from 11.70086
# Epoch 481/5000
#
# Epoch 00481: val_loss did not improve from 11.70086
# Epoch 482/5000
#
# Epoch 00482: val_loss did not improve from 11.70086
# Epoch 483/5000
#
# Epoch 00483: val_loss did not improve from 11.70086
# Epoch 484/5000
#
# Epoch 00484: val_loss did not improve from 11.70086
# Epoch 485/5000
#
# Epoch 00485: val_loss did not improve from 11.70086
# Epoch 486/5000
#
# Epoch 00486: val_loss did not improve from 11.70086
# Epoch 487/5000
#
# Epoch 00487: val_loss did not improve from 11.70086
# Epoch 488/5000
#
# Epoch 00488: val_loss did not improve from 11.70086
# Epoch 489/5000
#
# Epoch 00489: val_loss did not improve from 11.70086
# Epoch 490/5000
#
# Epoch 00490: val_loss did not improve from 11.70086
# Epoch 491/5000
#
# Epoch 00491: val_loss did not improve from 11.70086
# Epoch 492/5000
#
# Epoch 00492: val_loss improved from 11.70086 to 11.70004, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 493/5000
#
# Epoch 00493: val_loss did not improve from 11.70004
# Epoch 494/5000
#
# Epoch 00494: val_loss did not improve from 11.70004
# Epoch 495/5000
#
# Epoch 00495: val_loss did not improve from 11.70004
# Epoch 496/5000
#
# Epoch 00496: val_loss did not improve from 11.70004
# Epoch 497/5000
#
# Epoch 00497: val_loss did not improve from 11.70004
# Epoch 498/5000
#
# Epoch 00498: val_loss did not improve from 11.70004
# Epoch 499/5000
#
# Epoch 00499: val_loss did not improve from 11.70004
# Epoch 500/5000
#
# Epoch 00500: val_loss did not improve from 11.70004
# Epoch 501/5000
#
# Epoch 00501: val_loss did not improve from 11.70004
# Epoch 502/5000
#
# Epoch 00502: val_loss did not improve from 11.70004
# Epoch 503/5000
#
# Epoch 00503: val_loss did not improve from 11.70004
# Epoch 504/5000
#
# Epoch 00504: val_loss did not improve from 11.70004
# Epoch 505/5000
#
# Epoch 00505: val_loss did not improve from 11.70004
# Epoch 506/5000
#
# Epoch 00506: val_loss did not improve from 11.70004
# Epoch 507/5000
#
# Epoch 00507: val_loss did not improve from 11.70004
# Epoch 508/5000
#
# Epoch 00508: val_loss did not improve from 11.70004
# Epoch 509/5000
#
# Epoch 00509: val_loss did not improve from 11.70004
# Epoch 510/5000
#
# Epoch 00510: val_loss improved from 11.70004 to 11.69971, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 511/5000
#
# Epoch 00511: val_loss did not improve from 11.69971
# Epoch 512/5000
#
# Epoch 00512: val_loss did not improve from 11.69971
# Epoch 513/5000
#
# Epoch 00513: val_loss did not improve from 11.69971
# Epoch 514/5000
#
# Epoch 00514: val_loss did not improve from 11.69971
# Epoch 515/5000
#
# Epoch 00515: val_loss did not improve from 11.69971
# Epoch 516/5000
#
# Epoch 00516: val_loss did not improve from 11.69971
# Epoch 517/5000
#
# Epoch 00517: val_loss did not improve from 11.69971
# Epoch 518/5000
#
# Epoch 00518: val_loss did not improve from 11.69971
# Epoch 519/5000
#
# Epoch 00519: val_loss did not improve from 11.69971
# Epoch 520/5000
#
# Epoch 00520: val_loss did not improve from 11.69971
# Epoch 521/5000
#
# Epoch 00521: val_loss did not improve from 11.69971
# Epoch 522/5000
#
# Epoch 00522: val_loss did not improve from 11.69971
# Epoch 523/5000
#
# Epoch 00523: val_loss did not improve from 11.69971
# Epoch 524/5000
#
# Epoch 00524: val_loss did not improve from 11.69971
# Epoch 525/5000
#
# Epoch 00525: val_loss did not improve from 11.69971
# Epoch 526/5000
#
# Epoch 00526: val_loss did not improve from 11.69971
# Epoch 527/5000
#
# Epoch 00527: val_loss did not improve from 11.69971
# Epoch 528/5000
#
# Epoch 00528: val_loss did not improve from 11.69971
# Epoch 529/5000
#
# Epoch 00529: val_loss did not improve from 11.69971
# Epoch 530/5000
#
# Epoch 00530: val_loss did not improve from 11.69971
# Epoch 531/5000
#
# Epoch 00531: val_loss did not improve from 11.69971
# Epoch 532/5000
#
# Epoch 00532: val_loss did not improve from 11.69971
# Epoch 533/5000
#
# Epoch 00533: val_loss did not improve from 11.69971
# Epoch 534/5000
#
# Epoch 00534: val_loss did not improve from 11.69971
# Epoch 535/5000
#
# Epoch 00535: val_loss improved from 11.69971 to 11.69956, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 536/5000
#
# Epoch 00536: val_loss did not improve from 11.69956
# Epoch 537/5000
#
# Epoch 00537: val_loss did not improve from 11.69956
# Epoch 538/5000
#
# Epoch 00538: val_loss did not improve from 11.69956
# Epoch 539/5000
#
# Epoch 00539: val_loss did not improve from 11.69956
# Epoch 540/5000
#
# Epoch 00540: val_loss did not improve from 11.69956
# Epoch 541/5000
#
# Epoch 00541: val_loss did not improve from 11.69956
# Epoch 542/5000
#
# Epoch 00542: val_loss did not improve from 11.69956
# Epoch 543/5000
#
# Epoch 00543: val_loss did not improve from 11.69956
# Epoch 544/5000
#
# Epoch 00544: val_loss did not improve from 11.69956
# Epoch 545/5000
#
# Epoch 00545: val_loss did not improve from 11.69956
# Epoch 546/5000
#
# Epoch 00546: val_loss did not improve from 11.69956
# Epoch 547/5000
#
# Epoch 00547: val_loss did not improve from 11.69956
# Epoch 548/5000
#
# Epoch 00548: val_loss did not improve from 11.69956
# Epoch 549/5000
#
# Epoch 00549: val_loss did not improve from 11.69956
# Epoch 550/5000
#
# Epoch 00550: val_loss did not improve from 11.69956
# Epoch 551/5000
#
# Epoch 00551: val_loss did not improve from 11.69956
# Epoch 552/5000
#
# Epoch 00552: val_loss did not improve from 11.69956
# Epoch 553/5000
#
# Epoch 00553: val_loss did not improve from 11.69956
# Epoch 554/5000
#
# Epoch 00554: val_loss did not improve from 11.69956
# Epoch 555/5000
#
# Epoch 00555: val_loss improved from 11.69956 to 11.69787, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 556/5000
#
# Epoch 00556: val_loss did not improve from 11.69787
# Epoch 557/5000
#
# Epoch 00557: val_loss did not improve from 11.69787
# Epoch 558/5000
#
# Epoch 00558: val_loss did not improve from 11.69787
# Epoch 559/5000
#
# Epoch 00559: val_loss did not improve from 11.69787
# Epoch 560/5000
#
# Epoch 00560: val_loss did not improve from 11.69787
# Epoch 561/5000
#
# Epoch 00561: val_loss did not improve from 11.69787
# Epoch 562/5000
#
# Epoch 00562: val_loss did not improve from 11.69787
# Epoch 563/5000
#
# Epoch 00563: val_loss did not improve from 11.69787
# Epoch 564/5000
#
# Epoch 00564: val_loss did not improve from 11.69787
# Epoch 565/5000
#
# Epoch 00565: val_loss did not improve from 11.69787
# Epoch 566/5000
#
# Epoch 00566: val_loss did not improve from 11.69787
# Epoch 567/5000
#
# Epoch 00567: val_loss did not improve from 11.69787
# Epoch 568/5000
#
# Epoch 00568: val_loss did not improve from 11.69787
# Epoch 569/5000
#
# Epoch 00569: val_loss did not improve from 11.69787
# Epoch 570/5000
#
# Epoch 00570: val_loss did not improve from 11.69787
# Epoch 571/5000
# Epoch 00571: val_loss did not improve from 11.69787
# Epoch 572/5000
#
# Epoch 00572: val_loss did not improve from 11.69787
# Epoch 573/5000
#
# Epoch 00573: val_loss did not improve from 11.69787
# Epoch 574/5000
#
# Epoch 00574: val_loss did not improve from 11.69787
# Epoch 575/5000
#
# Epoch 00575: val_loss improved from 11.69787 to 11.69786, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 576/5000
#
# Epoch 00576: val_loss did not improve from 11.69786
# Epoch 577/5000
#
# Epoch 00577: val_loss did not improve from 11.69786
# Epoch 578/5000
#
# Epoch 00578: val_loss did not improve from 11.69786
# Epoch 579/5000
#
# Epoch 00579: val_loss did not improve from 11.69786
# Epoch 580/5000
#
# Epoch 00580: val_loss did not improve from 11.69786
# Epoch 581/5000
#
# Epoch 00581: val_loss did not improve from 11.69786
# Epoch 582/5000
#
# Epoch 00582: val_loss did not improve from 11.69786
# Epoch 583/5000
#
# Epoch 00583: val_loss did not improve from 11.69786
# Epoch 584/5000
#
# Epoch 00584: val_loss did not improve from 11.69786
# Epoch 585/5000
#
# Epoch 00585: val_loss did not improve from 11.69786
# Epoch 586/5000
#
# Epoch 00586: val_loss did not improve from 11.69786
# Epoch 587/5000
#
# Epoch 00587: val_loss did not improve from 11.69786
# Epoch 588/5000
#
# Epoch 00588: val_loss did not improve from 11.69786
# Epoch 589/5000
#
# Epoch 00589: val_loss did not improve from 11.69786
# Epoch 590/5000
#
# Epoch 00590: val_loss did not improve from 11.69786
# Epoch 591/5000
#
# Epoch 00591: val_loss did not improve from 11.69786
# Epoch 592/5000
#
# Epoch 00592: val_loss did not improve from 11.69786
# Epoch 593/5000
#
# Epoch 00593: val_loss did not improve from 11.69786
# Epoch 594/5000
#
# Epoch 00594: val_loss did not improve from 11.69786
# Epoch 595/5000
#
# Epoch 00595: val_loss did not improve from 11.69786
# Epoch 596/5000
#
# Epoch 00596: val_loss did not improve from 11.69786
# Epoch 597/5000
#
# Epoch 00597: val_loss did not improve from 11.69786
# Epoch 598/5000
#
# Epoch 00598: val_loss did not improve from 11.69786
# Epoch 599/5000
#
# Epoch 00599: val_loss did not improve from 11.69786
# Epoch 600/5000
#
# Epoch 00600: val_loss did not improve from 11.69786
# Epoch 601/5000
#
# Epoch 00601: val_loss did not improve from 11.69786
# Epoch 602/5000
#
# Epoch 00602: val_loss did not improve from 11.69786
# Epoch 603/5000
#
# Epoch 00603: val_loss did not improve from 11.69786
# Epoch 604/5000
#
# Epoch 00604: val_loss did not improve from 11.69786
# Epoch 605/5000
#
# Epoch 00605: val_loss did not improve from 11.69786
# Epoch 606/5000
#
# Epoch 00606: val_loss did not improve from 11.69786
# Epoch 607/5000
#
# Epoch 00607: val_loss did not improve from 11.69786
# Epoch 608/5000
#
# Epoch 00608: val_loss did not improve from 11.69786
# Epoch 609/5000
#
# Epoch 00609: val_loss did not improve from 11.69786
# Epoch 610/5000
#
# Epoch 00610: val_loss did not improve from 11.69786
# Epoch 611/5000
#
# Epoch 00611: val_loss did not improve from 11.69786
# Epoch 612/5000
#
# Epoch 00612: val_loss did not improve from 11.69786
# Epoch 613/5000
#
# Epoch 00613: val_loss did not improve from 11.69786
# Epoch 614/5000
#
# Epoch 00614: val_loss did not improve from 11.69786
# Epoch 615/5000
#
# Epoch 00615: val_loss did not improve from 11.69786
# Epoch 616/5000
#
# Epoch 00616: val_loss did not improve from 11.69786
# Epoch 617/5000
#
# Epoch 00617: val_loss did not improve from 11.69786
# Epoch 618/5000
#
# Epoch 00618: val_loss improved from 11.69786 to 11.69775, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 619/5000
#
# Epoch 00619: val_loss did not improve from 11.69775
# Epoch 620/5000
#
# Epoch 00620: val_loss did not improve from 11.69775
# Epoch 621/5000
#
# Epoch 00621: val_loss improved from 11.69775 to 11.69709, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 622/5000
#
# Epoch 00622: val_loss did not improve from 11.69709
# Epoch 623/5000
#
# Epoch 00623: val_loss did not improve from 11.69709
# Epoch 624/5000
#
# Epoch 00624: val_loss did not improve from 11.69709
# Epoch 625/5000
#
# Epoch 00625: val_loss did not improve from 11.69709
# Epoch 626/5000
#
# Epoch 00626: val_loss did not improve from 11.69709
# Epoch 627/5000
#
# Epoch 00627: val_loss did not improve from 11.69709
# Epoch 628/5000
#
# Epoch 00628: val_loss did not improve from 11.69709
# Epoch 629/5000
#
# Epoch 00629: val_loss did not improve from 11.69709
# Epoch 630/5000
#
# Epoch 00630: val_loss did not improve from 11.69709
# Epoch 631/5000
#
# Epoch 00631: val_loss did not improve from 11.69709
# Epoch 632/5000
#
# Epoch 00632: val_loss did not improve from 11.69709
# Epoch 633/5000
#
# Epoch 00633: val_loss did not improve from 11.69709
# Epoch 634/5000
#
# Epoch 00634: val_loss did not improve from 11.69709
# Epoch 635/5000
#
# Epoch 00635: val_loss did not improve from 11.69709
# Epoch 636/5000
#
# Epoch 00636: val_loss did not improve from 11.69709
# Epoch 637/5000
#
# Epoch 00637: val_loss did not improve from 11.69709
# Epoch 638/5000
#
# Epoch 00638: val_loss did not improve from 11.69709
# Epoch 639/5000
#
# Epoch 00639: val_loss did not improve from 11.69709
# Epoch 640/5000
#
# Epoch 00640: val_loss did not improve from 11.69709
# Epoch 641/5000
#
# Epoch 00641: val_loss did not improve from 11.69709
# Epoch 642/5000
#
# Epoch 00642: val_loss did not improve from 11.69709
# Epoch 643/5000
#
# Epoch 00643: val_loss did not improve from 11.69709
# Epoch 644/5000
#
# Epoch 00644: val_loss did not improve from 11.69709
# Epoch 645/5000
#
# Epoch 00645: val_loss did not improve from 11.69709
# Epoch 646/5000
#
# Epoch 00646: val_loss did not improve from 11.69709
# Epoch 647/5000
#
# Epoch 00647: val_loss did not improve from 11.69709
# Epoch 648/5000
#
# Epoch 00648: val_loss did not improve from 11.69709
# Epoch 649/5000
#
# Epoch 00649: val_loss did not improve from 11.69709
# Epoch 650/5000
#
# Epoch 00650: val_loss did not improve from 11.69709
# Epoch 651/5000
#
# Epoch 00651: val_loss did not improve from 11.69709
# Epoch 652/5000
#
# Epoch 00652: val_loss did not improve from 11.69709
# Epoch 653/5000
#
# Epoch 00653: val_loss did not improve from 11.69709
# Epoch 654/5000
#
# Epoch 00654: val_loss did not improve from 11.69709
# Epoch 655/5000
#
# Epoch 00655: val_loss did not improve from 11.69709
# Epoch 656/5000
#
# Epoch 00656: val_loss did not improve from 11.69709
# Epoch 657/5000
#
# Epoch 00657: val_loss did not improve from 11.69709
# Epoch 658/5000
#
# Epoch 00658: val_loss did not improve from 11.69709
# Epoch 659/5000
#
# Epoch 00659: val_loss did not improve from 11.69709
# Epoch 660/5000
#
# Epoch 00660: val_loss did not improve from 11.69709
# Epoch 661/5000
#
# Epoch 00661: val_loss did not improve from 11.69709
# Epoch 662/5000
#
# Epoch 00662: val_loss did not improve from 11.69709
# Epoch 663/5000
#
# Epoch 00663: val_loss did not improve from 11.69709
# Epoch 664/5000
#
# Epoch 00664: val_loss did not improve from 11.69709
# Epoch 665/5000
#
# Epoch 00665: val_loss did not improve from 11.69709
# Epoch 666/5000
#
# Epoch 00666: val_loss did not improve from 11.69709
# Epoch 667/5000
#
# Epoch 00667: val_loss did not improve from 11.69709
# Epoch 668/5000
#
# Epoch 00668: val_loss did not improve from 11.69709
# Epoch 669/5000
#
# Epoch 00669: val_loss did not improve from 11.69709
# Epoch 670/5000
#
# Epoch 00670: val_loss did not improve from 11.69709
# ...
# Epoch 4770/5000
#
# Epoch 04770: val_loss did not improve from 11.57984
# Epoch 4771/5000
#
# Epoch 04771: val_loss did not improve from 11.57984
# Epoch 4772/5000
#
# Epoch 04772: val_loss did not improve from 11.57984
# Epoch 4773/5000
#
# Epoch 04773: val_loss did not improve from 11.57984
# Epoch 4774/5000
#
# Epoch 04774: val_loss did not improve from 11.57984
# Epoch 4775/5000
#
# Epoch 04775: val_loss did not improve from 11.57984
# Epoch 4776/5000
#
# Epoch 04776: val_loss did not improve from 11.57984
# Epoch 4777/5000
#
# Epoch 04777: val_loss did not improve from 11.57984
# Epoch 4778/5000
#
# Epoch 04778: val_loss did not improve from 11.57984
# Epoch 4779/5000
#
# Epoch 04779: val_loss did not improve from 11.57984
# Epoch 4780/5000
#
# Epoch 04780: val_loss did not improve from 11.57984
# Epoch 4781/5000
#
# Epoch 04781: val_loss did not improve from 11.57984
# Epoch 4782/5000
#
# Epoch 04782: val_loss did not improve from 11.57984
# Epoch 4783/5000
#
# Epoch 04783: val_loss did not improve from 11.57984
# Epoch 4784/5000
#
# Epoch 04784: val_loss did not improve from 11.57984
# Epoch 4785/5000
#
# Epoch 04785: val_loss did not improve from 11.57984
# Epoch 4786/5000
#
# Epoch 04786: val_loss did not improve from 11.57984
# Epoch 4787/5000
#
# Epoch 04787: val_loss did not improve from 11.57984
# Epoch 4788/5000
#
# Epoch 04788: val_loss did not improve from 11.57984
# Epoch 4789/5000
#
# Epoch 04789: val_loss did not improve from 11.57984
# Epoch 4790/5000
#
# Epoch 04790: val_loss did not improve from 11.57984
# Epoch 4791/5000
# Epoch 04791: val_loss did not improve from 11.57984
# Epoch 4792/5000
#
# Epoch 04792: val_loss did not improve from 11.57984
# Epoch 4793/5000
#
# Epoch 04793: val_loss did not improve from 11.57984
# Epoch 4794/5000
#
# Epoch 04794: val_loss did not improve from 11.57984
# Epoch 4795/5000
#
# Epoch 04795: val_loss did not improve from 11.57984
# Epoch 4796/5000
#
# Epoch 04796: val_loss did not improve from 11.57984
# Epoch 4797/5000
#
# Epoch 04797: val_loss did not improve from 11.57984
# Epoch 4798/5000
#
# Epoch 04798: val_loss did not improve from 11.57984
# Epoch 4799/5000
#
# Epoch 04799: val_loss did not improve from 11.57984
# Epoch 4800/5000
#
# Epoch 04800: val_loss did not improve from 11.57984
# Epoch 4801/5000
#
# Epoch 04801: val_loss did not improve from 11.57984
# Epoch 4802/5000
#
# Epoch 04802: val_loss did not improve from 11.57984
# Epoch 4803/5000
#
# Epoch 04803: val_loss did not improve from 11.57984
# Epoch 4804/5000
#
# Epoch 04804: val_loss did not improve from 11.57984
# Epoch 4805/5000
#
# Epoch 04805: val_loss did not improve from 11.57984
# Epoch 4806/5000
#
# Epoch 04806: val_loss did not improve from 11.57984
# Epoch 4807/5000
#
# Epoch 04807: val_loss did not improve from 11.57984
# Epoch 4808/5000
#
# Epoch 04808: val_loss did not improve from 11.57984
# Epoch 4809/5000
#
# Epoch 04809: val_loss did not improve from 11.57984
# Epoch 4810/5000
#
# Epoch 04810: val_loss did not improve from 11.57984
# Epoch 4811/5000
#
# Epoch 04811: val_loss did not improve from 11.57984
# Epoch 4812/5000
#
# Epoch 04812: val_loss did not improve from 11.57984
# Epoch 4813/5000
#
# Epoch 04813: val_loss did not improve from 11.57984
# Epoch 4814/5000
#
# Epoch 04814: val_loss did not improve from 11.57984
# Epoch 4815/5000
#
# Epoch 04815: val_loss did not improve from 11.57984
# Epoch 4816/5000
#
# Epoch 04816: val_loss did not improve from 11.57984
# Epoch 4817/5000
#
# Epoch 04817: val_loss did not improve from 11.57984
# Epoch 4818/5000
#
# Epoch 04818: val_loss did not improve from 11.57984
# Epoch 4819/5000
#
# Epoch 04819: val_loss did not improve from 11.57984
# Epoch 4820/5000
#
# Epoch 04820: val_loss did not improve from 11.57984
# Epoch 4821/5000
#
# Epoch 04821: val_loss did not improve from 11.57984
# Epoch 4822/5000
#
# Epoch 04822: val_loss did not improve from 11.57984
# Epoch 4823/5000
#
# Epoch 04823: val_loss did not improve from 11.57984
# Epoch 4824/5000
#
# Epoch 04824: val_loss did not improve from 11.57984
# Epoch 4825/5000
#
# Epoch 04825: val_loss did not improve from 11.57984
# Epoch 4826/5000
#
# Epoch 04826: val_loss did not improve from 11.57984
# Epoch 4827/5000
#
# Epoch 04827: val_loss did not improve from 11.57984
# Epoch 4828/5000
#
# Epoch 04828: val_loss did not improve from 11.57984
# Epoch 4829/5000
#
# Epoch 04829: val_loss did not improve from 11.57984
# Epoch 4830/5000
#
# Epoch 04830: val_loss did not improve from 11.57984
# Epoch 4831/5000
#
# Epoch 04831: val_loss did not improve from 11.57984
# Epoch 4832/5000
#
# Epoch 04832: val_loss did not improve from 11.57984
# Epoch 4833/5000
#
# Epoch 04833: val_loss did not improve from 11.57984
# Epoch 4834/5000
#
# Epoch 04834: val_loss did not improve from 11.57984
# Epoch 4835/5000
#
# Epoch 04835: val_loss did not improve from 11.57984
# Epoch 4836/5000
#
# Epoch 04836: val_loss did not improve from 11.57984
# Epoch 4837/5000
#
# Epoch 04837: val_loss did not improve from 11.57984
# Epoch 4838/5000
#
# Epoch 04838: val_loss did not improve from 11.57984
# Epoch 4839/5000
#
# Epoch 04839: val_loss did not improve from 11.57984
# Epoch 4840/5000
#
# Epoch 04840: val_loss did not improve from 11.57984
# Epoch 4841/5000
#
# Epoch 04841: val_loss did not improve from 11.57984
# Epoch 4842/5000
#
# Epoch 04842: val_loss did not improve from 11.57984
# Epoch 4843/5000
#
# Epoch 04843: val_loss did not improve from 11.57984
# Epoch 4844/5000
#
# Epoch 04844: val_loss did not improve from 11.57984
# Epoch 4845/5000
#
# Epoch 04845: val_loss did not improve from 11.57984
# Epoch 4846/5000
#
# Epoch 04846: val_loss did not improve from 11.57984
# Epoch 4847/5000
#
# Epoch 04847: val_loss improved from 11.57984 to 11.57185, saving model to human_features_capsulenets_weights_v1.h5
# Epoch 4848/5000
#
# Epoch 04848: val_loss did not improve from 11.57185
# Epoch 4849/5000
#
# Epoch 04849: val_loss did not improve from 11.57185
# Epoch 4850/5000
#
# Epoch 04850: val_loss did not improve from 11.57185
# Epoch 4851/5000
#
# Epoch 04851: val_loss did not improve from 11.57185
# Epoch 4852/5000
#
# Epoch 04852: val_loss did not improve from 11.57185
# Epoch 4853/5000
#
# Epoch 04853: val_loss did not improve from 11.57185
# Epoch 4854/5000
#
# Epoch 04854: val_loss did not improve from 11.57185
# Epoch 4855/5000
#
# Epoch 04855: val_loss did not improve from 11.57185
# Epoch 4856/5000
#
# Epoch 04856: val_loss did not improve from 11.57185
# Epoch 4857/5000
#
# Epoch 04857: val_loss did not improve from 11.57185
# Epoch 4858/5000
#
# Epoch 04858: val_loss did not improve from 11.57185
# Epoch 4859/5000
#
# Epoch 04859: val_loss did not improve from 11.57185
# Epoch 4860/5000
#
# Epoch 04860: val_loss did not improve from 11.57185
# Epoch 4861/5000
#
# Epoch 04861: val_loss did not improve from 11.57185
# Epoch 4862/5000
#
# Epoch 04862: val_loss did not improve from 11.57185
# Epoch 4863/5000
#
# Epoch 04863: val_loss did not improve from 11.57185
# Epoch 4864/5000
#
# Epoch 04864: val_loss did not improve from 11.57185
# Epoch 4865/5000
#
# Epoch 04865: val_loss did not improve from 11.57185
# Epoch 4866/5000
#
# Epoch 04866: val_loss did not improve from 11.57185
# Epoch 4867/5000
#
# Epoch 04867: val_loss did not improve from 11.57185
# Epoch 4868/5000
#
# Epoch 04868: val_loss did not improve from 11.57185
# Epoch 4869/5000
#
# Epoch 04869: val_loss did not improve from 11.57185
# Epoch 4870/5000
#
# Epoch 04870: val_loss did not improve from 11.57185
# Epoch 4871/5000
#
# Epoch 04871: val_loss did not improve from 11.57185
# Epoch 4872/5000
#
# Epoch 04872: val_loss did not improve from 11.57185
# Epoch 4873/5000
#
# Epoch 04873: val_loss did not improve from 11.57185
# Epoch 4874/5000
#
# Epoch 04874: val_loss did not improve from 11.57185
# Epoch 4875/5000
#
# Epoch 04875: val_loss did not improve from 11.57185
# Epoch 4876/5000
#
# Epoch 04876: val_loss did not improve from 11.57185
# Epoch 4877/5000
#
# Epoch 04877: val_loss did not improve from 11.57185
# Epoch 4878/5000
#
# Epoch 04878: val_loss did not improve from 11.57185
# Epoch 4879/5000
#
# Epoch 04879: val_loss did not improve from 11.57185
# Epoch 4880/5000
#
# Epoch 04880: val_loss did not improve from 11.57185
# Epoch 4881/5000
#
# Epoch 04881: val_loss did not improve from 11.57185
# Epoch 4882/5000
#
# Epoch 04882: val_loss did not improve from 11.57185
# Epoch 4883/5000
#
# Epoch 04883: val_loss did not improve from 11.57185
# Epoch 4884/5000
#
# Epoch 04884: val_loss did not improve from 11.57185
# Epoch 4885/5000
#
# Epoch 04885: val_loss did not improve from 11.57185
# Epoch 4886/5000
#
# Epoch 04886: val_loss did not improve from 11.57185
# Epoch 4887/5000
#
# Epoch 04887: val_loss did not improve from 11.57185
# Epoch 4888/5000
#
# Epoch 04888: val_loss did not improve from 11.57185
# Epoch 4889/5000
#
# Epoch 04889: val_loss did not improve from 11.57185
# Epoch 4890/5000
#
# Epoch 04890: val_loss did not improve from 11.57185
# Epoch 4891/5000
#
# Epoch 04891: val_loss did not improve from 11.57185
# Epoch 4892/5000
#
# Epoch 04892: val_loss did not improve from 11.57185
# Epoch 4893/5000
#
# Epoch 04893: val_loss did not improve from 11.57185
# Epoch 4894/5000
#
# Epoch 04894: val_loss did not improve from 11.57185
# Epoch 4895/5000
#
# Epoch 04895: val_loss did not improve from 11.57185
# Epoch 4896/5000
#
# Epoch 04896: val_loss did not improve from 11.57185
# Epoch 4897/5000
#
# Epoch 04897: val_loss did not improve from 11.57185
# Epoch 4898/5000
#
# Epoch 04898: val_loss did not improve from 11.57185
# Epoch 4899/5000
#
# Epoch 04899: val_loss did not improve from 11.57185
# Epoch 4900/5000
#
# Epoch 04900: val_loss did not improve from 11.57185
# Epoch 4901/5000
#
# Epoch 04901: val_loss did not improve from 11.57185
# Epoch 4902/5000
#
# Epoch 04902: val_loss did not improve from 11.57185
# Epoch 4903/5000
#
# Epoch 04903: val_loss did not improve from 11.57185
# Epoch 4904/5000
#
# Epoch 04904: val_loss did not improve from 11.57185
# Epoch 4905/5000
#
# Epoch 04905: val_loss did not improve from 11.57185
# Epoch 4906/5000
#
# Epoch 04906: val_loss did not improve from 11.57185
# Epoch 4907/5000
#
# Epoch 04907: val_loss did not improve from 11.57185
# Epoch 4908/5000
#
# Epoch 04908: val_loss did not improve from 11.57185
# Epoch 4909/5000
# Epoch 04909: val_loss did not improve from 11.57185
# Epoch 4910/5000
#
# Epoch 04910: val_loss did not improve from 11.57185
# Epoch 4911/5000
#
# Epoch 04911: val_loss did not improve from 11.57185
# Epoch 4912/5000
#
# Epoch 04912: val_loss did not improve from 11.57185
# Epoch 4913/5000
#
# Epoch 04913: val_loss did not improve from 11.57185
# Epoch 4914/5000
#
# Epoch 04914: val_loss did not improve from 11.57185
# Epoch 4915/5000
#
# Epoch 04915: val_loss did not improve from 11.57185
# Epoch 4916/5000
#
# Epoch 04916: val_loss did not improve from 11.57185
# Epoch 4917/5000
#
# Epoch 04917: val_loss did not improve from 11.57185
# Epoch 4918/5000
#
# Epoch 04918: val_loss did not improve from 11.57185
# Epoch 4919/5000
#
# Epoch 04919: val_loss did not improve from 11.57185
# Epoch 4920/5000
#
# Epoch 04920: val_loss did not improve from 11.57185
# Epoch 4921/5000
#
# Epoch 04921: val_loss did not improve from 11.57185
# Epoch 4922/5000
#
# Epoch 04922: val_loss did not improve from 11.57185
# Epoch 4923/5000
#
# Epoch 04923: val_loss did not improve from 11.57185
# Epoch 4924/5000
#
# Epoch 04924: val_loss did not improve from 11.57185
# Epoch 4925/5000
#
# Epoch 04925: val_loss did not improve from 11.57185
# Epoch 4926/5000
#
# Epoch 04926: val_loss did not improve from 11.57185
# Epoch 4927/5000
#
# Epoch 04927: val_loss did not improve from 11.57185
# Epoch 4928/5000
#
# Epoch 04928: val_loss did not improve from 11.57185
# Epoch 4929/5000
#
# Epoch 04929: val_loss did not improve from 11.57185
# Epoch 4930/5000
#
# Epoch 04930: val_loss did not improve from 11.57185
# Epoch 4931/5000
#
# Epoch 04931: val_loss did not improve from 11.57185
# Epoch 4932/5000
#
# Epoch 04932: val_loss did not improve from 11.57185
# Epoch 4933/5000
#
# Epoch 04933: val_loss did not improve from 11.57185
# Epoch 4934/5000
#
# Epoch 04934: val_loss did not improve from 11.57185
# Epoch 4935/5000
#
# Epoch 04935: val_loss did not improve from 11.57185
# Epoch 4936/5000
#
# Epoch 04936: val_loss did not improve from 11.57185
# Epoch 4937/5000
#
# Epoch 04937: val_loss did not improve from 11.57185
# Epoch 4938/5000
#
# Epoch 04938: val_loss did not improve from 11.57185
# Epoch 4939/5000
#
# Epoch 04939: val_loss did not improve from 11.57185
# Epoch 4940/5000
#
# Epoch 04940: val_loss did not improve from 11.57185
# Epoch 4941/5000
#
# Epoch 04941: val_loss did not improve from 11.57185
# Epoch 4942/5000
#
# Epoch 04942: val_loss did not improve from 11.57185
# Epoch 4943/5000
#
# Epoch 04943: val_loss did not improve from 11.57185
# Epoch 4944/5000
#
# Epoch 04944: val_loss did not improve from 11.57185
# Epoch 4945/5000
#
# Epoch 04945: val_loss did not improve from 11.57185
# Epoch 4946/5000
#
# Epoch 04946: val_loss did not improve from 11.57185
# Epoch 4947/5000
#
# Epoch 04947: val_loss did not improve from 11.57185
# Epoch 4948/5000
#
# Epoch 04948: val_loss did not improve from 11.57185
# Epoch 4949/5000
#
# Epoch 04949: val_loss did not improve from 11.57185
# Epoch 4950/5000
#
# Epoch 04950: val_loss did not improve from 11.57185
# Epoch 4951/5000
#
# Epoch 04951: val_loss did not improve from 11.57185
# Epoch 4952/5000
#
# Epoch 04952: val_loss did not improve from 11.57185
# Epoch 4953/5000
#
# Epoch 04953: val_loss did not improve from 11.57185
# Epoch 4954/5000
#
# Epoch 04954: val_loss did not improve from 11.57185
# Epoch 4955/5000
#
# Epoch 04955: val_loss did not improve from 11.57185
# Epoch 4956/5000
#
# Epoch 04956: val_loss did not improve from 11.57185
# Epoch 4957/5000
#
# Epoch 04957: val_loss did not improve from 11.57185
# Epoch 4958/5000
#
# Epoch 04958: val_loss did not improve from 11.57185
# Epoch 4959/5000
#
# Epoch 04959: val_loss did not improve from 11.57185
# Epoch 4960/5000
#
# Epoch 04960: val_loss did not improve from 11.57185
# Epoch 4961/5000
#
# Epoch 04961: val_loss did not improve from 11.57185
# Epoch 4962/5000
#
# Epoch 04962: val_loss did not improve from 11.57185
# Epoch 4963/5000
#
# Epoch 04963: val_loss did not improve from 11.57185
# Epoch 4964/5000
#
# Epoch 04964: val_loss did not improve from 11.57185
# Epoch 4965/5000
#
# Epoch 04965: val_loss did not improve from 11.57185
# Epoch 4966/5000
#
# Epoch 04966: val_loss did not improve from 11.57185
# Epoch 4967/5000
#
# Epoch 04967: val_loss did not improve from 11.57185
# Epoch 4968/5000
#
# Epoch 04968: val_loss did not improve from 11.57185
# Epoch 4969/5000
#
# Epoch 04969: val_loss did not improve from 11.57185
# Epoch 4970/5000
#
# Epoch 04970: val_loss did not improve from 11.57185
# Epoch 4971/5000
#
# Epoch 04971: val_loss did not improve from 11.57185
# Epoch 4972/5000
#
# Epoch 04972: val_loss did not improve from 11.57185
# Epoch 4973/5000
#
# Epoch 04973: val_loss did not improve from 11.57185
# Epoch 4974/5000
#
# Epoch 04974: val_loss did not improve from 11.57185
# Epoch 4975/5000
#
# Epoch 04975: val_loss did not improve from 11.57185
# Epoch 4976/5000
#
# Epoch 04976: val_loss did not improve from 11.57185
# Epoch 4977/5000
#
# Epoch 04977: val_loss did not improve from 11.57185
# Epoch 4978/5000
#
# Epoch 04978: val_loss did not improve from 11.57185
# Epoch 4979/5000
#
# Epoch 04979: val_loss did not improve from 11.57185
# Epoch 4980/5000
#
# Epoch 04980: val_loss did not improve from 11.57185
# Epoch 4981/5000
#
# Epoch 04981: val_loss did not improve from 11.57185
# Epoch 4982/5000
#
# Epoch 04982: val_loss did not improve from 11.57185
# Epoch 4983/5000
#
# Epoch 04983: val_loss did not improve from 11.57185
# Epoch 4984/5000
#
# Epoch 04984: val_loss did not improve from 11.57185
# Epoch 4985/5000
#
# Epoch 04985: val_loss did not improve from 11.57185
# Epoch 4986/5000
#
# Epoch 04986: val_loss did not improve from 11.57185
# Epoch 4987/5000
#
# Epoch 04987: val_loss did not improve from 11.57185
# Epoch 4988/5000
#
# Epoch 04988: val_loss did not improve from 11.57185
# Epoch 4989/5000
#
# Epoch 04989: val_loss did not improve from 11.57185
# Epoch 4990/5000
#
# Epoch 04990: val_loss did not improve from 11.57185
# Epoch 4991/5000
#
# Epoch 04991: val_loss did not improve from 11.57185
# Epoch 4992/5000
#
# Epoch 04992: val_loss did not improve from 11.57185
# Epoch 4993/5000
#
# Epoch 04993: val_loss did not improve from 11.57185
# Epoch 4994/5000
#
# Epoch 04994: val_loss did not improve from 11.57185
# Epoch 4995/5000
#
# Epoch 04995: val_loss did not improve from 11.57185
# Epoch 4996/5000
#
# Epoch 04996: val_loss did not improve from 11.57185
# Epoch 4997/5000
#
# Epoch 04997: val_loss did not improve from 11.57185
# Epoch 4998/5000
#
# Epoch 04998: val_loss did not improve from 11.57185
# Epoch 4999/5000
#
# Epoch 04999: val_loss did not improve from 11.57185
# Epoch 5000/5000
#
# Epoch 05000: val_loss did not improve from 11.57185

# %%
df_hist = pd.DataFrame(hist.history)
df_hist.plot(subplots=True, figsize=(15,100))
print(df_hist['val_loss'].min())
df_hist[df_hist['val_loss']<10.2]
# Out:
# 11.571854591369629
# Empty DataFrame
# Columns: [val_loss, val_recon_loss, val_out_feature_1_loss, val_out_feature_2_loss, val_out_feature_3_loss, val_out_feature_4_loss, val_out_feature_5_loss, val_out_feature_6_loss, val_out_feature_7_loss, val_out_feature_8_loss, val_recon_acc, val_out_feature_1_acc, val_out_feature_2_acc, val_out_feature_3_acc, val_out_feature_4_acc, val_out_feature_5_acc, val_out_feature_6_acc, val_out_feature_7_acc, val_out_feature_8_acc, loss, recon_loss, out_feature_1_loss, out_feature_2_loss, out_feature_3_loss, out_feature_4_loss, out_feature_5_loss, out_feature_6_loss, out_feature_7_loss, out_feature_8_loss, recon_acc, out_feature_1_acc, out_feature_2_acc, out_feature_3_acc, out_feature_4_acc, out_feature_5_acc, out_feature_6_acc, out_feature_7_acc, out_feature_8_acc]
# Index: []
#
# [0 rows x 38 columns]

# %%
# print(df_hist.columns)
print(df_hist['val_out_feature_1_acc'].max(), df_hist['val_out_feature_2_acc'].max(),
       df_hist['val_out_feature_3_acc'].max(), df_hist['val_out_feature_4_acc'].max(),
       df_hist['val_out_feature_5_acc'].max(), df_hist['val_out_feature_6_acc'].max(),
       df_hist['val_out_feature_7_acc'].max(), df_hist['val_out_feature_8_acc'].max())
# df_hist[df_hist['val_acc']>10.2]
# Out:
# 0.484375 0.6349206566810608 0.796875 0.453125 0.71875 0.703125 0.53125 0.46875

# %%
train_csv_data.var()
# Out:
# Unnamed: 0    40891.666667
# f1                0.851443
# f2                1.531445
# f3                0.045492
# f4                1.736920
# f5                0.344204
# f6                0.345686
# f7                0.781598
# f8                1.696078
# f9                0.119540
# dtype: float64

# %%
val_csv_data.var()
# Out:
# Unnamed: 0    8883.500000
# f1               1.056461
# f2               1.782312
# f3               0.377348
# f4               1.635451
# f5               0.991638
# f6               0.637669
# f7               1.083200
# f8               1.550618
# f9               0.240491
# dtype: float64
