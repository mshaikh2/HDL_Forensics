# %%
import keras
import pandas as pd
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline
from keras.callbacks import ModelCheckpoint, EarlyStopping
# %reload_ext mermaid
# import IPython
# IPython.load_ipython_extensions(["nb-mermaid/nb-mermaid"]);
# Out:
# Using TensorFlow backend.

# %%
import tensorflow  as tf
from keras.models import Sequential, Model
from keras.layers import Conv2D,Reshape, Dropout, Dense, GlobalAveragePooling2D, \
BatchNormalization, Input, Flatten, MaxPooling2D, UpSampling2D,Lambda
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.optimizers import Adadelta, SGD, Adam
from keras.utils import to_categorical
import keras.backend as K

# %%
tf_config = tf.ConfigProto(allow_soft_placement=False)
tf_config.gpu_options.allow_growth = True
s = tf.Session(config=tf_config)
K.set_session(s)

# %%
csv_data = pd.read_csv('15features.csv')

# %%
display(csv_data.head()), csv_data.shape
# Out:
#         imagename  pen_pressure  letter_spacing  size  dimension  \
# 0  0968c_num1.png             2               2     2          1
# 1  0809c_num2.png             2               2     2          2
# 2  0237b_num6.png             2               2     2          2
# 3  0069b_num2.png             2               2     2          1
# 4  0966c_num4.png             2               2     2          2
#
#    is_lowercase  is_continuous  slantness  tilt  entry_stroke_a  staff_of_a  \
# 0             2              2          3     2               1           2
# 1             2              2          3     1               1           2
# 2             2              2          2     2               1           2
# 3             2              2          1     1               1           1
# 4             2              2          2     1               1           2
#
#    formation_n  staff_of_d  exit_stroke_d  word_formation  constancy
# 0            2           3              2               2          1
# 1            2           3              1               2          2
# 2            2           2              2               2          2
# 3            1           1              1               1          1
# 4            2           2              2               2          2
# (None, (13570, 16))

# %%
train_path = 'unseen-dataset/TrainingSet/'
train_images = os.listdir(train_path)
len(train_images)
val_path = 'unseen-dataset/ValidationSet/'
val_images = os.listdir(val_path)
len(val_images)
# Out:
# 888

# %%
input_img = Input(shape=(64, 64, 1))  # adapt this if using `channels_first` image data format

x = Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same', name='encoded')(x)
# encoded = GlobalAveragePooling2D()(x)

# encoder = Model(input_img, encoded)
# encoder.summary()
# print(encoded.shape)
# encoded = Flatten()(x)
# encoded = Dense(8*8*8)(encoded)
# # model = Model(input_img,encoded)
# # print(model.summary())
# # at this point the representation is (4, 4, 8) i.e. 128-dimensional
# r = Reshape(target_shape=(8,8,8))(encoded)
x = Conv2D(512, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same',name='output')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 2, 2, 512)         1180160
# _________________________________________________________________
# encoded (MaxPooling2D)       (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1, 1, 512)         2359808
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 2, 256)         1179904
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 128)         295040
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 8, 64)          73792
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 16, 16, 32)        18464
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 32, 32, 16)        4624
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# output (Conv2D)              (None, 64, 64, 1)         145
# =================================================================
# Total params: 5,504,257
# Trainable params: 5,504,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
SVG(model_to_dot(autoencoder, show_layer_names=True, show_shapes=True).create(prog='dot', format='svg'))

# %%
def datagen(batch_size,image_path,list_of_writers, hshift = (-64,64) ,vis=False):
    counter = 0
    
    
    while True:
        counter = 0
        # for writer in unique_writers:
        #     print(identitycounter*100/stop_at, end='\r')
        w_ids,ids = [],[]
        writer_indexes = np.random.randint(0,len(list_of_writers),batch_size)
        x,y,writers = [],[],[]
        for writer_index in writer_indexes:
#             class_vectors = []
            writer = list_of_writers[writer_index]
#             print(writer)
#             writer_samples = list(images[images['image'].str.match(writer)]['image'])
#             print('writer:',writer,', writer_samples:',writer_samples)
#             if len(writer_samples) == 0:
#                 continue
#             writer_sample_index = np.random.randint(0,len(writer_samples))

#             #     unique_writers_count[writer] = len(writer_samples)
# #             print('writer_sample_index:',writer_sample_index)
#             csv_writer = writer_samples[writer_sample_index][:5]

    
            loaded_image = cv2.imread(os.path.join(image_path,writer),0)
            rand = np.random.randint(hshift[0],hshift[1])
            loaded_image_shifted=np.roll(axis=0,a=loaded_image,shift=rand)
#             loaded_image = np.expand_dims(loaded_image,-1)
#             loaded_image_shifted = np.expand_dims(loaded_image_shifted,-1)
#             print('csv_writer:', csv_writer, ', writer:', writer)
#             display(csv_data[csv_data['ImageId'].str.match(csv_writer)])
#             csv_discreete_features = csv_data[csv_data['ImageId'].str.match(csv_writer)].iloc[0].values[2:]
#             print(csv_writer, writer_samples[writer_sample_index])
#             print(csv_writer,csv_discreete_features)
#             for i in range(1,9):
#                 print(csv_discreete_features[i-1],end=',')
#             f_1_out.append(csv_discreete_features[0])
#             f_2_out.append(csv_discreete_features[1])
#             f_3_out.append(csv_discreete_features[2])
#             f_4_out.append(csv_discreete_features[3])
#             f_5_out.append(csv_discreete_features[4])
#             f_6_out.append(csv_discreete_features[5])
#             f_7_out.append(csv_discreete_features[6])
#             f_8_out.append(csv_discreete_features[7])
#                 class_vectors.append(to_categorical(csv_discreete_features[i-1],num_classes=feature_lengths['f'+str(i)]))
#             print("\n",len(class_vectors))
#             print('\n-----------')
            
#             print("++++++++++++++++++++++[",counter,"]+++++++++++++++++++++++")
        #     imgcounter = 0
        #     for sample in writer_samples:
        #         imagepath = os.path.join(image_path,sample)
        #         raw_img = cv2.imread(imagepath)
        #         imgcounter+=1
        #     imgcounter=0
        #     identitycounter += 1
            x.append(255.0-loaded_image_shifted.reshape((64,64,1)))
            y.append(255.0-loaded_image.reshape((64,64,1)))
            w_ids.append(writer[:4])
            writers.append(writer)
            ids.append(writer_index)
            
            counter+=1
#             print('counter:', counter, end='\r')
        if counter <= batch_size:
            if vis== True:
                yield np.array(x)/255.0,[np.array(w_ids),np.array(writers)]
            else:
                yield np.array(x)/255.0,np.array(y)/255.0

# %%
# # unique_writers_count
# f_count = {}
train_list_of_writers = train_images
val_list_of_writers = val_images
batch_size = 64

tg = datagen(batch_size,train_path,train_list_of_writers, hshift = (-64,64))
vg = datagen(batch_size,val_path,val_list_of_writers, hshift = (-64,64))
# test_g = datagen(4,val_list_of_writers, hshift = (-12,12))

# %%
# images
for i in range(10):
    inputs,y = next(tg)
inputs.shape , y.shape#, o[0].shape #, o[1].shape,o[2].shape,o[3].shape,o[4].shape,o[5].shape,o[6].shape,o[7].shape
# Out:
# ((64, 64, 64, 1), (64, 64, 64, 1))

# %%
for r in range(8):
    f,ax = plt.subplots(1,8)
    f.subplots_adjust(hspace = .00, wspace=.15)
    f.set_size_inches(15,5)
    for c in range (8):
        ax[c].imshow(inputs[c+r*8].reshape((64,64)))
        ax[c].axis('off')

# %%
mc = ModelCheckpoint(filepath='simple_ae_maxpool_Unseen_weights_v1.h5', monitor='val_loss',period=1,save_best_only=True,save_weights_only=True,mode='auto',verbose=3)
es = EarlyStopping(patience=10000, monitor='val_loss', min_delta=0.0005, mode='auto')
autoencoder.load_weights('simple_ae_maxpool_less_weights_v3.h5')

# %%
EPOCHS = 50000

hist = autoencoder.fit_generator(tg, callbacks=[mc,es]
                                    , epochs=EPOCHS
                                    , steps_per_epoch = 1
                                    , validation_data = vg
                                    , validation_steps = 1
                                    , verbose = 3
                                    
                                   )
# Out:
# Epoch 1/50000
#
# Epoch 00001: val_loss improved from inf to 0.13579, saving model to simple_ae_maxpool_Unseen_weights_v1.h5
# Epoch 2/50000
#
# Epoch 00002: val_loss improved from 0.13579 to 0.10829, saving model to simple_ae_maxpool_Unseen_weights_v1.h5
# Epoch 3/50000
#
# Epoch 00003: val_loss did not improve from 0.10829
# Epoch 4/50000
#
# Epoch 00004: val_loss did not improve from 0.10829
# Epoch 5/50000
#
# Epoch 00005: val_loss did not improve from 0.10829
# Epoch 6/50000
#
# Epoch 00006: val_loss did not improve from 0.10829
# Epoch 7/50000
#
# Epoch 00007: val_loss did not improve from 0.10829
# Epoch 8/50000
#
# Epoch 00008: val_loss improved from 0.10829 to 0.10410, saving model to simple_ae_maxpool_Unseen_weights_v1.h5
# Epoch 9/50000
#
# Epoch 00009: val_loss did not improve from 0.10410
# Epoch 10/50000
#
# Epoch 00010: val_loss did not improve from 0.10410
# Epoch 11/50000
#
# Epoch 00011: val_loss did not improve from 0.10410
# Epoch 12/50000
#
# Epoch 00012: val_loss did not improve from 0.10410
# Epoch 13/50000
#
# Epoch 00013: val_loss did not improve from 0.10410
# Epoch 14/50000
#
# Epoch 00014: val_loss did not improve from 0.10410
# Epoch 15/50000
#
# Epoch 00015: val_loss did not improve from 0.10410
# Epoch 16/50000
#
# Epoch 00016: val_loss did not improve from 0.10410
# Epoch 17/50000
#
# Epoch 00017: val_loss did not improve from 0.10410
# Epoch 18/50000
#
# Epoch 00018: val_loss did not improve from 0.10410
# Epoch 19/50000
#
# Epoch 00019: val_loss did not improve from 0.10410
# Epoch 20/50000
#
# Epoch 00020: val_loss did not improve from 0.10410
# Epoch 21/50000
#
# Epoch 00021: val_loss did not improve from 0.10410
# Epoch 22/50000
#
# Epoch 00022: val_loss did not improve from 0.10410
# Epoch 23/50000
#
# Epoch 00023: val_loss did not improve from 0.10410
# Epoch 24/50000
#
# Epoch 00024: val_loss did not improve from 0.10410
# Epoch 25/50000
#
# Epoch 00025: val_loss improved from 0.10410 to 0.10381, saving model to simple_ae_maxpool_Unseen_weights_v1.h5
# Epoch 26/50000
#
# Epoch 00026: val_loss did not improve from 0.10381
# Epoch 27/50000
#
# Epoch 00027: val_loss did not improve from 0.10381
# Epoch 28/50000
#
# Epoch 00028: val_loss did not improve from 0.10381
# Epoch 29/50000
#
# Epoch 00029: val_loss did not improve from 0.10381
# Epoch 30/50000
#
# Epoch 00030: val_loss did not improve from 0.10381
# Epoch 31/50000
#
# Epoch 00031: val_loss did not improve from 0.10381
# Epoch 32/50000
#
# Epoch 00032: val_loss did not improve from 0.10381
# Epoch 33/50000
#
# Epoch 00033: val_loss did not improve from 0.10381
# Epoch 34/50000
#
# Epoch 00034: val_loss did not improve from 0.10381
# Epoch 35/50000
#
# Epoch 00035: val_loss did not improve from 0.10381
# Epoch 36/50000
#
# Epoch 00036: val_loss did not improve from 0.10381
# Epoch 37/50000
#
# Epoch 00037: val_loss did not improve from 0.10381
# Epoch 38/50000
#
# Epoch 00038: val_loss did not improve from 0.10381
# Epoch 39/50000
#
# Epoch 00039: val_loss improved from 0.10381 to 0.10273, saving model to simple_ae_maxpool_Unseen_weights_v1.h5
# Epoch 40/50000
#
# Epoch 00040: val_loss did not improve from 0.10273
# Epoch 41/50000
#
# Epoch 00041: val_loss did not improve from 0.10273
# Epoch 42/50000
#
# Epoch 00042: val_loss did not improve from 0.10273
# Epoch 43/50000
#
# Epoch 00043: val_loss did not improve from 0.10273
# Epoch 44/50000
#
# Epoch 00044: val_loss did not improve from 0.10273
# Epoch 45/50000
#
# Epoch 00045: val_loss improved from 0.10273 to 0.10225, saving model to simple_ae_maxpool_Unseen_weights_v1.h5
# Epoch 46/50000
#
# Epoch 00046: val_loss did not improve from 0.10225
# Epoch 47/50000
#
# Epoch 00047: val_loss did not improve from 0.10225
# Epoch 48/50000
#
# Epoch 00048: val_loss did not improve from 0.10225
# Epoch 49/50000
#
# Epoch 00049: val_loss improved from 0.10225 to 0.10054, saving model to simple_ae_maxpool_Unseen_weights_v1.h5
# Epoch 50/50000
#
# Epoch 00050: val_loss did not improve from 0.10054
# Epoch 51/50000
#
# Epoch 00051: val_loss did not improve from 0.10054
# Epoch 52/50000
#
# Epoch 00052: val_loss did not improve from 0.10054
# Epoch 53/50000
#
# Epoch 00053: val_loss did not improve from 0.10054
# Epoch 54/50000
#
# Epoch 00054: val_loss did not improve from 0.10054
# Epoch 55/50000
#
# Epoch 00055: val_loss did not improve from 0.10054
# Epoch 56/50000
#
# Epoch 00056: val_loss did not improve from 0.10054
# Epoch 57/50000
#
# Epoch 00057: val_loss did not improve from 0.10054
# Epoch 58/50000
#
# Epoch 00058: val_loss did not improve from 0.10054
# Epoch 59/50000
#
# Epoch 00059: val_loss did not improve from 0.10054
# Epoch 60/50000
#
# Epoch 00060: val_loss did not improve from 0.10054
# Epoch 61/50000
#
# Epoch 00061: val_loss did not improve from 0.10054
# Epoch 62/50000
#
# Epoch 00062: val_loss did not improve from 0.10054
# Epoch 63/50000
#
# Epoch 00063: val_loss did not improve from 0.10054
# Epoch 64/50000
#
# Epoch 00064: val_loss did not improve from 0.10054
# Epoch 65/50000
#
# Epoch 00065: val_loss did not improve from 0.10054
# Epoch 66/50000
#
# Epoch 00066: val_loss did not improve from 0.10054
# Epoch 67/50000
#
# Epoch 00067: val_loss did not improve from 0.10054
# Epoch 68/50000
#
# Epoch 00068: val_loss did not improve from 0.10054
# Epoch 69/50000
#
# Epoch 00069: val_loss did not improve from 0.10054
# Epoch 70/50000
#
# Epoch 00070: val_loss did not improve from 0.10054
# Epoch 71/50000
#
# Epoch 00071: val_loss improved from 0.10054 to 0.09847, saving model to simple_ae_maxpool_Unseen_weights_v1.h5
# Epoch 72/50000
#
# Epoch 00072: val_loss did not improve from 0.09847
# Epoch 73/50000
#
# Epoch 00073: val_loss did not improve from 0.09847
# Epoch 74/50000
#
# Epoch 00074: val_loss did not improve from 0.09847
# Epoch 75/50000
#
# Epoch 00075: val_loss did not improve from 0.09847
# Epoch 76/50000
#
# Epoch 00076: val_loss did not improve from 0.09847
# Epoch 77/50000
#
# Epoch 00077: val_loss did not improve from 0.09847
# Epoch 78/50000
#
# Epoch 00078: val_loss did not improve from 0.09847
# Epoch 79/50000
#
# Epoch 00079: val_loss did not improve from 0.09847
# Epoch 80/50000
#
# Epoch 00080: val_loss did not improve from 0.09847
# Epoch 81/50000
#
# Epoch 00081: val_loss did not improve from 0.09847
# Epoch 82/50000
#
# Epoch 00082: val_loss did not improve from 0.09847
# Epoch 83/50000
#
# Epoch 00083: val_loss did not improve from 0.09847
# Epoch 84/50000
#
# Epoch 00084: val_loss did not improve from 0.09847
# Epoch 85/50000
#
# Epoch 00085: val_loss did not improve from 0.09847
# Epoch 86/50000
#
# Epoch 00086: val_loss did not improve from 0.09847
# Epoch 87/50000
#
# Epoch 00087: val_loss did not improve from 0.09847
# Epoch 88/50000
#
# Epoch 00088: val_loss did not improve from 0.09847
# Epoch 89/50000
#
# Epoch 00089: val_loss did not improve from 0.09847
# Epoch 90/50000
#
# Epoch 00090: val_loss did not improve from 0.09847
# Epoch 91/50000
#
# Epoch 00091: val_loss did not improve from 0.09847
# Epoch 92/50000
#
# Epoch 00092: val_loss did not improve from 0.09847
# Epoch 93/50000
#
# Epoch 00093: val_loss did not improve from 0.09847
# Epoch 94/50000
#
# Epoch 00094: val_loss did not improve from 0.09847
# Epoch 95/50000
#
# Epoch 00095: val_loss did not improve from 0.09847
# Epoch 96/50000
#
# Epoch 00096: val_loss did not improve from 0.09847
# Epoch 97/50000
#
# Epoch 00097: val_loss did not improve from 0.09847
# Epoch 98/50000
#
# Epoch 00098: val_loss did not improve from 0.09847
# Epoch 99/50000
#
# Epoch 00099: val_loss did not improve from 0.09847
# Epoch 100/50000
#
# Epoch 00100: val_loss did not improve from 0.09847
# Epoch 101/50000
#
# Epoch 00101: val_loss did not improve from 0.09847
# Epoch 102/50000
#
# Epoch 00102: val_loss did not improve from 0.09847
# Epoch 103/50000
#
# Epoch 00103: val_loss did not improve from 0.09847
# Epoch 104/50000
#
# Epoch 00104: val_loss did not improve from 0.09847
# Epoch 105/50000
#
# Epoch 00105: val_loss did not improve from 0.09847
# Epoch 106/50000
#
# Epoch 00106: val_loss did not improve from 0.09847
# Epoch 107/50000
#
# Epoch 00107: val_loss did not improve from 0.09847
# Epoch 108/50000
#
# Epoch 00108: val_loss did not improve from 0.09847
# Epoch 109/50000
#
# Epoch 00109: val_loss did not improve from 0.09847
# Epoch 110/50000
#
# Epoch 00110: val_loss did not improve from 0.09847
# Epoch 111/50000
#
# Epoch 00111: val_loss did not improve from 0.09847
# Epoch 112/50000
#
# Epoch 00112: val_loss did not improve from 0.09847
# Epoch 113/50000
#
# Epoch 00113: val_loss did not improve from 0.09847
# Epoch 114/50000
#
# Epoch 00114: val_loss did not improve from 0.09847
# Epoch 115/50000
#
# Epoch 00115: val_loss did not improve from 0.09847
# Epoch 116/50000
# Epoch 00116: val_loss did not improve from 0.09847
# Epoch 117/50000
#
# Epoch 00117: val_loss did not improve from 0.09847
# Epoch 118/50000
#
# Epoch 00118: val_loss did not improve from 0.09847
# Epoch 119/50000
#
# Epoch 00119: val_loss did not improve from 0.09847
# Epoch 120/50000
#
# Epoch 00120: val_loss did not improve from 0.09847
# Epoch 121/50000
#
# Epoch 00121: val_loss did not improve from 0.09847
# Epoch 122/50000
#
# Epoch 00122: val_loss did not improve from 0.09847
# Epoch 123/50000
#
# Epoch 00123: val_loss did not improve from 0.09847
# Epoch 124/50000
#
# Epoch 00124: val_loss did not improve from 0.09847
# Epoch 125/50000
#
# Epoch 00125: val_loss did not improve from 0.09847
# Epoch 126/50000
#
# Epoch 00126: val_loss did not improve from 0.09847
# Epoch 127/50000
#
# Epoch 00127: val_loss did not improve from 0.09847
# Epoch 128/50000
#
# Epoch 00128: val_loss did not improve from 0.09847
# Epoch 129/50000
#
# Epoch 00129: val_loss did not improve from 0.09847
# Epoch 130/50000
#
# Epoch 00130: val_loss did not improve from 0.09847
# Epoch 131/50000
#
# Epoch 00131: val_loss did not improve from 0.09847
# Epoch 132/50000
#
# Epoch 00132: val_loss did not improve from 0.09847
# Epoch 133/50000
#
# Epoch 00133: val_loss did not improve from 0.09847
# Epoch 134/50000
#
# Epoch 00134: val_loss did not improve from 0.09847
# Epoch 135/50000
#
# Epoch 00135: val_loss did not improve from 0.09847
# Epoch 136/50000
#
# Epoch 00136: val_loss did not improve from 0.09847
# Epoch 137/50000
#
# Epoch 00137: val_loss did not improve from 0.09847
# Epoch 138/50000
#
# Epoch 00138: val_loss did not improve from 0.09847
# Epoch 139/50000
#
# Epoch 00139: val_loss did not improve from 0.09847
# Epoch 140/50000
#
# Epoch 00140: val_loss did not improve from 0.09847
# Epoch 141/50000
#
# Epoch 00141: val_loss did not improve from 0.09847
# Epoch 142/50000
#
# Epoch 00142: val_loss did not improve from 0.09847
# Epoch 143/50000
#
# Epoch 00143: val_loss did not improve from 0.09847
# Epoch 144/50000
#
# Epoch 00144: val_loss did not improve from 0.09847
# Epoch 145/50000
#
# Epoch 00145: val_loss did not improve from 0.09847
# Epoch 146/50000
#
# Epoch 00146: val_loss did not improve from 0.09847
# Epoch 147/50000
#
# Epoch 00147: val_loss did not improve from 0.09847
# Epoch 148/50000
#
# Epoch 00148: val_loss did not improve from 0.09847
# Epoch 149/50000
#
# Epoch 00149: val_loss did not improve from 0.09847
# Epoch 150/50000
#
# Epoch 00150: val_loss did not improve from 0.09847
# Epoch 151/50000
#
# Epoch 00151: val_loss did not improve from 0.09847
# Epoch 152/50000
#
# Epoch 00152: val_loss did not improve from 0.09847
# Epoch 153/50000
#
# Epoch 00153: val_loss did not improve from 0.09847
# Epoch 154/50000
#
# Epoch 00154: val_loss did not improve from 0.09847
# Epoch 155/50000
#
# Epoch 00155: val_loss did not improve from 0.09847
# Epoch 156/50000
#
# Epoch 00156: val_loss did not improve from 0.09847
# Epoch 157/50000
#
# Epoch 00157: val_loss did not improve from 0.09847
# Epoch 158/50000
#
# Epoch 00158: val_loss did not improve from 0.09847
# Epoch 159/50000
#
# Epoch 00159: val_loss did not improve from 0.09847
# Epoch 160/50000
#
# Epoch 00160: val_loss did not improve from 0.09847
# Epoch 161/50000
#
# Epoch 00161: val_loss did not improve from 0.09847
# Epoch 162/50000
#
# Epoch 00162: val_loss did not improve from 0.09847
# Epoch 163/50000
#
# Epoch 00163: val_loss did not improve from 0.09847
# Epoch 164/50000
#
# Epoch 00164: val_loss did not improve from 0.09847
# Epoch 165/50000
#
# Epoch 00165: val_loss did not improve from 0.09847
# Epoch 166/50000
#
# Epoch 00166: val_loss did not improve from 0.09847
# Epoch 167/50000
#
# Epoch 00167: val_loss did not improve from 0.09847
# Epoch 168/50000
#
# Epoch 00168: val_loss did not improve from 0.09847
# Epoch 169/50000
#
# Epoch 00169: val_loss did not improve from 0.09847
# Epoch 170/50000
#
# Epoch 00170: val_loss did not improve from 0.09847
# Epoch 171/50000
#
# Epoch 00171: val_loss did not improve from 0.09847
# Epoch 172/50000
#
# Epoch 00172: val_loss did not improve from 0.09847
# Epoch 173/50000
#
# Epoch 00173: val_loss did not improve from 0.09847
# Epoch 174/50000
#
# Epoch 00174: val_loss did not improve from 0.09847
# Epoch 175/50000
#
# Epoch 00175: val_loss did not improve from 0.09847
# Epoch 176/50000
#
# Epoch 00176: val_loss did not improve from 0.09847
# Epoch 177/50000
#
# Epoch 00177: val_loss did not improve from 0.09847
# Epoch 178/50000
#
# Epoch 00178: val_loss did not improve from 0.09847
# Epoch 179/50000
#
# Epoch 00179: val_loss did not improve from 0.09847
# Epoch 180/50000
#
# Epoch 00180: val_loss did not improve from 0.09847
# Epoch 181/50000
#
# Epoch 00181: val_loss did not improve from 0.09847
# Epoch 182/50000
#
# Epoch 00182: val_loss did not improve from 0.09847
# Epoch 183/50000
#
# Epoch 00183: val_loss did not improve from 0.09847
# Epoch 184/50000
#
# Epoch 00184: val_loss did not improve from 0.09847
# Epoch 185/50000
#
# Epoch 00185: val_loss did not improve from 0.09847
# Epoch 186/50000
#
# Epoch 00186: val_loss did not improve from 0.09847
# Epoch 187/50000
#
# Epoch 00187: val_loss did not improve from 0.09847
# Epoch 188/50000
#
# Epoch 00188: val_loss did not improve from 0.09847
# Epoch 189/50000
#
# Epoch 00189: val_loss did not improve from 0.09847
# Epoch 190/50000
#
# Epoch 00190: val_loss did not improve from 0.09847
# Epoch 191/50000
#
# Epoch 00191: val_loss did not improve from 0.09847
# Epoch 192/50000
#
# Epoch 00192: val_loss did not improve from 0.09847
# Epoch 193/50000
#
# Epoch 00193: val_loss did not improve from 0.09847
# Epoch 194/50000
#
# Epoch 00194: val_loss did not improve from 0.09847
# Epoch 195/50000
#
# Epoch 00195: val_loss did not improve from 0.09847
# Epoch 196/50000
#
# Epoch 00196: val_loss did not improve from 0.09847
# Epoch 197/50000
#
# Epoch 00197: val_loss did not improve from 0.09847
# Epoch 198/50000
#
# Epoch 00198: val_loss did not improve from 0.09847
# Epoch 199/50000
#
# Epoch 00199: val_loss did not improve from 0.09847
# Epoch 200/50000
#
# Epoch 00200: val_loss did not improve from 0.09847
# Epoch 201/50000
#
# Epoch 00201: val_loss did not improve from 0.09847
# Epoch 202/50000
#
# Epoch 00202: val_loss did not improve from 0.09847
# Epoch 203/50000
#
# Epoch 00203: val_loss did not improve from 0.09847
# Epoch 204/50000
#
# Epoch 00204: val_loss did not improve from 0.09847
# Epoch 205/50000
#
# Epoch 00205: val_loss did not improve from 0.09847
# Epoch 206/50000
#
# Epoch 00206: val_loss did not improve from 0.09847
# Epoch 207/50000
#
# Epoch 00207: val_loss did not improve from 0.09847
# Epoch 208/50000
#
# Epoch 00208: val_loss did not improve from 0.09847
# Epoch 209/50000
#
# Epoch 00209: val_loss did not improve from 0.09847
# Epoch 210/50000
#
# Epoch 00210: val_loss did not improve from 0.09847
# Epoch 211/50000
#
# Epoch 00211: val_loss did not improve from 0.09847
# Epoch 212/50000
#
# Epoch 00212: val_loss did not improve from 0.09847
# Epoch 213/50000
#
# Epoch 00213: val_loss did not improve from 0.09847
# Epoch 214/50000
#
# Epoch 00214: val_loss did not improve from 0.09847
# Epoch 215/50000
#
# Epoch 00215: val_loss did not improve from 0.09847
# Epoch 216/50000
#
# Epoch 00216: val_loss did not improve from 0.09847
# Epoch 217/50000
#
# Epoch 00217: val_loss did not improve from 0.09847
# Epoch 218/50000
#
# Epoch 00218: val_loss did not improve from 0.09847
# Epoch 219/50000
#
# Epoch 00219: val_loss did not improve from 0.09847
# Epoch 220/50000
#
# Epoch 00220: val_loss did not improve from 0.09847
# Epoch 221/50000
#
# Epoch 00221: val_loss did not improve from 0.09847
# Epoch 222/50000
#
# Epoch 00222: val_loss did not improve from 0.09847
# Epoch 223/50000
#
# Epoch 00223: val_loss did not improve from 0.09847
# Epoch 224/50000
#
# Epoch 00224: val_loss did not improve from 0.09847
# Epoch 225/50000
#
# Epoch 00225: val_loss did not improve from 0.09847
# Epoch 226/50000
#
# Epoch 00226: val_loss did not improve from 0.09847
# Epoch 227/50000
#
# Epoch 00227: val_loss did not improve from 0.09847
# Epoch 228/50000
#
# Epoch 00228: val_loss did not improve from 0.09847
# Epoch 229/50000
#
# Epoch 00229: val_loss did not improve from 0.09847
# Epoch 230/50000
#
# Epoch 00230: val_loss did not improve from 0.09847
# Epoch 231/50000
#
# Epoch 00231: val_loss did not improve from 0.09847
# Epoch 232/50000
#
# Epoch 00232: val_loss did not improve from 0.09847
# Epoch 233/50000
#
# Epoch 00233: val_loss did not improve from 0.09847
# Epoch 234/50000
#
# Epoch 00234: val_loss did not improve from 0.09847
# Epoch 235/50000
#
# Epoch 00235: val_loss did not improve from 0.09847
# Epoch 236/50000
#
# Epoch 00236: val_loss did not improve from 0.09847
# Epoch 237/50000
#
# Epoch 00237: val_loss did not improve from 0.09847
# Epoch 238/50000
#
# Epoch 00238: val_loss did not improve from 0.09847
# Epoch 239/50000
#
# Epoch 00239: val_loss did not improve from 0.09847
# Epoch 240/50000
#
# Epoch 00240: val_loss did not improve from 0.09847
# Epoch 241/50000
#
# Epoch 00241: val_loss did not improve from 0.09847
# Epoch 242/50000
# Epoch 00242: val_loss did not improve from 0.09847
# Epoch 243/50000
#
# Epoch 00243: val_loss did not improve from 0.09847
# Epoch 244/50000
#
# Epoch 00244: val_loss did not improve from 0.09847
# Epoch 245/50000
#
# Epoch 00245: val_loss did not improve from 0.09847
# Epoch 246/50000
#
# Epoch 00246: val_loss did not improve from 0.09847
# Epoch 247/50000
#
# Epoch 00247: val_loss did not improve from 0.09847
# Epoch 248/50000
#
# Epoch 00248: val_loss did not improve from 0.09847
# Epoch 249/50000
#
# Epoch 00249: val_loss did not improve from 0.09847
# Epoch 250/50000
#
# Epoch 00250: val_loss did not improve from 0.09847
# Epoch 251/50000
#
# Epoch 00251: val_loss did not improve from 0.09847
# Epoch 252/50000
#
# Epoch 00252: val_loss did not improve from 0.09847
# Epoch 253/50000
#
# Epoch 00253: val_loss did not improve from 0.09847
# Epoch 254/50000
#
# Epoch 00254: val_loss did not improve from 0.09847
# Epoch 255/50000
#
# Epoch 00255: val_loss did not improve from 0.09847
# Epoch 256/50000
#
# Epoch 00256: val_loss did not improve from 0.09847
# Epoch 257/50000
#
# Epoch 00257: val_loss did not improve from 0.09847
# Epoch 258/50000
#
# Epoch 00258: val_loss did not improve from 0.09847
# Epoch 259/50000
#
# Epoch 00259: val_loss did not improve from 0.09847
# Epoch 260/50000
#
# Epoch 00260: val_loss did not improve from 0.09847
# Epoch 261/50000
#
# Epoch 00261: val_loss did not improve from 0.09847
# Epoch 262/50000
#
# Epoch 00262: val_loss did not improve from 0.09847
# Epoch 263/50000
#
# Epoch 00263: val_loss did not improve from 0.09847
# Epoch 264/50000
#
# Epoch 00264: val_loss did not improve from 0.09847
# Epoch 265/50000
#
# Epoch 00265: val_loss did not improve from 0.09847
# Epoch 266/50000
#
# Epoch 00266: val_loss did not improve from 0.09847
# Epoch 267/50000
#
# Epoch 00267: val_loss did not improve from 0.09847
# Epoch 268/50000
#
# Epoch 00268: val_loss did not improve from 0.09847
# Epoch 269/50000
#
# Epoch 00269: val_loss did not improve from 0.09847
# Epoch 270/50000
#
# Epoch 00270: val_loss did not improve from 0.09847
# Epoch 271/50000
#
# Epoch 00271: val_loss did not improve from 0.09847
# Epoch 272/50000
#
# Epoch 00272: val_loss did not improve from 0.09847
# Epoch 273/50000
#
# Epoch 00273: val_loss did not improve from 0.09847
# Epoch 274/50000
#
# Epoch 00274: val_loss did not improve from 0.09847
# Epoch 275/50000
#
# Epoch 00275: val_loss did not improve from 0.09847
# Epoch 276/50000
#
# Epoch 00276: val_loss did not improve from 0.09847
# Epoch 277/50000
#
# Epoch 00277: val_loss did not improve from 0.09847
# Epoch 278/50000
#
# Epoch 00278: val_loss did not improve from 0.09847
# Epoch 279/50000
#
# Epoch 00279: val_loss did not improve from 0.09847
# Epoch 280/50000
#
# Epoch 00280: val_loss did not improve from 0.09847
# Epoch 281/50000
#
# Epoch 00281: val_loss did not improve from 0.09847
# Epoch 282/50000
#
# Epoch 00282: val_loss did not improve from 0.09847
# Epoch 283/50000
#
# Epoch 00283: val_loss did not improve from 0.09847
# Epoch 284/50000
#
# Epoch 00284: val_loss did not improve from 0.09847
# Epoch 285/50000
#
# Epoch 00285: val_loss did not improve from 0.09847
# Epoch 286/50000
#
# Epoch 00286: val_loss did not improve from 0.09847
# Epoch 287/50000
#
# Epoch 00287: val_loss did not improve from 0.09847
# Epoch 288/50000
#
# Epoch 00288: val_loss did not improve from 0.09847
# Epoch 289/50000
#
# Epoch 00289: val_loss did not improve from 0.09847
# Epoch 290/50000
#
# Epoch 00290: val_loss did not improve from 0.09847
# Epoch 291/50000
#
# Epoch 00291: val_loss did not improve from 0.09847
# Epoch 292/50000
#
# Epoch 00292: val_loss did not improve from 0.09847
# Epoch 293/50000
#
# Epoch 00293: val_loss did not improve from 0.09847
# Epoch 294/50000
#
# Epoch 00294: val_loss did not improve from 0.09847
# Epoch 295/50000
#
# Epoch 00295: val_loss did not improve from 0.09847
# Epoch 296/50000
#
# Epoch 00296: val_loss did not improve from 0.09847
# Epoch 297/50000
#
# Epoch 00297: val_loss did not improve from 0.09847
# Epoch 298/50000
#
# Epoch 00298: val_loss did not improve from 0.09847
# Epoch 299/50000
#
# Epoch 00299: val_loss did not improve from 0.09847
# Epoch 300/50000
#
# Epoch 00300: val_loss did not improve from 0.09847
# Epoch 301/50000
#
# Epoch 00301: val_loss did not improve from 0.09847
# Epoch 302/50000
#
# Epoch 00302: val_loss did not improve from 0.09847
# Epoch 303/50000
#
# Epoch 00303: val_loss did not improve from 0.09847
# Epoch 304/50000
#
# Epoch 00304: val_loss did not improve from 0.09847
# Epoch 305/50000
#
# Epoch 00305: val_loss did not improve from 0.09847
# Epoch 306/50000
#
# Epoch 00306: val_loss did not improve from 0.09847
# Epoch 307/50000
#
# Epoch 00307: val_loss did not improve from 0.09847
# Epoch 308/50000
#
# Epoch 00308: val_loss did not improve from 0.09847
# Epoch 309/50000
#
# Epoch 00309: val_loss did not improve from 0.09847
# Epoch 310/50000
#
# Epoch 00310: val_loss did not improve from 0.09847
# Epoch 311/50000
#
# Epoch 00311: val_loss did not improve from 0.09847
# Epoch 312/50000
#
# Epoch 00312: val_loss did not improve from 0.09847
# Epoch 313/50000
#
# Epoch 00313: val_loss did not improve from 0.09847
# Epoch 314/50000
#
# Epoch 00314: val_loss did not improve from 0.09847
# Epoch 315/50000
#
# Epoch 00315: val_loss did not improve from 0.09847
# Epoch 316/50000
#
# Epoch 00316: val_loss did not improve from 0.09847
# Epoch 317/50000
#
# Epoch 00317: val_loss did not improve from 0.09847
# Epoch 318/50000
#
# Epoch 00318: val_loss did not improve from 0.09847
# Epoch 319/50000
#
# Epoch 00319: val_loss did not improve from 0.09847
# Epoch 320/50000
#
# Epoch 00320: val_loss did not improve from 0.09847
# Epoch 321/50000
#
# Epoch 00321: val_loss did not improve from 0.09847
# Epoch 322/50000
#
# Epoch 00322: val_loss did not improve from 0.09847
# Epoch 323/50000
#
# Epoch 00323: val_loss did not improve from 0.09847
# Epoch 324/50000
#
# Epoch 00324: val_loss did not improve from 0.09847
# Epoch 325/50000
#
# Epoch 00325: val_loss did not improve from 0.09847
# Epoch 326/50000
#
# Epoch 00326: val_loss did not improve from 0.09847
# Epoch 327/50000
#
# Epoch 00327: val_loss did not improve from 0.09847
# Epoch 328/50000
#
# Epoch 00328: val_loss did not improve from 0.09847
# Epoch 329/50000
#
# Epoch 00329: val_loss did not improve from 0.09847
# Epoch 330/50000
#
# Epoch 00330: val_loss did not improve from 0.09847
# Epoch 331/50000
#
# Epoch 00331: val_loss did not improve from 0.09847
# Epoch 332/50000
#
# Epoch 00332: val_loss did not improve from 0.09847
# Epoch 333/50000
#
# Epoch 00333: val_loss did not improve from 0.09847
# Epoch 334/50000
#
# Epoch 00334: val_loss did not improve from 0.09847
# Epoch 335/50000
#
# Epoch 00335: val_loss did not improve from 0.09847
# Epoch 336/50000
#
# Epoch 00336: val_loss did not improve from 0.09847
# Epoch 337/50000
#
# Epoch 00337: val_loss did not improve from 0.09847
# Epoch 338/50000
#
# Epoch 00338: val_loss did not improve from 0.09847
# Epoch 339/50000
#
# Epoch 00339: val_loss did not improve from 0.09847
# Epoch 340/50000
#
# Epoch 00340: val_loss did not improve from 0.09847
# Epoch 341/50000
#
# Epoch 00341: val_loss did not improve from 0.09847
# Epoch 342/50000
#
# Epoch 00342: val_loss did not improve from 0.09847
# Epoch 343/50000
#
# Epoch 00343: val_loss did not improve from 0.09847
# Epoch 344/50000
#
# Epoch 00344: val_loss did not improve from 0.09847
# Epoch 345/50000
#
# Epoch 00345: val_loss did not improve from 0.09847
# Epoch 346/50000
#
# Epoch 00346: val_loss did not improve from 0.09847
# Epoch 347/50000
#
# Epoch 00347: val_loss did not improve from 0.09847
# Epoch 348/50000
#
# Epoch 00348: val_loss did not improve from 0.09847
# Epoch 349/50000
#
# Epoch 00349: val_loss did not improve from 0.09847
# Epoch 350/50000
#
# Epoch 00350: val_loss did not improve from 0.09847
# Epoch 351/50000
#
# Epoch 00351: val_loss did not improve from 0.09847
# Epoch 352/50000
#
# Epoch 00352: val_loss did not improve from 0.09847
# Epoch 353/50000
#
# Epoch 00353: val_loss did not improve from 0.09847
# Epoch 354/50000
#
# Epoch 00354: val_loss did not improve from 0.09847
# Epoch 355/50000
#
# Epoch 00355: val_loss did not improve from 0.09847
# Epoch 356/50000
#
# Epoch 00356: val_loss did not improve from 0.09847
# Epoch 357/50000
#
# Epoch 00357: val_loss did not improve from 0.09847
# Epoch 358/50000
#
# Epoch 00358: val_loss did not improve from 0.09847
# Epoch 359/50000
#
# Epoch 00359: val_loss did not improve from 0.09847
# Epoch 360/50000
#
# Epoch 00360: val_loss did not improve from 0.09847
# Epoch 361/50000
#
# Epoch 00361: val_loss did not improve from 0.09847
# Epoch 362/50000
#
# Epoch 00362: val_loss did not improve from 0.09847
# Epoch 363/50000
#
# Epoch 00363: val_loss did not improve from 0.09847
# Epoch 364/50000
#
# Epoch 00364: val_loss did not improve from 0.09847
# Epoch 365/50000
#
# Epoch 00365: val_loss did not improve from 0.09847
# Epoch 366/50000
#
# Epoch 00366: val_loss did not improve from 0.09847
# Epoch 367/50000
#
# Epoch 00367: val_loss did not improve from 0.09847
# Epoch 368/50000
# Epoch 00368: val_loss did not improve from 0.09847
# Epoch 369/50000
#
# Epoch 00369: val_loss did not improve from 0.09847
# Epoch 370/50000
#
# Epoch 00370: val_loss did not improve from 0.09847
# Epoch 371/50000
#
# Epoch 00371: val_loss improved from 0.09847 to 0.09785, saving model to simple_ae_maxpool_Unseen_weights_v1.h5
# Epoch 372/50000
#
# Epoch 00372: val_loss did not improve from 0.09785
# Epoch 373/50000
#
# Epoch 00373: val_loss did not improve from 0.09785
# Epoch 374/50000
#
# Epoch 00374: val_loss did not improve from 0.09785
# Epoch 375/50000
#
# Epoch 00375: val_loss did not improve from 0.09785
# Epoch 376/50000
#
# Epoch 00376: val_loss did not improve from 0.09785
# Epoch 377/50000
#
# Epoch 00377: val_loss did not improve from 0.09785
# Epoch 378/50000
#
# Epoch 00378: val_loss did not improve from 0.09785
# Epoch 379/50000
#
# Epoch 00379: val_loss did not improve from 0.09785
# Epoch 380/50000
#
# Epoch 00380: val_loss did not improve from 0.09785
# Epoch 381/50000
#
# Epoch 00381: val_loss did not improve from 0.09785
# Epoch 382/50000
#
# Epoch 00382: val_loss did not improve from 0.09785
# Epoch 383/50000
#
# Epoch 00383: val_loss did not improve from 0.09785
# Epoch 384/50000
#
# Epoch 00384: val_loss did not improve from 0.09785
# Epoch 385/50000
#
# Epoch 00385: val_loss did not improve from 0.09785
# Epoch 386/50000
#
# Epoch 00386: val_loss did not improve from 0.09785
# Epoch 387/50000
#
# Epoch 00387: val_loss did not improve from 0.09785
# Epoch 388/50000
#
# Epoch 00388: val_loss did not improve from 0.09785
# Epoch 389/50000
#
# Epoch 00389: val_loss did not improve from 0.09785
# Epoch 390/50000
#
# Epoch 00390: val_loss did not improve from 0.09785
# Epoch 391/50000
#
# Epoch 00391: val_loss did not improve from 0.09785
# Epoch 392/50000
#
# Epoch 00392: val_loss did not improve from 0.09785
# Epoch 393/50000
#
# Epoch 00393: val_loss did not improve from 0.09785
# Epoch 394/50000
#
# Epoch 00394: val_loss did not improve from 0.09785
# Epoch 395/50000
#
# Epoch 00395: val_loss did not improve from 0.09785
# Epoch 396/50000
#
# Epoch 00396: val_loss did not improve from 0.09785
# Epoch 397/50000
#
# Epoch 00397: val_loss did not improve from 0.09785
# Epoch 398/50000
#
# Epoch 00398: val_loss did not improve from 0.09785
# Epoch 399/50000
#
# Epoch 00399: val_loss did not improve from 0.09785
# Epoch 400/50000
#
# Epoch 00400: val_loss did not improve from 0.09785
# Epoch 401/50000
#
# Epoch 00401: val_loss did not improve from 0.09785
# Epoch 402/50000
#
# Epoch 00402: val_loss did not improve from 0.09785
# Epoch 403/50000
#
# Epoch 00403: val_loss did not improve from 0.09785
# Epoch 404/50000
#
# Epoch 00404: val_loss did not improve from 0.09785
# Epoch 405/50000
#
# Epoch 00405: val_loss did not improve from 0.09785
# Epoch 406/50000
#
# Epoch 00406: val_loss did not improve from 0.09785
# Epoch 407/50000
#
# Epoch 00407: val_loss did not improve from 0.09785
# Epoch 408/50000
#
# Epoch 00408: val_loss did not improve from 0.09785
# Epoch 409/50000
#
# Epoch 00409: val_loss did not improve from 0.09785
# Epoch 410/50000
#
# Epoch 00410: val_loss did not improve from 0.09785
# Epoch 411/50000
#
# Epoch 00411: val_loss did not improve from 0.09785
# Epoch 412/50000
#
# Epoch 00412: val_loss did not improve from 0.09785
# Epoch 413/50000
#
# Epoch 00413: val_loss did not improve from 0.09785
# Epoch 414/50000
#
# Epoch 00414: val_loss did not improve from 0.09785
# Epoch 415/50000
#
# Epoch 00415: val_loss did not improve from 0.09785
# Epoch 416/50000
#
# Epoch 00416: val_loss did not improve from 0.09785
# Epoch 417/50000
#
# Epoch 00417: val_loss did not improve from 0.09785
# Epoch 418/50000
#
# Epoch 00418: val_loss did not improve from 0.09785
# Epoch 419/50000
#
# Epoch 00419: val_loss did not improve from 0.09785
# Epoch 420/50000
#
# Epoch 00420: val_loss did not improve from 0.09785
# Epoch 421/50000
#
# Epoch 00421: val_loss did not improve from 0.09785
# Epoch 422/50000
#
# Epoch 00422: val_loss did not improve from 0.09785
# Epoch 423/50000
#
# Epoch 00423: val_loss did not improve from 0.09785
# Epoch 424/50000
#
# Epoch 00424: val_loss did not improve from 0.09785
# Epoch 425/50000
#
# Epoch 00425: val_loss did not improve from 0.09785
# Epoch 426/50000
#
# Epoch 00426: val_loss did not improve from 0.09785
# Epoch 427/50000
#
# Epoch 00427: val_loss did not improve from 0.09785
# Epoch 428/50000
#
# Epoch 00428: val_loss did not improve from 0.09785
# Epoch 429/50000
#
# Epoch 00429: val_loss did not improve from 0.09785
# Epoch 430/50000
#
# Epoch 00430: val_loss did not improve from 0.09785
# Epoch 431/50000
#
# Epoch 00431: val_loss did not improve from 0.09785
# Epoch 432/50000
#
# Epoch 00432: val_loss did not improve from 0.09785
# Epoch 433/50000
#
# Epoch 00433: val_loss did not improve from 0.09785
# Epoch 434/50000
#
# Epoch 00434: val_loss did not improve from 0.09785
# Epoch 435/50000
#
# Epoch 00435: val_loss improved from 0.09785 to 0.09763, saving model to simple_ae_maxpool_Unseen_weights_v1.h5
# Epoch 436/50000
#
# Epoch 00436: val_loss did not improve from 0.09763
# Epoch 437/50000
#
# Epoch 00437: val_loss did not improve from 0.09763
# Epoch 438/50000
#
# Epoch 00438: val_loss did not improve from 0.09763
# Epoch 439/50000
#
# Epoch 00439: val_loss did not improve from 0.09763
# Epoch 440/50000
#
# Epoch 00440: val_loss did not improve from 0.09763
# Epoch 441/50000
#
# Epoch 00441: val_loss did not improve from 0.09763
# Epoch 442/50000
#
# Epoch 00442: val_loss did not improve from 0.09763
# Epoch 443/50000
#
# Epoch 00443: val_loss did not improve from 0.09763
# Epoch 444/50000
#
# Epoch 00444: val_loss did not improve from 0.09763
# Epoch 445/50000
#
# Epoch 00445: val_loss did not improve from 0.09763
# Epoch 446/50000
#
# Epoch 00446: val_loss did not improve from 0.09763
# Epoch 447/50000
#
# Epoch 00447: val_loss did not improve from 0.09763
# Epoch 448/50000
#
# Epoch 00448: val_loss did not improve from 0.09763
# Epoch 449/50000
#
# Epoch 00449: val_loss did not improve from 0.09763
# Epoch 450/50000
#
# Epoch 00450: val_loss did not improve from 0.09763
# Epoch 451/50000
#
# Epoch 00451: val_loss did not improve from 0.09763
# Epoch 452/50000
#
# Epoch 00452: val_loss did not improve from 0.09763
# Epoch 453/50000
#
# Epoch 00453: val_loss did not improve from 0.09763
# Epoch 454/50000
#
# Epoch 00454: val_loss did not improve from 0.09763
# Epoch 455/50000
#
# Epoch 00455: val_loss did not improve from 0.09763
# Epoch 456/50000
#
# Epoch 00456: val_loss did not improve from 0.09763
# Epoch 457/50000
#
# Epoch 00457: val_loss did not improve from 0.09763
# Epoch 458/50000
#
# Epoch 00458: val_loss did not improve from 0.09763
# Epoch 459/50000
#
# Epoch 00459: val_loss did not improve from 0.09763
# Epoch 460/50000
#
# Epoch 00460: val_loss did not improve from 0.09763
# Epoch 461/50000
#
# Epoch 00461: val_loss did not improve from 0.09763
# Epoch 462/50000
#
# Epoch 00462: val_loss did not improve from 0.09763
# Epoch 463/50000
#
# Epoch 00463: val_loss did not improve from 0.09763
# Epoch 464/50000
#
# Epoch 00464: val_loss did not improve from 0.09763
# Epoch 465/50000
#
# Epoch 00465: val_loss did not improve from 0.09763
# Epoch 466/50000
#
# Epoch 00466: val_loss did not improve from 0.09763
# Epoch 467/50000
#
# Epoch 00467: val_loss did not improve from 0.09763
# Epoch 468/50000
#
# Epoch 00468: val_loss did not improve from 0.09763
# Epoch 469/50000
#
# Epoch 00469: val_loss did not improve from 0.09763
# Epoch 470/50000
#
# Epoch 00470: val_loss did not improve from 0.09763
# Epoch 471/50000
#
# Epoch 00471: val_loss did not improve from 0.09763
# Epoch 472/50000
#
# Epoch 00472: val_loss did not improve from 0.09763
# Epoch 473/50000
#
# Epoch 00473: val_loss did not improve from 0.09763
# Epoch 474/50000
#
# Epoch 00474: val_loss did not improve from 0.09763
# Epoch 475/50000
#
# Epoch 00475: val_loss did not improve from 0.09763
# Epoch 476/50000
#
# Epoch 00476: val_loss did not improve from 0.09763
# Epoch 477/50000
#
# Epoch 00477: val_loss did not improve from 0.09763
# Epoch 478/50000
#
# Epoch 00478: val_loss did not improve from 0.09763
# Epoch 479/50000
#
# Epoch 00479: val_loss did not improve from 0.09763
# Epoch 480/50000
#
# Epoch 00480: val_loss did not improve from 0.09763
# Epoch 481/50000
#
# Epoch 00481: val_loss did not improve from 0.09763
# Epoch 482/50000
#
# Epoch 00482: val_loss did not improve from 0.09763
# Epoch 483/50000
#
# Epoch 00483: val_loss did not improve from 0.09763
# Epoch 484/50000
#
# Epoch 00484: val_loss did not improve from 0.09763
# Epoch 485/50000
#
# Epoch 00485: val_loss did not improve from 0.09763
# Epoch 486/50000
#
# Epoch 00486: val_loss did not improve from 0.09763
# Epoch 487/50000
#
# Epoch 00487: val_loss did not improve from 0.09763
# Epoch 488/50000
#
# Epoch 00488: val_loss did not improve from 0.09763
# Epoch 489/50000
#
# Epoch 00489: val_loss did not improve from 0.09763
# Epoch 490/50000
#
# Epoch 00490: val_loss did not improve from 0.09763
# Epoch 491/50000
#
# Epoch 00491: val_loss did not improve from 0.09763
# Epoch 492/50000
#
# Epoch 00492: val_loss did not improve from 0.09763
# Epoch 493/50000
#
# Epoch 00493: val_loss did not improve from 0.09763
# Epoch 494/50000
# Epoch 00494: val_loss did not improve from 0.09763
# Epoch 495/50000
#
# Epoch 00495: val_loss did not improve from 0.09763
# Epoch 496/50000
#
# Epoch 00496: val_loss did not improve from 0.09763
# Epoch 497/50000
#
# Epoch 00497: val_loss did not improve from 0.09763
# Epoch 498/50000
#
# Epoch 00498: val_loss did not improve from 0.09763
# Epoch 499/50000
#
# Epoch 00499: val_loss did not improve from 0.09763
# Epoch 500/50000
#
# Epoch 00500: val_loss did not improve from 0.09763
# Epoch 501/50000
#
# Epoch 00501: val_loss did not improve from 0.09763
# Epoch 502/50000
#
# Epoch 00502: val_loss did not improve from 0.09763
# Epoch 503/50000
#
# Epoch 00503: val_loss did not improve from 0.09763
# Epoch 504/50000
#
# Epoch 00504: val_loss did not improve from 0.09763
# Epoch 505/50000
#
# Epoch 00505: val_loss did not improve from 0.09763
# Epoch 506/50000
#
# Epoch 00506: val_loss did not improve from 0.09763
# Epoch 507/50000
#
# Epoch 00507: val_loss did not improve from 0.09763
# Epoch 508/50000
#
# Epoch 00508: val_loss did not improve from 0.09763
# Epoch 509/50000
#
# Epoch 00509: val_loss did not improve from 0.09763
# Epoch 510/50000
#
# Epoch 00510: val_loss did not improve from 0.09763
# Epoch 511/50000
#
# Epoch 00511: val_loss did not improve from 0.09763
# Epoch 512/50000
#
# Epoch 00512: val_loss did not improve from 0.09763
# Epoch 513/50000
#
# Epoch 00513: val_loss did not improve from 0.09763
# Epoch 514/50000
#
# Epoch 00514: val_loss did not improve from 0.09763
# Epoch 515/50000
#
# Epoch 00515: val_loss did not improve from 0.09763
# Epoch 516/50000
#
# Epoch 00516: val_loss did not improve from 0.09763
# Epoch 517/50000
#
# Epoch 00517: val_loss did not improve from 0.09763
# Epoch 518/50000
#
# Epoch 00518: val_loss did not improve from 0.09763
# Epoch 519/50000
#
# Epoch 00519: val_loss did not improve from 0.09763
# Epoch 520/50000
#
# Epoch 00520: val_loss did not improve from 0.09763
# Epoch 521/50000
#
# Epoch 00521: val_loss did not improve from 0.09763
# Epoch 522/50000
#
# Epoch 00522: val_loss did not improve from 0.09763
# Epoch 523/50000
#
# Epoch 00523: val_loss did not improve from 0.09763
# Epoch 524/50000
#
# Epoch 00524: val_loss did not improve from 0.09763
# Epoch 525/50000
#
# Epoch 00525: val_loss did not improve from 0.09763
# Epoch 526/50000
#
# Epoch 00526: val_loss did not improve from 0.09763
# Epoch 527/50000
#
# Epoch 00527: val_loss did not improve from 0.09763
# Epoch 528/50000
#
# Epoch 00528: val_loss did not improve from 0.09763
# Epoch 529/50000
#
# Epoch 00529: val_loss did not improve from 0.09763
# Epoch 530/50000
#
# Epoch 00530: val_loss did not improve from 0.09763
# Epoch 531/50000
#
# Epoch 00531: val_loss did not improve from 0.09763
# Epoch 532/50000
#
# Epoch 00532: val_loss did not improve from 0.09763
# Epoch 533/50000
#
# Epoch 00533: val_loss did not improve from 0.09763
# Epoch 534/50000
#
# Epoch 00534: val_loss did not improve from 0.09763
# Epoch 535/50000
#
# Epoch 00535: val_loss did not improve from 0.09763
# Epoch 536/50000
#
# Epoch 00536: val_loss did not improve from 0.09763
# Epoch 537/50000
#
# Epoch 00537: val_loss did not improve from 0.09763
# Epoch 538/50000
#
# Epoch 00538: val_loss did not improve from 0.09763
# Epoch 539/50000
#
# Epoch 00539: val_loss did not improve from 0.09763
# Epoch 540/50000
#
# Epoch 00540: val_loss did not improve from 0.09763
# Epoch 541/50000
#
# Epoch 00541: val_loss did not improve from 0.09763
# Epoch 542/50000
#
# Epoch 00542: val_loss did not improve from 0.09763
# Epoch 543/50000
#
# Epoch 00543: val_loss did not improve from 0.09763
# Epoch 544/50000
#
# Epoch 00544: val_loss did not improve from 0.09763
# Epoch 545/50000
#
# Epoch 00545: val_loss did not improve from 0.09763
# Epoch 546/50000
#
# Epoch 00546: val_loss did not improve from 0.09763
# Epoch 547/50000
#
# Epoch 00547: val_loss did not improve from 0.09763
# Epoch 548/50000
#
# Epoch 00548: val_loss did not improve from 0.09763
# Epoch 549/50000
#
# Epoch 00549: val_loss did not improve from 0.09763
# Epoch 550/50000
#
# Epoch 00550: val_loss did not improve from 0.09763
# Epoch 551/50000
#
# Epoch 00551: val_loss did not improve from 0.09763
# Epoch 552/50000
#
# Epoch 00552: val_loss did not improve from 0.09763
# Epoch 553/50000
#
# Epoch 00553: val_loss did not improve from 0.09763
# Epoch 554/50000
#
# Epoch 00554: val_loss did not improve from 0.09763
# Epoch 555/50000
#
# Epoch 00555: val_loss did not improve from 0.09763
# Epoch 556/50000
#
# Epoch 00556: val_loss did not improve from 0.09763
# Epoch 557/50000
#
# Epoch 00557: val_loss did not improve from 0.09763
# Epoch 558/50000
#
# Epoch 00558: val_loss did not improve from 0.09763
# Epoch 559/50000
#
# Epoch 00559: val_loss did not improve from 0.09763
# Epoch 560/50000
#
# Epoch 00560: val_loss did not improve from 0.09763
# Epoch 561/50000
#
# Epoch 00561: val_loss did not improve from 0.09763
# Epoch 562/50000
#
# Epoch 00562: val_loss did not improve from 0.09763
# Epoch 563/50000
#
# Epoch 00563: val_loss did not improve from 0.09763
# Epoch 564/50000
#
# Epoch 00564: val_loss did not improve from 0.09763
# Epoch 565/50000
#
# Epoch 00565: val_loss did not improve from 0.09763
# Epoch 566/50000
#
# Epoch 00566: val_loss did not improve from 0.09763
# Epoch 567/50000
#
# Epoch 00567: val_loss did not improve from 0.09763
# Epoch 568/50000
#
# Epoch 00568: val_loss did not improve from 0.09763
# Epoch 569/50000
#
# Epoch 00569: val_loss did not improve from 0.09763
# Epoch 570/50000
#
# Epoch 00570: val_loss did not improve from 0.09763
# Epoch 571/50000
#
# Epoch 00571: val_loss did not improve from 0.09763
# Epoch 572/50000
#
# Epoch 00572: val_loss did not improve from 0.09763
# Epoch 573/50000
#
# Epoch 00573: val_loss did not improve from 0.09763
# Epoch 574/50000
#
# Epoch 00574: val_loss did not improve from 0.09763
# Epoch 575/50000
#
# Epoch 00575: val_loss did not improve from 0.09763
# Epoch 576/50000
#
# Epoch 00576: val_loss did not improve from 0.09763
# Epoch 577/50000
#
# Epoch 00577: val_loss did not improve from 0.09763
# Epoch 578/50000
#
# Epoch 00578: val_loss did not improve from 0.09763
# Epoch 579/50000
#
# Epoch 00579: val_loss did not improve from 0.09763
# Epoch 580/50000
#
# Epoch 00580: val_loss did not improve from 0.09763
# Epoch 581/50000
#
# Epoch 00581: val_loss did not improve from 0.09763
# Epoch 582/50000
#
# Epoch 00582: val_loss did not improve from 0.09763
# Epoch 583/50000
#
# Epoch 00583: val_loss did not improve from 0.09763
# Epoch 584/50000
#
# Epoch 00584: val_loss did not improve from 0.09763
# Epoch 585/50000
#
# Epoch 00585: val_loss did not improve from 0.09763
# Epoch 586/50000
#
# Epoch 00586: val_loss did not improve from 0.09763
# Epoch 587/50000
#
# Epoch 00587: val_loss did not improve from 0.09763
# Epoch 588/50000
#
# Epoch 00588: val_loss did not improve from 0.09763
# Epoch 589/50000
#
# Epoch 00589: val_loss did not improve from 0.09763
# Epoch 590/50000
#
# Epoch 00590: val_loss did not improve from 0.09763
# Epoch 591/50000
#
# Epoch 00591: val_loss did not improve from 0.09763
# Epoch 592/50000
#
# Epoch 00592: val_loss did not improve from 0.09763
# Epoch 593/50000
#
# Epoch 00593: val_loss did not improve from 0.09763
# Epoch 594/50000
#
# Epoch 00594: val_loss did not improve from 0.09763
# Epoch 595/50000
#
# Epoch 00595: val_loss did not improve from 0.09763
# Epoch 596/50000
#
# Epoch 00596: val_loss did not improve from 0.09763
# Epoch 597/50000
#
# Epoch 00597: val_loss did not improve from 0.09763
# Epoch 598/50000
#
# Epoch 00598: val_loss did not improve from 0.09763
# Epoch 599/50000
#
# Epoch 00599: val_loss did not improve from 0.09763
# Epoch 600/50000
#
# Epoch 00600: val_loss did not improve from 0.09763
# Epoch 601/50000
#
# Epoch 00601: val_loss did not improve from 0.09763
# Epoch 602/50000
#
# Epoch 00602: val_loss did not improve from 0.09763
# Epoch 603/50000
#
# Epoch 00603: val_loss did not improve from 0.09763
# Epoch 604/50000
#
# Epoch 00604: val_loss did not improve from 0.09763
# Epoch 605/50000
#
# Epoch 00605: val_loss did not improve from 0.09763
# Epoch 606/50000
#
# Epoch 00606: val_loss did not improve from 0.09763
# Epoch 607/50000
#
# Epoch 00607: val_loss did not improve from 0.09763
# Epoch 608/50000
#
# Epoch 00608: val_loss did not improve from 0.09763
# Epoch 609/50000
#
# Epoch 00609: val_loss did not improve from 0.09763
# Epoch 610/50000
#
# Epoch 00610: val_loss did not improve from 0.09763
# Epoch 611/50000
#
# Epoch 00611: val_loss did not improve from 0.09763
# Epoch 612/50000
#
# Epoch 00612: val_loss did not improve from 0.09763
# Epoch 613/50000
#
# Epoch 00613: val_loss did not improve from 0.09763
# Epoch 614/50000
#
# Epoch 00614: val_loss did not improve from 0.09763
# Epoch 615/50000
#
# Epoch 00615: val_loss did not improve from 0.09763
# Epoch 616/50000
#
# Epoch 00616: val_loss did not improve from 0.09763
# Epoch 617/50000
#
# Epoch 00617: val_loss did not improve from 0.09763
# Epoch 618/50000
#
# Epoch 00618: val_loss did not improve from 0.09763
# Epoch 619/50000
#
# Epoch 00619: val_loss did not improve from 0.09763
# Epoch 620/50000
# Epoch 00620: val_loss did not improve from 0.09763
# Epoch 621/50000
#
# Epoch 00621: val_loss did not improve from 0.09763
# Epoch 622/50000
#
# Epoch 00622: val_loss did not improve from 0.09763
# Epoch 623/50000
#
# Epoch 00623: val_loss did not improve from 0.09763
# Epoch 624/50000
#
# Epoch 00624: val_loss did not improve from 0.09763
# Epoch 625/50000
#
# Epoch 00625: val_loss did not improve from 0.09763
# Epoch 626/50000
#
# Epoch 00626: val_loss did not improve from 0.09763
# Epoch 627/50000
#
# Epoch 00627: val_loss did not improve from 0.09763
# Epoch 628/50000
#
# Epoch 00628: val_loss did not improve from 0.09763
# Epoch 629/50000
#
# Epoch 00629: val_loss did not improve from 0.09763
# Epoch 630/50000
#
# Epoch 00630: val_loss did not improve from 0.09763
# Epoch 631/50000
#
# Epoch 00631: val_loss did not improve from 0.09763
# Epoch 632/50000
#
# Epoch 00632: val_loss did not improve from 0.09763
# Epoch 633/50000
#
# Epoch 00633: val_loss did not improve from 0.09763
# Epoch 634/50000
#
# Epoch 00634: val_loss did not improve from 0.09763
# Epoch 635/50000
#
# Epoch 00635: val_loss did not improve from 0.09763
# Epoch 636/50000
#
# Epoch 00636: val_loss did not improve from 0.09763
# Epoch 637/50000
#
# Epoch 00637: val_loss did not improve from 0.09763
# Epoch 638/50000
#
# Epoch 00638: val_loss did not improve from 0.09763
# Epoch 639/50000
#
# Epoch 00639: val_loss did not improve from 0.09763
# Epoch 640/50000
#
# Epoch 00640: val_loss did not improve from 0.09763
# Epoch 641/50000
#
# Epoch 00641: val_loss did not improve from 0.09763
# Epoch 642/50000
#
# Epoch 00642: val_loss did not improve from 0.09763
# Epoch 643/50000
#
# Epoch 00643: val_loss did not improve from 0.09763
# Epoch 644/50000
#
# Epoch 00644: val_loss did not improve from 0.09763
# Epoch 645/50000
#
# Epoch 00645: val_loss did not improve from 0.09763
# Epoch 646/50000
#
# Epoch 00646: val_loss did not improve from 0.09763
# Epoch 647/50000
#
# Epoch 00647: val_loss did not improve from 0.09763
# Epoch 648/50000
#
# Epoch 00648: val_loss did not improve from 0.09763
# Epoch 649/50000
#
# Epoch 00649: val_loss did not improve from 0.09763
# Epoch 650/50000
#
# Epoch 00650: val_loss did not improve from 0.09763
# Epoch 651/50000
#
# Epoch 00651: val_loss did not improve from 0.09763
# Epoch 652/50000
#
# Epoch 00652: val_loss did not improve from 0.09763
# Epoch 653/50000
#
# Epoch 00653: val_loss did not improve from 0.09763
# Epoch 654/50000
#
# Epoch 00654: val_loss did not improve from 0.09763
# Epoch 655/50000
#
# Epoch 00655: val_loss did not improve from 0.09763
# Epoch 656/50000
#
# Epoch 00656: val_loss did not improve from 0.09763
# Epoch 657/50000
#
# Epoch 00657: val_loss did not improve from 0.09763
# Epoch 658/50000
#
# Epoch 00658: val_loss did not improve from 0.09763
# Epoch 659/50000
#
# Epoch 00659: val_loss did not improve from 0.09763
# Epoch 660/50000
#
# Epoch 00660: val_loss did not improve from 0.09763
# Epoch 661/50000
#
# Epoch 00661: val_loss did not improve from 0.09763
# Epoch 662/50000
#
# Epoch 00662: val_loss did not improve from 0.09763
# Epoch 663/50000
#
# Epoch 00663: val_loss did not improve from 0.09763
# Epoch 664/50000
#
# Epoch 00664: val_loss did not improve from 0.09763
# Epoch 665/50000
#
# Epoch 00665: val_loss did not improve from 0.09763
# Epoch 666/50000
#
# Epoch 00666: val_loss did not improve from 0.09763
# Epoch 667/50000
#
# Epoch 00667: val_loss did not improve from 0.09763
# Epoch 668/50000
#
# Epoch 00668: val_loss did not improve from 0.09763
# Epoch 669/50000
#
# Epoch 00669: val_loss did not improve from 0.09763
# Epoch 670/50000
#
# Epoch 00670: val_loss did not improve from 0.09763
# Epoch 671/50000
#
# Epoch 00671: val_loss did not improve from 0.09763
# Epoch 672/50000
#
# Epoch 00672: val_loss did not improve from 0.09763
# Epoch 673/50000
#
# Epoch 00673: val_loss did not improve from 0.09763
# Epoch 674/50000
#
# Epoch 00674: val_loss did not improve from 0.09763
# Epoch 675/50000
#
# Epoch 00675: val_loss did not improve from 0.09763
# Epoch 676/50000
#
# Epoch 00676: val_loss did not improve from 0.09763
# Epoch 677/50000
#
# Epoch 00677: val_loss did not improve from 0.09763
# Epoch 678/50000
#
# Epoch 00678: val_loss did not improve from 0.09763
# Epoch 679/50000
#
# Epoch 00679: val_loss did not improve from 0.09763
# Epoch 680/50000
#
# Epoch 00680: val_loss did not improve from 0.09763
# Epoch 681/50000
#
# Epoch 00681: val_loss did not improve from 0.09763
# Epoch 682/50000
#
# Epoch 00682: val_loss did not improve from 0.09763
# Epoch 683/50000
#
# Epoch 00683: val_loss did not improve from 0.09763
# Epoch 684/50000
#
# Epoch 00684: val_loss did not improve from 0.09763
# Epoch 685/50000
#
# Epoch 00685: val_loss did not improve from 0.09763
# Epoch 686/50000
#
# Epoch 00686: val_loss did not improve from 0.09763
# Epoch 687/50000
#
# Epoch 00687: val_loss did not improve from 0.09763
# Epoch 688/50000
#
# Epoch 00688: val_loss did not improve from 0.09763
# Epoch 689/50000
#
# Epoch 00689: val_loss did not improve from 0.09763
# Epoch 690/50000
#
# Epoch 00690: val_loss did not improve from 0.09763
# Epoch 691/50000
#
# Epoch 00691: val_loss did not improve from 0.09763
# Epoch 692/50000
#
# Epoch 00692: val_loss did not improve from 0.09763
# Epoch 693/50000
#
# Epoch 00693: val_loss did not improve from 0.09763
# Epoch 694/50000
#
# Epoch 00694: val_loss did not improve from 0.09763
# Epoch 695/50000
#
# Epoch 00695: val_loss did not improve from 0.09763
# Epoch 696/50000
#
# Epoch 00696: val_loss did not improve from 0.09763
# Epoch 697/50000
#
# Epoch 00697: val_loss did not improve from 0.09763
# Epoch 698/50000
#
# Epoch 00698: val_loss did not improve from 0.09763
# Epoch 699/50000
#
# ...
# Epoch 21049/50000
#
# Epoch 21049: val_loss did not improve from 0.08850
# Epoch 21050/50000
#
# Epoch 21050: val_loss did not improve from 0.08850
# Epoch 21051/50000
#
# Epoch 21051: val_loss did not improve from 0.08850
# Epoch 21052/50000
#
# Epoch 21052: val_loss did not improve from 0.08850
# Epoch 21053/50000
#
# Epoch 21053: val_loss did not improve from 0.08850
# Epoch 21054/50000
#
# Epoch 21054: val_loss did not improve from 0.08850
# Epoch 21055/50000
#
# Epoch 21055: val_loss did not improve from 0.08850
# Epoch 21056/50000
#
# Epoch 21056: val_loss did not improve from 0.08850
# Epoch 21057/50000
# Epoch 21057: val_loss did not improve from 0.08850
# Epoch 21058/50000
#
# Epoch 21058: val_loss did not improve from 0.08850
# Epoch 21059/50000
#
# Epoch 21059: val_loss did not improve from 0.08850
# Epoch 21060/50000
#
# Epoch 21060: val_loss did not improve from 0.08850
# Epoch 21061/50000
#
# Epoch 21061: val_loss did not improve from 0.08850
# Epoch 21062/50000
#
# Epoch 21062: val_loss did not improve from 0.08850
# Epoch 21063/50000
#
# Epoch 21063: val_loss did not improve from 0.08850
# Epoch 21064/50000
#
# Epoch 21064: val_loss did not improve from 0.08850
# Epoch 21065/50000
#
# Epoch 21065: val_loss did not improve from 0.08850
# Epoch 21066/50000
#
# Epoch 21066: val_loss did not improve from 0.08850
# Epoch 21067/50000
#
# Epoch 21067: val_loss did not improve from 0.08850
# Epoch 21068/50000
#
# Epoch 21068: val_loss did not improve from 0.08850
# Epoch 21069/50000
#
# Epoch 21069: val_loss did not improve from 0.08850
# Epoch 21070/50000
#
# Epoch 21070: val_loss did not improve from 0.08850
# Epoch 21071/50000
#
# Epoch 21071: val_loss did not improve from 0.08850
# Epoch 21072/50000
#
# Epoch 21072: val_loss did not improve from 0.08850
# Epoch 21073/50000
#
# Epoch 21073: val_loss did not improve from 0.08850
# Epoch 21074/50000
#
# Epoch 21074: val_loss did not improve from 0.08850
# Epoch 21075/50000
#
# Epoch 21075: val_loss did not improve from 0.08850
# Epoch 21076/50000
#
# Epoch 21076: val_loss did not improve from 0.08850
# Epoch 21077/50000
#
# Epoch 21077: val_loss did not improve from 0.08850
# Epoch 21078/50000
#
# Epoch 21078: val_loss did not improve from 0.08850
# Epoch 21079/50000
#
# Epoch 21079: val_loss did not improve from 0.08850
# Epoch 21080/50000
#
# Epoch 21080: val_loss did not improve from 0.08850
# Epoch 21081/50000
#
# Epoch 21081: val_loss did not improve from 0.08850
# Epoch 21082/50000
#
# Epoch 21082: val_loss did not improve from 0.08850
# Epoch 21083/50000
#
# Epoch 21083: val_loss did not improve from 0.08850
# Epoch 21084/50000
#
# Epoch 21084: val_loss did not improve from 0.08850
# Epoch 21085/50000
#
# Epoch 21085: val_loss did not improve from 0.08850
# Epoch 21086/50000
#
# Epoch 21086: val_loss did not improve from 0.08850
# Epoch 21087/50000
#
# Epoch 21087: val_loss did not improve from 0.08850
# Epoch 21088/50000
#
# Epoch 21088: val_loss did not improve from 0.08850
# Epoch 21089/50000
#
# Epoch 21089: val_loss did not improve from 0.08850
# Epoch 21090/50000
#
# Epoch 21090: val_loss did not improve from 0.08850
# Epoch 21091/50000
#
# Epoch 21091: val_loss did not improve from 0.08850
# Epoch 21092/50000
#
# Epoch 21092: val_loss did not improve from 0.08850
# Epoch 21093/50000
#
# Epoch 21093: val_loss did not improve from 0.08850
# Epoch 21094/50000
#
# Epoch 21094: val_loss did not improve from 0.08850
# Epoch 21095/50000
#
# Epoch 21095: val_loss did not improve from 0.08850
# Epoch 21096/50000
#
# Epoch 21096: val_loss did not improve from 0.08850
# Epoch 21097/50000
#
# Epoch 21097: val_loss did not improve from 0.08850
# Epoch 21098/50000
#
# Epoch 21098: val_loss did not improve from 0.08850
# Epoch 21099/50000
#
# Epoch 21099: val_loss did not improve from 0.08850
# Epoch 21100/50000
#
# Epoch 21100: val_loss did not improve from 0.08850
# Epoch 21101/50000
#
# Epoch 21101: val_loss did not improve from 0.08850
# Epoch 21102/50000
#
# Epoch 21102: val_loss did not improve from 0.08850
# Epoch 21103/50000
#
# Epoch 21103: val_loss did not improve from 0.08850
# Epoch 21104/50000
#
# Epoch 21104: val_loss did not improve from 0.08850
# Epoch 21105/50000
#
# Epoch 21105: val_loss did not improve from 0.08850
# Epoch 21106/50000
#
# Epoch 21106: val_loss did not improve from 0.08850
# Epoch 21107/50000
#
# Epoch 21107: val_loss did not improve from 0.08850
# Epoch 21108/50000
#
# Epoch 21108: val_loss did not improve from 0.08850
# Epoch 21109/50000
#
# Epoch 21109: val_loss did not improve from 0.08850
# Epoch 21110/50000
#
# Epoch 21110: val_loss did not improve from 0.08850
# Epoch 21111/50000
#
# Epoch 21111: val_loss did not improve from 0.08850
# Epoch 21112/50000
#
# Epoch 21112: val_loss did not improve from 0.08850
# Epoch 21113/50000
#
# Epoch 21113: val_loss did not improve from 0.08850
# Epoch 21114/50000
#
# Epoch 21114: val_loss did not improve from 0.08850
# Epoch 21115/50000
#
# Epoch 21115: val_loss did not improve from 0.08850
# Epoch 21116/50000
#
# Epoch 21116: val_loss did not improve from 0.08850
# Epoch 21117/50000
#
# Epoch 21117: val_loss did not improve from 0.08850
# Epoch 21118/50000
#
# Epoch 21118: val_loss did not improve from 0.08850
# Epoch 21119/50000
#
# Epoch 21119: val_loss did not improve from 0.08850
# Epoch 21120/50000
#
# Epoch 21120: val_loss did not improve from 0.08850
# Epoch 21121/50000
#
# Epoch 21121: val_loss did not improve from 0.08850
# Epoch 21122/50000
#
# Epoch 21122: val_loss did not improve from 0.08850
# Epoch 21123/50000
#
# Epoch 21123: val_loss did not improve from 0.08850
# Epoch 21124/50000
#
# Epoch 21124: val_loss did not improve from 0.08850
# Epoch 21125/50000
#
# Epoch 21125: val_loss did not improve from 0.08850
# Epoch 21126/50000
#
# Epoch 21126: val_loss did not improve from 0.08850
# Epoch 21127/50000
#
# Epoch 21127: val_loss did not improve from 0.08850
# Epoch 21128/50000
#
# Epoch 21128: val_loss did not improve from 0.08850
# Epoch 21129/50000
#
# Epoch 21129: val_loss did not improve from 0.08850
# Epoch 21130/50000
#
# Epoch 21130: val_loss did not improve from 0.08850
# Epoch 21131/50000
#
# Epoch 21131: val_loss did not improve from 0.08850
# Epoch 21132/50000
#
# Epoch 21132: val_loss did not improve from 0.08850
# Epoch 21133/50000
#
# Epoch 21133: val_loss did not improve from 0.08850
# Epoch 21134/50000
#
# Epoch 21134: val_loss did not improve from 0.08850
# Epoch 21135/50000
#
# Epoch 21135: val_loss did not improve from 0.08850
# Epoch 21136/50000
#
# Epoch 21136: val_loss did not improve from 0.08850
# Epoch 21137/50000
#
# Epoch 21137: val_loss did not improve from 0.08850
# Epoch 21138/50000
#
# Epoch 21138: val_loss did not improve from 0.08850
# Epoch 21139/50000
#
# Epoch 21139: val_loss did not improve from 0.08850
# Epoch 21140/50000
#
# Epoch 21140: val_loss did not improve from 0.08850
# Epoch 21141/50000
#
# Epoch 21141: val_loss did not improve from 0.08850
# Epoch 21142/50000
#
# Epoch 21142: val_loss did not improve from 0.08850
# Epoch 21143/50000
#
# Epoch 21143: val_loss did not improve from 0.08850
# Epoch 21144/50000
#
# Epoch 21144: val_loss did not improve from 0.08850
# Epoch 21145/50000
#
# Epoch 21145: val_loss did not improve from 0.08850
# Epoch 21146/50000
#
# Epoch 21146: val_loss did not improve from 0.08850
# Epoch 21147/50000
#
# Epoch 21147: val_loss did not improve from 0.08850
# Epoch 21148/50000
#
# Epoch 21148: val_loss did not improve from 0.08850
# Epoch 21149/50000
#
# Epoch 21149: val_loss did not improve from 0.08850
# Epoch 21150/50000
#
# Epoch 21150: val_loss did not improve from 0.08850
# Epoch 21151/50000
#
# Epoch 21151: val_loss did not improve from 0.08850
# Epoch 21152/50000
#
# Epoch 21152: val_loss did not improve from 0.08850
# Epoch 21153/50000
#
# Epoch 21153: val_loss did not improve from 0.08850
# Epoch 21154/50000
#
# Epoch 21154: val_loss did not improve from 0.08850
# Epoch 21155/50000
#
# Epoch 21155: val_loss did not improve from 0.08850
# Epoch 21156/50000
#
# Epoch 21156: val_loss did not improve from 0.08850
# Epoch 21157/50000
#
# Epoch 21157: val_loss did not improve from 0.08850
# Epoch 21158/50000
#
# Epoch 21158: val_loss did not improve from 0.08850
# Epoch 21159/50000
#
# Epoch 21159: val_loss did not improve from 0.08850
# Epoch 21160/50000
#
# Epoch 21160: val_loss did not improve from 0.08850
# Epoch 21161/50000
#
# Epoch 21161: val_loss did not improve from 0.08850
# Epoch 21162/50000
#
# Epoch 21162: val_loss did not improve from 0.08850
# Epoch 21163/50000
#
# Epoch 21163: val_loss did not improve from 0.08850
# Epoch 21164/50000
#
# Epoch 21164: val_loss did not improve from 0.08850
# Epoch 21165/50000
#
# Epoch 21165: val_loss did not improve from 0.08850
# Epoch 21166/50000
#
# Epoch 21166: val_loss did not improve from 0.08850
# Epoch 21167/50000
#
# Epoch 21167: val_loss did not improve from 0.08850
# Epoch 21168/50000
#
# Epoch 21168: val_loss did not improve from 0.08850
# Epoch 21169/50000
#
# Epoch 21169: val_loss did not improve from 0.08850
# Epoch 21170/50000
#
# Epoch 21170: val_loss did not improve from 0.08850
# Epoch 21171/50000
#
# Epoch 21171: val_loss did not improve from 0.08850
# Epoch 21172/50000
#
# Epoch 21172: val_loss did not improve from 0.08850
# Epoch 21173/50000
#
# Epoch 21173: val_loss did not improve from 0.08850
# Epoch 21174/50000
#
# Epoch 21174: val_loss did not improve from 0.08850
# Epoch 21175/50000
#
# Epoch 21175: val_loss did not improve from 0.08850
# Epoch 21176/50000
#
# Epoch 21176: val_loss did not improve from 0.08850
# Epoch 21177/50000
#
# Epoch 21177: val_loss did not improve from 0.08850
# Epoch 21178/50000
#
# Epoch 21178: val_loss did not improve from 0.08850
# Epoch 21179/50000
#
# Epoch 21179: val_loss did not improve from 0.08850
# Epoch 21180/50000
#
# Epoch 21180: val_loss did not improve from 0.08850
# Epoch 21181/50000
#
# Epoch 21181: val_loss did not improve from 0.08850
# Epoch 21182/50000
#
# Epoch 21182: val_loss did not improve from 0.08850
# Epoch 21183/50000
# Epoch 21183: val_loss did not improve from 0.08850
# Epoch 21184/50000
#
# Epoch 21184: val_loss did not improve from 0.08850
# Epoch 21185/50000
#
# Epoch 21185: val_loss did not improve from 0.08850
# Epoch 21186/50000
#
# Epoch 21186: val_loss did not improve from 0.08850
# Epoch 21187/50000
#
# Epoch 21187: val_loss did not improve from 0.08850
# Epoch 21188/50000
#
# Epoch 21188: val_loss did not improve from 0.08850
# Epoch 21189/50000
#
# Epoch 21189: val_loss did not improve from 0.08850
# Epoch 21190/50000
#
# Epoch 21190: val_loss did not improve from 0.08850
# Epoch 21191/50000
#
# Epoch 21191: val_loss did not improve from 0.08850
# Epoch 21192/50000
#
# Epoch 21192: val_loss did not improve from 0.08850
# Epoch 21193/50000
#
# Epoch 21193: val_loss did not improve from 0.08850
# Epoch 21194/50000
#
# Epoch 21194: val_loss did not improve from 0.08850
# Epoch 21195/50000
#
# Epoch 21195: val_loss did not improve from 0.08850
# Epoch 21196/50000
#
# Epoch 21196: val_loss did not improve from 0.08850
# Epoch 21197/50000
#
# Epoch 21197: val_loss did not improve from 0.08850
# Epoch 21198/50000
#
# Epoch 21198: val_loss did not improve from 0.08850
# Epoch 21199/50000
#
# Epoch 21199: val_loss did not improve from 0.08850
# Epoch 21200/50000
#
# Epoch 21200: val_loss did not improve from 0.08850
# Epoch 21201/50000
#
# Epoch 21201: val_loss did not improve from 0.08850
# Epoch 21202/50000
#
# Epoch 21202: val_loss did not improve from 0.08850
# Epoch 21203/50000
#
# Epoch 21203: val_loss did not improve from 0.08850
# Epoch 21204/50000
#
# Epoch 21204: val_loss did not improve from 0.08850
# Epoch 21205/50000
#
# Epoch 21205: val_loss did not improve from 0.08850
# Epoch 21206/50000
#
# Epoch 21206: val_loss did not improve from 0.08850
# Epoch 21207/50000
#
# Epoch 21207: val_loss did not improve from 0.08850
# Epoch 21208/50000
#
# Epoch 21208: val_loss did not improve from 0.08850
# Epoch 21209/50000
#
# Epoch 21209: val_loss did not improve from 0.08850
# Epoch 21210/50000
#
# Epoch 21210: val_loss did not improve from 0.08850
# Epoch 21211/50000
#
# Epoch 21211: val_loss did not improve from 0.08850
# Epoch 21212/50000
#
# Epoch 21212: val_loss did not improve from 0.08850
# Epoch 21213/50000
#
# Epoch 21213: val_loss did not improve from 0.08850
# Epoch 21214/50000
#
# Epoch 21214: val_loss did not improve from 0.08850
# Epoch 21215/50000
#
# Epoch 21215: val_loss did not improve from 0.08850
# Epoch 21216/50000
#
# Epoch 21216: val_loss did not improve from 0.08850
# Epoch 21217/50000
#
# Epoch 21217: val_loss did not improve from 0.08850
# Epoch 21218/50000
#
# Epoch 21218: val_loss did not improve from 0.08850
# Epoch 21219/50000
#
# Epoch 21219: val_loss did not improve from 0.08850
# Epoch 21220/50000
#
# Epoch 21220: val_loss did not improve from 0.08850
# Epoch 21221/50000
#
# Epoch 21221: val_loss did not improve from 0.08850
# Epoch 21222/50000
#
# Epoch 21222: val_loss did not improve from 0.08850
# Epoch 21223/50000
#
# Epoch 21223: val_loss did not improve from 0.08850
# Epoch 21224/50000
#
# Epoch 21224: val_loss did not improve from 0.08850
# Epoch 21225/50000
#
# Epoch 21225: val_loss did not improve from 0.08850
# Epoch 21226/50000
#
# Epoch 21226: val_loss did not improve from 0.08850
# Epoch 21227/50000
#
# Epoch 21227: val_loss did not improve from 0.08850
# Epoch 21228/50000
#
# Epoch 21228: val_loss did not improve from 0.08850
# Epoch 21229/50000
#
# Epoch 21229: val_loss did not improve from 0.08850
# Epoch 21230/50000
#
# Epoch 21230: val_loss did not improve from 0.08850
# Epoch 21231/50000
#
# Epoch 21231: val_loss did not improve from 0.08850
# Epoch 21232/50000
#
# Epoch 21232: val_loss did not improve from 0.08850
# Epoch 21233/50000
#
# Epoch 21233: val_loss did not improve from 0.08850
# Epoch 21234/50000
#
# Epoch 21234: val_loss did not improve from 0.08850
# Epoch 21235/50000
#
# Epoch 21235: val_loss did not improve from 0.08850
# Epoch 21236/50000
#
# Epoch 21236: val_loss did not improve from 0.08850
# Epoch 21237/50000
#
# Epoch 21237: val_loss did not improve from 0.08850
# Epoch 21238/50000
#
# Epoch 21238: val_loss did not improve from 0.08850
# Epoch 21239/50000
#
# Epoch 21239: val_loss did not improve from 0.08850
# Epoch 21240/50000
#
# Epoch 21240: val_loss did not improve from 0.08850
# Epoch 21241/50000
#
# Epoch 21241: val_loss did not improve from 0.08850
# Epoch 21242/50000
#
# Epoch 21242: val_loss did not improve from 0.08850
# Epoch 21243/50000
#
# Epoch 21243: val_loss did not improve from 0.08850
# Epoch 21244/50000
#
# Epoch 21244: val_loss did not improve from 0.08850
# Epoch 21245/50000
#
# Epoch 21245: val_loss did not improve from 0.08850
# Epoch 21246/50000
#
# Epoch 21246: val_loss did not improve from 0.08850
# Epoch 21247/50000
#
# Epoch 21247: val_loss did not improve from 0.08850
# Epoch 21248/50000
#
# Epoch 21248: val_loss did not improve from 0.08850
# Epoch 21249/50000
#
# Epoch 21249: val_loss did not improve from 0.08850
# Epoch 21250/50000
#
# Epoch 21250: val_loss did not improve from 0.08850
# Epoch 21251/50000
#
# Epoch 21251: val_loss did not improve from 0.08850
# Epoch 21252/50000
#
# Epoch 21252: val_loss did not improve from 0.08850
# Epoch 21253/50000
#
# Epoch 21253: val_loss did not improve from 0.08850
# Epoch 21254/50000
#
# Epoch 21254: val_loss did not improve from 0.08850
# Epoch 21255/50000
#
# Epoch 21255: val_loss did not improve from 0.08850
# Epoch 21256/50000
#
# Epoch 21256: val_loss did not improve from 0.08850
# Epoch 21257/50000
#
# Epoch 21257: val_loss did not improve from 0.08850
# Epoch 21258/50000
#
# Epoch 21258: val_loss did not improve from 0.08850
# Epoch 21259/50000
#
# Epoch 21259: val_loss did not improve from 0.08850
# Epoch 21260/50000
#
# Epoch 21260: val_loss did not improve from 0.08850
# Epoch 21261/50000
#
# Epoch 21261: val_loss did not improve from 0.08850
# Epoch 21262/50000
#
# Epoch 21262: val_loss did not improve from 0.08850
# Epoch 21263/50000
#
# Epoch 21263: val_loss did not improve from 0.08850
# Epoch 21264/50000
#
# Epoch 21264: val_loss did not improve from 0.08850
# Epoch 21265/50000
#
# Epoch 21265: val_loss did not improve from 0.08850
# Epoch 21266/50000
#
# Epoch 21266: val_loss did not improve from 0.08850
# Epoch 21267/50000
#
# Epoch 21267: val_loss did not improve from 0.08850
# Epoch 21268/50000
#
# Epoch 21268: val_loss did not improve from 0.08850
# Epoch 21269/50000
#
# Epoch 21269: val_loss did not improve from 0.08850
# Epoch 21270/50000
#
# Epoch 21270: val_loss did not improve from 0.08850
# Epoch 21271/50000
#
# Epoch 21271: val_loss did not improve from 0.08850
# Epoch 21272/50000
#
# Epoch 21272: val_loss did not improve from 0.08850
# Epoch 21273/50000
#
# Epoch 21273: val_loss did not improve from 0.08850
# Epoch 21274/50000
#
# Epoch 21274: val_loss did not improve from 0.08850
# Epoch 21275/50000
#
# Epoch 21275: val_loss did not improve from 0.08850
# Epoch 21276/50000
#
# Epoch 21276: val_loss did not improve from 0.08850

# %%
df_hist = pd.DataFrame(hist.history)
df_hist.plot(subplots=True, figsize=(15,15))
print(df_hist['val_loss'].min())
df_hist[df_hist['val_loss']<=0.1054]
# Out:
# 0.08850246667861938
#        val_loss      loss
# 7      0.104097  0.130967
# 24     0.103807  0.148132
# 29     0.104791  0.125098
# 38     0.102731  0.125499
# 44     0.102255  0.126362
# 48     0.100542  0.134570
# 54     0.104635  0.128908
# 70     0.098468  0.122930
# 71     0.098726  0.121256
# 93     0.104860  0.129207
# 102    0.104514  0.125598
# 106    0.104527  0.135767
# 110    0.105316  0.125285
# 112    0.100673  0.126963
# 113    0.098547  0.123658
# 114    0.104599  0.125235
# 117    0.102649  0.129475
# 124    0.100358  0.127782
# 131    0.104495  0.118968
# 145    0.100417  0.129656
# 147    0.101696  0.121507
# 149    0.099583  0.125881
# 152    0.101837  0.109153
# 153    0.102993  0.124243
# 154    0.101703  0.133284
# 159    0.100808  0.120777
# 169    0.102116  0.124079
# 170    0.102592  0.128144
# 177    0.105100  0.119556
# 179    0.098757  0.117651
# ...         ...       ...
# 21235  0.105112  0.088038
# 21236  0.103745  0.091928
# 21237  0.097788  0.089425
# 21238  0.100733  0.090126
# 21239  0.101435  0.095737
# 21240  0.099897  0.091203
# 21241  0.099287  0.095685
# 21242  0.099397  0.091036
# 21243  0.100964  0.093957
# 21245  0.103834  0.095264
# 21246  0.101978  0.093278
# 21247  0.093250  0.100768
# 21249  0.102021  0.097237
# 21251  0.095963  0.092781
# 21252  0.100765  0.092941
# 21254  0.103407  0.094357
# 21255  0.100817  0.092348
# 21256  0.104564  0.093358
# 21257  0.098759  0.093096
# 21259  0.102096  0.091523
# 21264  0.101197  0.096137
# 21265  0.097330  0.098853
# 21266  0.096213  0.093676
# 21267  0.102210  0.088976
# 21268  0.102311  0.095944
# 21269  0.103514  0.099510
# 21270  0.097284  0.098421
# 21272  0.104758  0.098787
# 21273  0.101627  0.096647
# 21274  0.096280  0.093101
#
# [13084 rows x 2 columns]

# %%
# human_features.load_weights('human_features_weights_v2.h5')

# %%
# # print(df_hist.columns)
# print(df_hist['val_out_feature_1_acc'].max(), df_hist['val_out_feature_2_acc'].max(),
#        df_hist['val_out_feature_3_acc'].max(), df_hist['val_out_feature_4_acc'].max(),
#        df_hist['val_out_feature_5_acc'].max(), df_hist['val_out_feature_6_acc'].max(),
#        df_hist['val_out_feature_7_acc'].max(), df_hist['val_out_feature_8_acc'].max())
# # df_hist[df_hist['val_acc']>10.2]

# %%
test_g = datagen(len(val_list_of_writers)*5,val_path,val_list_of_writers, hshift = (-12,12), vis=True)
vx,vy = next(test_g)

# %%
print(vx.shape,vy[0].shape)
py = autoencoder.predict(vx[:10])
f,ax = plt.subplots(len(vx[:10]),2)
f.subplots_adjust(hspace = .00, wspace=.05)
f.set_size_inches(5,len(vx[:10])*3)
ax[0,0].set_title('TRUE')
ax[0,1].set_title('PRED')
for i in range(len(vx[:10])):
#     print(vy[0][i], vy[1][i])
    ax[i,0].imshow(vx[i].reshape((64,64)))
    ax[i,0].axis('off')
    
    ax[i,1].imshow(py[i].reshape((64,64)))
    ax[i,1].axis('off')
# Out:
# (4440, 64, 64, 1) (4440,)

# %%
encoder = Model(inputs=autoencoder.inputs,outputs=autoencoder.get_layer('encoded').output)

# %%
# df_val = pd.DataFrame(vy).T
# df_val.columns = ['identity','id','imagename']
# df_val = df_val.sort_values(by=['identity','imagename'])
# df_val = df_val.drop_duplicates()
# df_val = df_val.drop(columns=['id'])
# df_val

# %%
ids = vy[0].reshape(-1,1)
imagenames = vy[1].reshape(-1,1)
preds = encoder.predict(vx).reshape((-1,512))
# print(ids.shape,preds.shape)
# 
data=[]
for i in range(len(vx)):
    data.append([ids[i][0],imagenames[i][0],preds[i]])
df_data = pd.DataFrame(data=data, columns=['identity','imagename','latent'])
# df_outs['ids'] = ids
# df_outs['preds'] = preds 
df_data=df_data.sort_values(by='identity').reset_index()
df_data.shape
# Out:
# (4440, 4)

# %%
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm_notebook

# %%
cos_dist_out = cosine_similarity(list(df_data['latent'].values))

# %%
queried_count, idx_count, tp, tn, fp, fn = 0,0,0,0,0,0
cos_thresh = 0.6
data_result = []
fp_list = []
fn_list = []
r_counter = 0
stop_at = 10
prev_query = ''
prev_given = ''
given_count = 0
# total = cos_dist_out.shape[0]
for row in tqdm_notebook(cos_dist_out):
    c_counter = 0
    given_idx = df_data.iloc[r_counter]['identity']
    given_img = df_data.iloc[r_counter]['imagename']
    for col in row:
        queried_idx = df_data.iloc[c_counter]['identity']
        queried_img = df_data.iloc[c_counter]['imagename']
        if int(given_idx) == int(queried_idx) and cos_dist_out[r_counter][c_counter]>cos_thresh:
            tp += 1
        if int(given_idx) != int(queried_idx) and cos_dist_out[r_counter][c_counter]<cos_thresh:
            tn += 1
        if int(given_idx) != int(queried_idx) and cos_dist_out[r_counter][c_counter]>cos_thresh:
            fp += 1
            fp_list.append(os.path.join(queried_idx,queried_img))
        if int(given_idx) == int(queried_idx) and cos_dist_out[r_counter][c_counter]<cos_thresh:
            fn += 1
            fn_list.append(os.path.join(queried_idx,queried_img))
        if int(given_idx) == int(queried_idx):
            idx_count += 1
#             print('--i--',idx_count,'--i--')
#             print(given_idx,queried_idx)
        if prev_query != queried_idx:
#             print('--q--',queried_count,'--q--')
            queried_count += 1
        c_counter += 1
        prev_query = queried_idx
#         if queried_count == stop_at:
#             break
    precision = tp/(fp+tp)
    recall = tp/(tp+fn)
    f1 = 2*(precision*recall)/(precision+recall)
    total = np.sum((tp,tn,fp,fn))
    accuracy = (tp+tn)/total
    data_result.append([given_idx,given_img, idx_count, tp, tn, fp, fn,precision,recall,f1,accuracy, total, fp_list, fn_list])
    if prev_given != given_idx:
#         print('----',given_count,'-----')
        given_count+=1
    r_counter += 1
    prev_given = given_idx
    queried_count, idx_count, tp, tn, fp, fn = 0, 0, 0, 0, 0, 0
    fp_list = []
    fn_list = []
#     if given_count == stop_at:
#         break
# Out:
# HBox(children=(IntProgress(value=0, max=4440), HTML(value='')))

# %%
df_cos_dist_out = pd.DataFrame(data_result, columns=['identity','imagename','total_images_identity','TP','TN','FP','FN','precision','recall','f1','accuracy','total_images', 'FP_List','FN_List'])
df_cos_dist_out=df_cos_dist_out.sort_values(by='identity',ascending=True).reset_index().drop(columns=['index'])
df_cos_dist_out.head(50)
# Out:
#    identity       imagename  total_images_identity  TP    TN   FP  FN  \
# 0      1451  1451c_num2.png                     57  35  4259  124  22
# 1      1451  1451a_num3.png                     57  40  4208  175  17
# 2      1451  1451c_num5.png                     57   4  4335   48  53
# 3      1451  1451b_num2.png                     57  30  4325   58  27
# 4      1451  1451a_num2.png                     57  42  4256  127  15
# 5      1451  1451c_num1.png                     57  34  4278  105  23
# 6      1451  1451b_num2.png                     57  30  4325   58  27
# 7      1451  1451b_num1.png                     57  42  4236  147  15
# 8      1451  1451a_num1.png                     57  38  4198  185  19
# 9      1451  1451c_num5.png                     57   4  4333   50  53
# 10     1451  1451c_num6.png                     57  16  4145  238  41
# 11     1451  1451c_num1.png                     57  32  4292   91  25
# 12     1451  1451a_num2.png                     57  40  4264  119  17
# 13     1451  1451b_num1.png                     57  42  4231  152  15
# 14     1451  1451b_num2.png                     57  29  4298   85  28
# 15     1451  1451c_num5.png                     57   4  4328   55  53
# 16     1451  1451c_num6.png                     57  14  4081  302  43
# 17     1451  1451b_num3.png                     57   5  4331   52  52
# 18     1451  1451a_num2.png                     57  33  4301   82  24
# 19     1451  1451a_num3.png                     57  35  4234  149  22
# 20     1451  1451b_num1.png                     57  40  4249  134  17
# 21     1451  1451c_num2.png                     57  35  4260  123  22
# 22     1451  1451a_num1.png                     57  36  4203  180  21
# 23     1451  1451a_num3.png                     57  37  4214  169  20
# 24     1451  1451b_num3.png                     57   5  4340   43  52
# 25     1451  1451c_num2.png                     57  33  4277  106  24
# 26     1451  1451a_num2.png                     57  42  4256  127  15
# 27     1451  1451b_num1.png                     57  43  4228  155  14
# 28     1451  1451a_num3.png                     57  36  4216  167  21
# 29     1451  1451b_num3.png                     57   5  4322   61  52
# 30     1451  1451c_num6.png                     57  12  4119  264  45
# 31     1451  1451c_num3.png                     57   2  4312   71  55
# 32     1451  1451a_num1.png                     57  35  4273  110  22
# 33     1451  1451b_num1.png                     57  42  4221  162  15
# 34     1451  1451a_num2.png                     57  34  4290   93  23
# 35     1451  1451a_num3.png                     57  34  4219  164  23
# 36     1451  1451c_num5.png                     57   4  4328   55  53
# 37     1451  1451b_num2.png                     57  30  4321   62  27
# 38     1451  1451b_num1.png                     57  42  4228  155  15
# 39     1451  1451a_num3.png                     57  37  4215  168  20
# 40     1451  1451a_num3.png                     57  34  4217  166  23
# 41     1451  1451a_num3.png                     57  40  4207  176  17
# 42     1451  1451c_num2.png                     57  35  4259  124  22
# 43     1451  1451a_num1.png                     57  33  4242  141  24
# 44     1451  1451c_num1.png                     57  33  4301   82  24
# 45     1451  1451b_num1.png                     57  42  4236  147  15
# 46     1451  1451a_num2.png                     57  40  4264  119  17
# 47     1451  1451a_num1.png                     57  37  4221  162  20
# 48     1451  1451a_num1.png                     57  36  4206  177  21
# 49     1451  1451c_num6.png                     57  12  4133  250  45
#
#     precision    recall        f1  accuracy  total_images  \
# 0    0.220126  0.614035  0.324074  0.967117          4440
# 1    0.186047  0.701754  0.294118  0.956757          4440
# 2    0.076923  0.070175  0.073394  0.977252          4440
# 3    0.340909  0.526316  0.413793  0.980856          4440
# 4    0.248521  0.736842  0.371681  0.968018          4440
# 5    0.244604  0.596491  0.346939  0.971171          4440
# 6    0.340909  0.526316  0.413793  0.980856          4440
# 7    0.222222  0.736842  0.341463  0.963514          4440
# 8    0.170404  0.666667  0.271429  0.954054          4440
# 9    0.074074  0.070175  0.072072  0.976802          4440
# 10   0.062992  0.280702  0.102894  0.937162          4440
# 11   0.260163  0.561404  0.355556  0.973874          4440
# 12   0.251572  0.701754  0.370370  0.969369          4440
# 13   0.216495  0.736842  0.334661  0.962387          4440
# 14   0.254386  0.508772  0.339181  0.974550          4440
# 15   0.067797  0.070175  0.068966  0.975676          4440
# 16   0.044304  0.245614  0.075067  0.922297          4440
# 17   0.087719  0.087719  0.087719  0.976577          4440
# 18   0.286957  0.578947  0.383721  0.976126          4440
# 19   0.190217  0.614035  0.290456  0.961486          4440
# 20   0.229885  0.701754  0.346320  0.965991          4440
# 21   0.221519  0.614035  0.325581  0.967342          4440
# 22   0.166667  0.631579  0.263736  0.954730          4440
# 23   0.179612  0.649123  0.281369  0.957432          4440
# 24   0.104167  0.087719  0.095238  0.978604          4440
# 25   0.237410  0.578947  0.336735  0.970721          4440
# 26   0.248521  0.736842  0.371681  0.968018          4440
# 27   0.217172  0.754386  0.337255  0.961937          4440
# 28   0.177340  0.631579  0.276923  0.957658          4440
# 29   0.075758  0.087719  0.081301  0.974550          4440
# 30   0.043478  0.210526  0.072072  0.930405          4440
# 31   0.027397  0.035088  0.030769  0.971622          4440
# 32   0.241379  0.614035  0.346535  0.970270          4440
# 33   0.205882  0.736842  0.321839  0.960135          4440
# 34   0.267717  0.596491  0.369565  0.973874          4440
# 35   0.171717  0.596491  0.266667  0.957883          4440
# 36   0.067797  0.070175  0.068966  0.975676          4440
# 37   0.326087  0.526316  0.402685  0.979955          4440
# 38   0.213198  0.736842  0.330709  0.961712          4440
# 39   0.180488  0.649123  0.282443  0.957658          4440
# 40   0.170000  0.596491  0.264591  0.957432          4440
# 41   0.185185  0.701754  0.293040  0.956532          4440
# 42   0.220126  0.614035  0.324074  0.967117          4440
# 43   0.189655  0.578947  0.285714  0.962838          4440
# 44   0.286957  0.578947  0.383721  0.976126          4440
# 45   0.222222  0.736842  0.341463  0.963514          4440
# 46   0.251572  0.701754  0.370370  0.969369          4440
# 47   0.185930  0.649123  0.289062  0.959009          4440
# 48   0.169014  0.631579  0.266667  0.955405          4440
# 49   0.045802  0.210526  0.075235  0.933559          4440
#
#                                               FP_List  \
# 0   [1457/1457b_num2.png, 1457/1457b_num2.png, 145...
# 1   [1452/1452c_num1.png, 1452/1452b_num1.png, 145...
# 2   [1457/1457c_num1.png, 1461/1461b_num2.png, 146...
# 3   [1457/1457a_num5.png, 1457/1457c_num2.png, 145...
# 4   [1452/1452c_num1.png, 1452/1452b_num1.png, 145...
# 5   [1457/1457b_num2.png, 1457/1457b_num2.png, 145...
# 6   [1457/1457a_num5.png, 1457/1457c_num2.png, 145...
# 7   [1452/1452c_num1.png, 1452/1452c_num1.png, 145...
# 8   [1452/1452c_num1.png, 1452/1452b_num1.png, 145...
# 9   [1457/1457c_num1.png, 1457/1457c_num1.png, 145...
# 10  [1452/1452c_num1.png, 1452/1452c_num1.png, 145...
# 11  [1457/1457b_num2.png, 1457/1457b_num2.png, 145...
# 12  [1452/1452c_num1.png, 1452/1452b_num1.png, 145...
# 13  [1452/1452c_num1.png, 1452/1452c_num1.png, 145...
# 14  [1456/1456a_num3.png, 1456/1456a_num3.png, 145...
# 15  [1457/1457c_num1.png, 1457/1457c_num1.png, 145...
# 16  [1452/1452c_num1.png, 1452/1452c_num1.png, 145...
# 17  [1456/1456b_num2.png, 1456/1456b_num2.png, 145...
# 18  [1452/1452c_num1.png, 1452/1452b_num1.png, 145...
# 19  [1452/1452b_num1.png, 1452/1452b_num1.png, 145...
# 20  [1452/1452c_num1.png, 1452/1452c_num1.png, 145...
# 21  [1457/1457b_num2.png, 1457/1457b_num2.png, 145...
# 22  [1452/1452c_num1.png, 1452/1452b_num1.png, 145...
# 23  [1452/1452c_num1.png, 1452/1452b_num1.png, 145...
# 24  [1456/1456b_num2.png, 1456/1456b_num2.png, 146...
# 25  [1457/1457b_num2.png, 1457/1457b_num2.png, 145...
# 26  [1452/1452c_num1.png, 1452/1452b_num1.png, 145...
# 27  [1452/1452c_num1.png, 1452/1452c_num1.png, 145...
# 28  [1452/1452c_num1.png, 1452/1452b_num1.png, 145...
# 29  [1453/1453a_num1.png, 1453/1453a_num1.png, 145...
# 30  [1452/1452c_num1.png, 1452/1452c_num1.png, 145...
# 31  [1457/1457a_num4.png, 1457/1457a_num4.png, 145...
# 32  [1452/1452c_num1.png, 1452/1452c_num1.png, 145...
# 33  [1452/1452c_num1.png, 1452/1452c_num1.png, 145...
# 34  [1452/1452c_num1.png, 1452/1452b_num1.png, 145...
# 35  [1452/1452b_num1.png, 1452/1452c_num1.png, 145...
# 36  [1457/1457c_num1.png, 1457/1457c_num1.png, 145...
# 37  [1457/1457b_num2.png, 1457/1457a_num5.png, 145...
# 38  [1452/1452c_num1.png, 1452/1452c_num1.png, 145...
# 39  [1452/1452c_num1.png, 1452/1452b_num1.png, 145...
# 40  [1452/1452c_num1.png, 1452/1452b_num1.png, 145...
# 41  [1452/1452c_num1.png, 1452/1452b_num1.png, 145...
# 42  [1457/1457b_num2.png, 1457/1457b_num2.png, 145...
# 43  [1452/1452c_num1.png, 1452/1452c_num1.png, 145...
# 44  [1457/1457b_num2.png, 1457/1457b_num2.png, 145...
# 45  [1452/1452c_num1.png, 1452/1452c_num1.png, 145...
# 46  [1452/1452c_num1.png, 1452/1452b_num1.png, 145...
# 47  [1452/1452c_num1.png, 1452/1452c_num1.png, 145...
# 48  [1452/1452c_num1.png, 1452/1452b_num1.png, 145...
# 49  [1452/1452c_num1.png, 1452/1452c_num1.png, 145...
#
#                                               FN_List
# 0   [1451/1451c_num3.png, 1451/1451a_num3.png, 145...
# 1   [1451/1451c_num3.png, 1451/1451c_num5.png, 145...
# 2   [1451/1451c_num2.png, 1451/1451c_num3.png, 145...
# 3   [1451/1451c_num3.png, 1451/1451a_num2.png, 145...
# 4   [1451/1451c_num3.png, 1451/1451c_num5.png, 145...
# 5   [1451/1451c_num3.png, 1451/1451a_num1.png, 145...
# 6   [1451/1451c_num3.png, 1451/1451a_num2.png, 145...
# 7   [1451/1451c_num3.png, 1451/1451c_num5.png, 145...
# 8   [1451/1451c_num3.png, 1451/1451a_num2.png, 145...
# 9   [1451/1451c_num2.png, 1451/1451c_num3.png, 145...
# 10  [1451/1451c_num2.png, 1451/1451c_num3.png, 145...
# 11  [1451/1451c_num3.png, 1451/1451c_num5.png, 145...
# 12  [1451/1451c_num3.png, 1451/1451a_num1.png, 145...
# 13  [1451/1451c_num3.png, 1451/1451c_num5.png, 145...
# 14  [1451/1451c_num3.png, 1451/1451a_num2.png, 145...
# 15  [1451/1451c_num2.png, 1451/1451c_num3.png, 145...
# 16  [1451/1451c_num2.png, 1451/1451c_num3.png, 145...
# 17  [1451/1451c_num2.png, 1451/1451c_num3.png, 145...
# 18  [1451/1451c_num3.png, 1451/1451c_num5.png, 145...
# 19  [1451/1451c_num2.png, 1451/1451c_num3.png, 145...
# 20  [1451/1451c_num3.png, 1451/1451c_num5.png, 145...
# 21  [1451/1451c_num3.png, 1451/1451a_num3.png, 145...
# 22  [1451/1451c_num3.png, 1451/1451a_num2.png, 145...
# 23  [1451/1451c_num2.png, 1451/1451c_num3.png, 145...
# 24  [1451/1451c_num2.png, 1451/1451c_num3.png, 145...
# 25  [1451/1451c_num3.png, 1451/1451a_num3.png, 145...
# 26  [1451/1451c_num3.png, 1451/1451c_num5.png, 145...
# 27  [1451/1451c_num3.png, 1451/1451c_num5.png, 145...
# 28  [1451/1451c_num2.png, 1451/1451c_num3.png, 145...
# 29  [1451/1451c_num2.png, 1451/1451c_num3.png, 145...
# 30  [1451/1451c_num2.png, 1451/1451c_num3.png, 145...
# 31  [1451/1451c_num2.png, 1451/1451a_num1.png, 145...
# 32  [1451/1451c_num3.png, 1451/1451c_num5.png, 145...
# 33  [1451/1451c_num3.png, 1451/1451c_num5.png, 145...
# 34  [1451/1451c_num3.png, 1451/1451c_num5.png, 145...
# 35  [1451/1451c_num2.png, 1451/1451c_num3.png, 145...
# 36  [1451/1451c_num2.png, 1451/1451c_num3.png, 145...
# 37  [1451/1451c_num3.png, 1451/1451a_num2.png, 145...
# 38  [1451/1451c_num3.png, 1451/1451c_num5.png, 145...
# 39  [1451/1451c_num2.png, 1451/1451c_num3.png, 145...
# 40  [1451/1451c_num2.png, 1451/1451c_num3.png, 145...
# 41  [1451/1451c_num3.png, 1451/1451c_num5.png, 145...
# 42  [1451/1451c_num3.png, 1451/1451a_num3.png, 145...
# 43  [1451/1451c_num3.png, 1451/1451a_num2.png, 145...
# 44  [1451/1451c_num3.png, 1451/1451a_num1.png, 145...
# 45  [1451/1451c_num3.png, 1451/1451c_num5.png, 145...
# 46  [1451/1451c_num3.png, 1451/1451a_num1.png, 145...
# 47  [1451/1451c_num3.png, 1451/1451a_num2.png, 145...
# 48  [1451/1451c_num3.png, 1451/1451a_num2.png, 145...
# 49  [1451/1451c_num2.png, 1451/1451c_num3.png, 145...

# %%
df_cos_dist_out.to_csv('results-DL_AE_Maxpool_1x1x512_Unseen.csv')

# %%
# print(df_cos_dist_out.keys())
total = df_cos_dist_out.shape[0]
total_images_identity = df_cos_dist_out['total_images_identity']
tps = df_cos_dist_out['TP'].sum()
fps = df_cos_dist_out['FP'].sum()
tns = df_cos_dist_out['TN'].sum()
fns = df_cos_dist_out['FN'].sum()
precision = tps/(fps+tps)
recall = tps/(tps+fns)
f1 = 2*(precision*recall)/(precision+recall)
print('precision:',precision,'\nrecall:',recall,'\nf1:',f1)
acc = df_cos_dist_out['accuracy'].mean()
print('Intra Writer Accuracy (Type 1):',np.mean(df_cos_dist_out['TP']/total_images_identity))
print('Inter Writer Accuracy (Type 2)::',tns/total/total)
print('acc:',acc)
# Out:
# precision: 0.14253974326785507
# recall: 0.6679521537355383
# f1: 0.23494307311569793
# Intra Writer Accuracy (Type 1): 0.6731905250800788
# Inter Writer Accuracy (Type 2):: 0.9454786543300058
# acc: 0.9527358777696615

# %%
# test_im_shifted=test_im_normal
# test_im_shifted = vx[-2]
# rand = np.random.randint(-12,12)
# test_im_shifted=np.roll(axis=0,a=test_im_shifted,shift=-10)
# test = np.zeros((64,64,1))
# test[0:45]=test_im_shifted
# test_im_normal = vx[1]
# test_im_shifted = vx[2]
# plt.imshow(test_im_shifted.reshape((64,64)))
test_im_normal = 255.0-cv2.imread('../Handwriting/cleaned_AND_data_64x64/0301c_num2.png',0)
test_im_shifted = 255.0-cv2.imread('../Handwriting/cleaned_AND_data_64x64/0301c_num1.png',0)
f,ax = plt.subplots(1,2)
f.subplots_adjust(hspace = .00, wspace=.05)
f.set_size_inches(5,1*3)
ax[0].imshow(test_im_normal.reshape((64,64)))
ax[0].axis('off')

ax[1].imshow(test_im_shifted.reshape((64,64)))
ax[1].axis('off')
ax[0].set_title('Left Input')
ax[1].set_title('Right Input')
# Out:
# Text(0.5, 1.0, 'Right Input')

# %%
py1 = encoder.predict(test_im_normal.reshape((1,64,64,1)))
py2 = encoder.predict(test_im_shifted.reshape((1,64,64,1)))
py1[py1==0].shape,py2[py2==0].shape
# Out:
# ((259,), (277,))

# %%
py1 = py1.reshape((-1,512))
py2 = py2.reshape((-1,512))
print(py1.shape,py2.shape)
from sklearn.metrics.pairwise import cosine_similarity, cosine_distances, euclidean_distances
cosine_similarity(py1,py2), cosine_distances(py1,py2), euclidean_distances(py1,py2)
# Out:
# (1, 512) (1, 512)
# (array([[0.767698]], dtype=float32),
#  array([[0.23230201]], dtype=float32),
#  array([[1968.4119]], dtype=float32))

# %%
val_list_of_writers[:2]
# Out:
# ['1469b_num3.png', '1453b_num4.png']
